# %% [markdown]
# ## Intro Aprendizaje por Refuerzo

# %% [markdown]
# Considera el escenario de enseñarle nuevos trucos a un perro. El perro no entiende nuestro lenguaje, así que no podemos decirle qué hacer. En cambio, seguimos una estrategia diferente. Emulamos una situación (o una señal), y el perro intenta responder de muchas maneras diferentes. Si la respuesta del perro es la deseada, lo recompensamos con golosinas. Ahora, adivina qué, la próxima vez que el perro se enfrenta a la misma situación, ejecuta una acción similar con aún más entusiasmo esperando más comida. Esto es como aprender "qué hacer" a partir de experiencias positivas. De manera similar, los perros tienden a aprender qué no hacer cuando se enfrentan a experiencias negativas.

# %% [markdown]
# ## Entendiendo cómo funciona el Aprendizaje por Refuerzo
#
# En un sentido más amplio, así es como funciona el Aprendizaje por Refuerzo:
#
# * Tu perro es un "agente" que está expuesto al entorno. El entorno podría ser tu casa, contigo.
# * Las situaciones que encuentran son análogas a un estado. Un ejemplo de un estado podría ser tu perro de pie y tú usando una palabra específica con cierto tono en tu sala de estar.
# * Nuestros agentes reaccionan realizando una acción para pasar de un "estado" a otro "estado"; por ejemplo, tu perro pasa de estar de pie a sentarse.
# * Después de la transición, pueden recibir una recompensa o una penalización a cambio. ¡Les das una golosina! O un "No" como penalización.
# * La política es la estrategia de elegir una acción dada un estado en espera de mejores resultados.

# %% [markdown]
# El Aprendizaje por Refuerzo se encuentra entre el espectro del Aprendizaje Supervisado y el No Supervisado, y hay algunas cosas importantes que tener en cuenta:
#
# #### No siempre es beneficioso ser codicioso
#
# **Ser codicioso no siempre funciona:**
#
# * Hay cosas que son fáciles de hacer para obtener una gratificación instantánea, y hay cosas que proporcionan recompensas a largo plazo. El objetivo no es ser codicioso buscando las recompensas inmediatas, sino optimizar las recompensas máximas durante todo el entrenamiento.
#
# #### La secuencia importa en el Aprendizaje por Refuerzo
#
# **La secuencia importa en el Aprendizaje por Refuerzo:**
#
# * La recompensa del agente no solo depende del estado actual, sino de toda la historia de estados. A diferencia del aprendizaje supervisado y no supervisado, el tiempo es importante aquí.

# %% [markdown]
# ## El proceso

# %% [markdown]
# <img src="./img/Reinforcement-Learning-Animation.gif" alt="drawing" width="650"/>

# %% [markdown]
# En cierto sentido, el Aprendizaje por Refuerzo es la ciencia de tomar decisiones óptimas utilizando experiencias. Desglosándolo, el proceso de Aprendizaje por Refuerzo involucra estos pasos simples:
#
# 1. Observación del entorno.
# 2. Decidir cómo actuar utilizando alguna estrategia.
# 3. Actuar en consecuencia.
# 4. Recibir una recompensa o penalización.
# 5. Aprender de las experiencias y refinar nuestra estrategia.
# 6. Iterar hasta encontrar una estrategia óptima.
#
# Ahora vamos a entender el Aprendizaje por Refuerzo desarrollando un agente para aprender a jugar un juego automáticamente por sí mismo.

# %% [markdown]
# ## Comenzando con Gym
#
# Gym es un conjunto de herramientas para desarrollar y comparar algoritmos de aprendizaje por refuerzo. No hace suposiciones sobre la estructura de tu agente y es compatible con cualquier biblioteca de cálculo numérico, como TensorFlow o Theano.
#
# La biblioteca Gym es una colección de problemas de prueba, o entornos, que puedes usar para desarrollar tus algoritmos de aprendizaje por refuerzo. Estos entornos tienen una interfaz compartida, lo que te permite escribir algoritmos generales.

# %%
# %pip install gymnasium[classic_control]
# %pip install pygame
# Out:
# Collecting gymnasium[classic_control]
#   Downloading gymnasium-1.3.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.21.0 in /home/david/The_Bridge/2026-02-DS-FT-BIL/2026-02-BILBAO-FT-Data-Science/.venv/lib/python3.11/site-packages (from gymnasium[classic_control]) (2.3.5)
# Collecting cloudpickle>=1.2.0 (from gymnasium[classic_control])
#   Using cached cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/david/The_Bridge/2026-02-DS-FT-BIL/2026-02-BILBAO-FT-Data-Science/.venv/lib/python3.11/site-packages (from gymnasium[classic_control]) (4.15.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium[classic_control])
#   Downloading farama_notifications-0.0.6-py3-none-any.whl.metadata (729 bytes)
# Collecting pygame-ce>=2.1.3 (from gymnasium[classic_control])
#   Downloading pygame_ce-2.5.7-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Downloading gymnasium-1.3.0-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 15.5 MB/s  0:00:00
# Using cached cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading farama_notifications-0.0.6-py3-none-any.whl (2.9 kB)
# Downloading pygame_ce-2.5.7-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (12.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 9.3 MB/s  0:00:01 eta 0:00:01
# Installing collected packages: farama-notifications, pygame-ce, cloudpickle, gymnasium
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [gymnasium]/4 [gymnasium]
# Successfully installed cloudpickle-3.1.2 farama-notifications-0.0.6 gymnasium-1.3.0 pygame-ce-2.5.7
# Note: you may need to restart the kernel to use updated packages.
# Collecting pygame
#   Downloading pygame-2.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Downloading pygame-2.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 29.4 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: pygame
# Successfully installed pygame-2.6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
#!pip install numpy==1.23.5

# %% [markdown]
# ## Entornos
#
# Aquí tienes un ejemplo mínimo para comenzar a ejecutar algo. Esto ejecutará una instancia del entorno CartPole-v0 durante 1000 pasos de tiempo, representando el entorno en cada paso.

# %% [markdown]
#  Consiste en equilibrar un poste (péndulo) montado en la parte superior de un carrito móvil:
#  * El **objetivo** es mantener el poste en posición vertical mientras el carrito se mueve hacia adelante y hacia atrás en una pista.
#  * El **agente** (o jugador) tiene dos acciones disponibles en cada paso de tiempo: empujar el carrito hacia la izquierda o hacia la derecha.
#  * El **desafío** radica en tomar decisiones adecuadas para evitar que el poste caiga mientras se mueve el carrito.
#
#  Este problema es un ejemplo comúnmente utilizado para probar algoritmos de aprendizaje por refuerzo debido a su simplicidad y naturaleza desafiante.

# %% [markdown]
# https://gymnasium.farama.org/api/env/

# %%
import gymnasium as gym
import warnings
warnings.filterwarnings("ignore")
import time
import numpy as np

# %% [markdown]
# Crea un entorno de simulación llamado MountainCar-v0.
# Este es un entorno clásico en gym en el que un coche debe moverse hacia arriba de una colina empinada.
# El objetivo es aplicar fuerza en las direcciones izquierda o derecha para ganar impulso suficiente y alcanzar la cima.

# %%
env = gym.make('MountainCar-v0')

# %% [markdown]
# Reinicia el entorno a su estado inicial.
# Esto es útil para comenzar una nueva simulación. Devuelve el estado inicial del entorno.

# %%
env.reset()
# Out:
# (array([-0.5161618,  0.       ], dtype=float32), {})

# %% [markdown]
# A continuación: se ejecuta un bucle con 300 pasos dentro del entorno.

# %% [markdown]
# ``env.render()`` dibuja el entorno en una ventana gráfica para que puedas visualizar lo que está sucediendo (por ejemplo, el carro moviéndose).

# %% [markdown]
# ``env.action_space.sample()``
# Toma una acción aleatoria en el espacio de acciones del entorno. En este caso, las acciones posibles son:
#
# * 0: Aplicar fuerza hacia la izquierda.
# * 1: No aplicar fuerza.
# * 2: Aplicar fuerza hacia la derecha.

# %%
#for i in range(300):
#    env.render()
#    time.sleep(0.1)
#    env.step(env.action_space.sample()) # take a random action
#env.close()

# %%
#numpy.__version__

# %%
import gymnasium as gym
import warnings
import numpy

warnings.filterwarnings("ignore")

# Crear el entorno
env = gym.make('MountainCar-v0')
env.reset()

# Loop para ejecutar pasos en el entorno
for i in range(300):
    env.render()  # Renderizar el entorno
    env.step(env.action_space.sample())  # Tomar una acción aleatoria

env.close()

# %%
#numpy.__version__

# %% [markdown]
# Normalmente, terminaremos la simulación antes de que el carrito-péndulo tenga permitido salir de la pantalla. Más sobre eso después. Por ahora, por favor ignora la advertencia sobre llamar a `step()` aunque este entorno ya haya devuelto `done = True`.
#
# Si deseas ver otros entornos en acción, intenta reemplazar `CartPole-v0` arriba con algo como `MountainCar-v0`, `MsPacman-v0` (requiere la dependencia de Atari), o `Hopper-v1` (requiere las dependencias de MuJoCo). Todos los entornos descienden de la clase base `Env`.
#
# Ten en cuenta que si te faltan dependencias, deberías recibir un mensaje de error útil que te diga qué te falta. (Avísanos si alguna dependencia te causa problemas sin una instrucción clara para solucionarlo). Instalar una dependencia faltante generalmente es bastante simple. También necesitarás una licencia de MuJoCo para `Hopper-v1`.

# %% [markdown]
# ## Observaciones
#
# Si queremos hacer algo mejor que tomar acciones aleatorias en cada paso, probablemente sería bueno saber realmente qué están haciendo nuestras acciones en el entorno.
#
# La función `step` del entorno devuelve exactamente lo que necesitamos. De hecho, `step` devuelve cuatro valores. Estos son:
#
# * `observation` (object): un objeto específico del entorno que representa tu observación del entorno. Por ejemplo, datos de píxeles de una cámara, ángulos de articulación y velocidades de articulación de un robot, o el estado del tablero en un juego de mesa.
# * `reward` (float): cantidad de recompensa lograda por la acción anterior. La escala varía entre entornos, pero el objetivo es siempre aumentar tu recompensa total.
# * `done` (bool): si es hora de restablecer el entorno nuevamente. La mayoría (pero no todos) de las tareas están divididas en episodios bien definidos, y `done` siendo True indica que el episodio ha terminado. (Por ejemplo, tal vez el poste se inclinó demasiado, o perdiste tu última vida).
# * `truncated` (bool): True si el episodio se trunca debido a un límite de tiempo o una razón que no está definida.
# * `info` (dict): información de diagnóstico útil para la depuración. A veces puede ser útil para el aprendizaje (por ejemplo, podría contener las probabilidades crudas detrás del último cambio de estado del entorno). Sin embargo, no se permite usar esto para el aprendizaje en las evaluaciones oficiales de tu agente.
#
# Esto es simplemente una implementación del clásico "bucle agente-entorno". En cada paso de tiempo, el agente elige una acción, y el entorno devuelve una observación y una recompensa.

# %%
env = gym.make('MountainCar-v0')

# %%
env.action_space
# Out:
# Discrete(3)

# %% [markdown]
# ## Espacio de Acciones
#
# Hay 3 acciones discretas determinísticas:
#
# | Num | Observación          | Valor | Unidad       |
# |-----|----------------------|-------|--------------|
# | 0   | Acelerar a la izquierda | Inf   | posición (m) |
# | 1   | No acelerar              | Inf   | posición (m) |
# | 2   | Acelerar a la derecha    | Inf   | posición (m) |

# %%
# env = gym.make('MountainCar-v0', render_mode='human')
print(env.observation_space.shape)
# Out:
# (2,)

# %% [markdown]
# ## Espacio de Observación
#
# La observación es un ndarray con forma (2,), donde los elementos corresponden a lo siguiente:
#
# | Num | Observación                    | Mínimo | Máximo | Unidad        |
# |-----|--------------------------------|--------|--------|---------------|
# | 0   | posición del coche a lo largo del eje x | -Inf   | Inf    | posición (m) |
# | 1   | velocidad del coche             | -Inf   | Inf    | velocidad (m) |

# %%
import numpy as np
np.random.choice(np.array([1,2,3]))
# Out:
# np.int64(1)

# %%
# import gym
env = gym.make('MountainCar-v0', render_mode='human')
for i_episode in range(5):
    # Reset del entorno
    print("Intento", i_episode)
    observation = env.reset()
    for t in range(10000):
        if t % 10 == 0:
            print("Accion", t)
            print("Observación", observation)
        # Visualizar ejercicio
        env.render()
        # Print del estado
        # print(observation)
        # Guarda en la variable action una de las acciones posibles elegida al azar
        action = env.action_space.sample()
        # Ejecuta esa acción, lo que nos devuelve, un nuevo estado, una recompensa, booleana /
        # que nos indica que ha alcanzado su objetivo e info debug
        observation, reward, done, truncated, info = env.step(action)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            break
env.close()
# Out:
# Intento 0
# Accion 0
# Observación (array([-0.45735607,  0.        ], dtype=float32), {})
# Accion 10
# Observación [-0.48983866 -0.0052978 ]
# Accion 20
# Observación [-0.5484154  -0.00685355]
# Accion 30
# Observación [-0.5913934  -0.00438428]
# Accion 40
# Observación [-0.618646   -0.00114176]
# Accion 50
# Observación [-6.3331658e-01  4.5826467e-04]
# Accion 60
# Observación [-0.5911394   0.00758825]
# Accion 70
# Observación [-0.48504254  0.01458675]
# Accion 80
# Observación [-0.36012608  0.00819296]
# Accion 90
# Observación [-0.33279687 -0.00296178]
# Accion 100
# Observación [-0.40820888 -0.01175787]
# Accion 110
# Observación [-0.5680812  -0.01936326]
# Accion 120
# Observación [-0.7246938  -0.01140354]
# Accion 130
# Observación [-0.7656243  0.0035144]
# Accion 140
# Observación [-0.65786886  0.01475071]
# Accion 150
# Observación [-0.4638765   0.02153009]
# Accion 160
# Observación [-0.3057541   0.01045415]
# Accion 170
# Observación [-0.31214303 -0.00632978]
# Accion 180
# Observación [-0.43767735 -0.01930843]
# Accion 190
# Observación [-0.66610247 -0.02448337]
# Accion 200
# Observación [-0.7941132  -0.00547958]
# Accion 210
# Observación [-0.73783326  0.01414559]
# Accion 220
# Observación [-0.5428762   0.02390819]
# Accion 230
# Observación [-0.3056483   0.02014029]
# Accion 240
# Observación [-0.21180286  0.0007709 ]
# Accion 250
# Observación [-0.28640288 -0.01645284]
# Accion 260
# Observación [-0.5452477  -0.03190897]
# Accion 270
# Observación [-0.80888844 -0.0192803 ]
# Accion 280
# Observación [-0.9200623  -0.00274005]
# Accion 290
# Observación [-0.8414226   0.01481096]
# Accion 300
# Observación [-0.6204813   0.02735041]
# Accion 310
# Observación [-0.3511925   0.02217359]
# Accion 320
# Observación [-2.4392213e-01 -2.1865894e-04]
# Accion 330
# Observación [-0.36040604 -0.01879893]
# Accion 340
# Observación [-0.5822178  -0.02259164]
# Accion 350
# Observación [-0.74992377 -0.01121232]
# Accion 360
# Observación [-0.7712521   0.00692113]
# Accion 370
# Observación [-0.62895215  0.01954822]
# Accion 380
# Observación [-0.4168321   0.01917056]
# Accion 390
# Observación [-0.26839477  0.01037223]
# Accion 400
# Observación [-0.2893329  -0.01027358]
# Accion 410
# Observación [-0.4710459  -0.02176413]
# Accion 420
# Observación [-0.7010299  -0.02097768]
# Accion 430
# Observación [-0.84238994 -0.00685996]
# Accion 440
# Observación [-0.8151547  0.0117334]
# Accion 450
# Observación [-0.5877392   0.02665764]
# Accion 460
# Observación [-0.2917674   0.02766652]
# Accion 470
# Observación [-0.1486989   0.00462095]
# Accion 480
# Observación [-0.20708378 -0.01560089]
# Accion 490
# Observación [-0.45471236 -0.02925027]
# Accion 500
# Observación [-0.71921945 -0.02101056]
# Accion 510
# Observación [-0.85173535 -0.00302725]
# Accion 520
# Observación [-0.78399193  0.0151126 ]
# Accion 530
# Observación [-0.5709348   0.02644376]
# Accion 540
# Observación [-0.31937206  0.01909969]
# Accion 550
# Observación [-0.246579   -0.00317279]
# Accion 560
# Observación [-0.37828487 -0.02119418]
# Accion 570
# Observación [-0.60614556 -0.0224685 ]
# Accion 580
# Observación [-0.77968687 -0.01028784]
# Accion 590
# Observación [-0.7730528   0.00762644]
# Accion 600
# Observación [-0.62459135  0.01697873]
# Accion 610
# Observación [-0.41614053  0.01965532]
# Accion 620
# Observación [-0.30190155  0.00346916]
# Accion 630
# Observación [-0.3417165  -0.01060428]
# Accion 640
# Observación [-0.49823236 -0.01807161]
# Accion 650
# Observación [-0.6731193  -0.01476767]
# Accion 660
# Observación [-0.74772984 -0.0020898 ]
# Accion 670
# Observación [-0.7026777   0.00980581]
# Accion 680
# Observación [-0.55601007  0.01860684]
# Accion 690
# Observación [-0.39583996  0.01114472]
# Accion 700
# Observación [-0.36169374 -0.00084005]
# Accion 710
# Observación [-0.43193567 -0.00964028]
# Accion 720
# Observación [-0.53624755 -0.01100063]
# Accion 730
# Observación [-0.61242396 -0.00525886]
# Accion 740
# Observación [-0.636113    0.00150056]
# Accion 750
# Observación [-0.5845224   0.00530656]
# Accion 760
# Observación [-0.5179116   0.00331278]
# Accion 770
# Observación [-0.47755373  0.00565607]
# Accion 780
# Observación [-0.4468222   0.00196144]
# Accion 790
# Observación [-0.45827883 -0.00359468]
# Accion 800
# Observación [-0.5237012  -0.00859477]
# Accion 810
# Observación [-0.58181626 -0.0043274 ]
# Accion 820
# Observación [-0.5936219   0.00166167]
# Accion 830
# Observación [-0.54173774  0.00630873]
# Accion 840
# Observación [-0.46500942  0.00819613]
# Accion 850
# Observación [-0.40099257  0.00347218]
# Accion 860
# Observación [-0.4054865  -0.00262656]
# Accion 870
# Observación [-0.47680053 -0.01035705]
# Accion 880
# Observación [-0.5544716  -0.00592652]
# Accion 890
# Observación [-0.62674624 -0.00608582]
# Accion 900
# Observación [-0.61110365  0.00772851]
# Accion 910
# Observación [-0.50807464  0.01311246]
# Accion 920
# Observación [-0.39694273  0.00786119]
# Accion 930
# Observación [-0.36415005 -0.00102732]
# Accion 940
# Observación [-0.4725702 -0.0159374]
# Accion 950
# Observación [-0.6353706  -0.01311173]
# Accion 960
# Observación [-7.0299453e-01 -7.3880365e-05]
# Accion 970
# Observación [-0.6117806  0.0158908]
# Accion 980
# Observación [-0.44727856  0.01383412]
# Accion 990
# Observación [-0.34777614  0.00881481]
# Accion 1000
# Observación [-0.3650893  -0.00925995]
# Accion 1010
# Observación [-0.5085222  -0.01883738]
# Accion 1020
# Observación [-0.67292726 -0.01426363]
# Accion 1030
# Observación [-0.7321549  -0.00104213]
# Accion 1040
# Observación [-0.6491777   0.01289576]
# Accion 1050
# Observación [-0.48275506  0.01676255]
# Accion 1060
# Observación [-0.34879386  0.01100225]
# Accion 1070
# Observación [-0.33849397 -0.00677695]
# Accion 1080
# Observación [-0.47958097 -0.01712041]
# Accion 1090
# Observación [-0.62408715 -0.01114975]
# Accion 1100
# Observación [-0.67106766  0.00143694]
# Accion 1110
# Observación [-0.64180064  0.00553296]
# Accion 1120
# Observación [-0.5798588  0.0072732]
# Accion 1130
# Observación [-0.48554605  0.00828672]
# Accion 1140
# Observación [-0.4473257 -0.0015099]
# Accion 1150
# Observación [-0.48906446 -0.00830887]
# Accion 1160
# Observación [-0.5597945 -0.0031106]
# Accion 1170
# Observación [-0.58905184 -0.00234437]
# Accion 1180
# Observación [-0.59239215  0.00201394]
# Accion 1190
# Observación [-0.58152944  0.00176067]
# Accion 1200
# Observación [-0.5754937   0.00076871]
# Accion 1210
# Observación [-0.5855077  -0.00104468]
# Accion 1220
# Observación [-0.5605412   0.00513134]
# Accion 1230
# Observación [-0.5169384   0.00229888]
# Accion 1240
# Observación [-0.50982213 -0.00067397]
# Accion 1250
# Observación [-5.0770015e-01  1.9147879e-04]
# Accion 1260
# Observación [-0.5244203  -0.00368171]
# Accion 1270
# Observación [-5.3223127e-01 -3.9637325e-05]
# Accion 1280
# Observación [-0.5326134  -0.00150105]
# Accion 1290
# Observación [-0.55499065 -0.00222536]
# Accion 1300
# Observación [-5.7697344e-01  3.2465603e-05]
# Accion 1310
# Observación [-0.5514613   0.00666441]
# Accion 1320
# Observación [-0.47007585  0.01011853]
# Accion 1330
# Observación [-0.40926132  0.00372229]
# Accion 1340
# Observación [-0.42375115 -0.00565446]
# Accion 1350
# Observación [-0.50193727 -0.00976453]
# Accion 1360
# Observación [-0.6125328  -0.01060601]
# Accion 1370
# Observación [-0.6577352   0.00212313]
# Accion 1380
# Observación [-0.5782183   0.01192502]
# Accion 1390
# Observación [-0.45751566  0.00987901]
# Accion 1400
# Observación [-0.39245138  0.0022581 ]
# Accion 1410
# Observación [-0.41841248 -0.00485612]
# Accion 1420
# Observación [-0.50627494 -0.00893731]
# Accion 1430
# Observación [-0.57929134 -0.00447322]
# Accion 1440
# Observación [-0.57617277  0.00405005]
# Accion 1450
# Observación [-0.49244872  0.00828556]
# Accion 1460
# Observación [-0.4247604   0.00669941]
# Accion 1470
# Observación [-0.4197086  -0.00338789]
# Accion 1480
# Observación [-0.47968027 -0.00951262]
# Accion 1490
# Observación [-0.58996755 -0.01018409]
# Accion 1500
# Observación [-0.6573592 -0.0036192]
# Accion 1510
# Observación [-0.6386015   0.00502714]
# Accion 1520
# Observación [-0.5484903  0.0109498]
# Accion 1530
# Observación [-0.43074635  0.00750402]
# Accion 1540
# Observación [-0.3928178   0.00086665]
# Accion 1550
# Observación [-0.44311547 -0.00871065]
# Accion 1560
# Observación [-0.5625472  -0.00964441]
# Accion 1570
# Observación [-0.62018156 -0.0024622 ]
# Accion 1580
# Observación [-0.6014654   0.00552652]
# Accion 1590
# Observación [-0.51178694  0.00838799]
# Accion 1600
# Observación [-0.46576747  0.00150323]
# Accion 1610
# Observación [-4.5743188e-01 -2.6133543e-04]
# Accion 1620
# Observación [-0.48698214 -0.00446173]
# Accion 1630
# Observación [-0.53136194 -0.00353294]
# Accion 1640
# Observación [-0.5648653  -0.00272339]
# Accion 1650
# Observación [-0.5417229   0.00723878]
# Accion 1660
# Observación [-0.49484435  0.00277848]
# Accion 1670
# Observación [-4.8915654e-01  3.3637887e-04]
# Accion 1680
# Observación [-0.49425074 -0.00347687]
# Accion 1690
# Observación [-0.5278873  -0.00130463]
# Accion 1700
# Observación [-0.563136   -0.00404628]
# Accion 1710
# Observación [-0.59836096 -0.00075341]
# Accion 1720
# Observación [-0.55922085  0.00484887]
# Accion 1730
# Observación [-0.5056907   0.00350565]
# Accion 1740
# Observación [-0.47701335  0.00312265]
# Accion 1750
# Observación [-0.47999272 -0.00373579]
# Accion 1760
# Observación [-0.52558094 -0.00665343]
# Accion 1770
# Observación [-0.61038727 -0.00550382]
# Accion 1780
# Observación [-0.6053048   0.00219658]
# Accion 1790
# Observación [-0.5593561   0.00598087]
# Accion 1800
# Observación [-0.5058134   0.00476125]
# Accion 1810
# Observación [-0.49715802 -0.00338646]
# Accion 1820
# Observación [-0.5142447  -0.00168269]
# Accion 1830
# Observación [-5.1928663e-01 -1.9558547e-04]
# Accion 1840
# Observación [-5.156424e-01  3.433644e-04]
# Accion 1850
# Observación [-0.503437   -0.00080007]
# Accion 1860
# Observación [-0.54064226 -0.00536485]
# Accion 1870
# Observación [-0.6002793  -0.00408995]
# Accion 1880
# Observación [-0.6138836   0.00150289]
# Accion 1890
# Observación [-0.56279624  0.0078107 ]
# Accion 1900
# Observación [-0.4877305   0.00723353]
# Accion 1910
# Observación [-0.43109766  0.00343465]
# Accion 1920
# Observación [-0.40443593  0.00052548]
# Accion 1930
# Observación [-0.46665242 -0.01198111]
# Accion 1940
# Observación [-0.56876093 -0.00869518]
# Accion 1950
# Observación [-0.62719786 -0.00198973]
# Accion 1960
# Observación [-0.589699    0.00697123]
# Accion 1970
# Observación [-0.50938857  0.00824528]
# Accion 1980
# Observación [-0.43236443  0.00435552]
# Accion 1990
# Observación [-4.1976476e-01 -3.3410688e-05]
# Accion 2000
# Observación [-0.45057875 -0.00388875]
# Accion 2010
# Observación [-0.49815443 -0.00485604]
# Accion 2020
# Observación [-0.5781139  -0.00821347]
# Accion 2030
# Observación [-0.64007556 -0.00281169]
# Accion 2040
# Observación [-0.61771363  0.00663363]
# Accion 2050
# Observación [-0.5384996   0.01021743]
# Accion 2060
# Observación [-0.4106177   0.01207514]
# Accion 2070
# Observación [-0.3590932  -0.00055607]
# Accion 2080
# Observación [-0.4098338  -0.00820326]
# Accion 2090
# Observación [-0.5223739  -0.01427039]
# Accion 2100
# Observación [-0.65295935 -0.00966686]
# Accion 2110
# Observación [-0.7012834  -0.00134737]
# Accion 2120
# Observación [-0.6476697   0.00934243]
# Accion 2130
# Observación [-0.52346003  0.01248179]
# Accion 2140
# Observación [-0.3841158   0.01173935]
# Accion 2150
# Observación [-0.33663568 -0.00161732]
# Accion 2160
# Observación [-0.4202247  -0.01306645]
# Accion 2170
# Observación [-0.57821655 -0.01673017]
# Accion 2180
# Observación [-0.7175429  -0.00771033]
# Accion 2190
# Observación [-0.70256895  0.01063967]
# Accion 2200
# Observación [-0.5503227   0.01804674]
# Accion 2210
# Observación [-0.38245192  0.01201564]
# Accion 2220
# Observación [-0.30891377  0.00194485]
# Accion 2230
# Observación [-0.36784047 -0.01318781]
# Accion 2240
# Observación [-0.5222391  -0.01457291]
# Accion 2250
# Observación [-0.666302   -0.01275925]
# Accion 2260
# Observación [-0.7100621   0.00392454]
# Accion 2270
# Observación [-0.60920507  0.01488131]
# Accion 2280
# Observación [-0.4684504   0.01014581]
# Accion 2290
# Observación [-0.39261514  0.00516625]
# Accion 2300
# Observación [-0.40275168 -0.00676357]
# Accion 2310
# Observación [-0.49928063 -0.01078454]
# Accion 2320
# Observación [-0.6003877  -0.00912969]
# Accion 2330
# Observación [-0.6484588  -0.00142044]
# Accion 2340
# Observación [-0.6400671   0.00474814]
# Accion 2350
# Observación [-0.5486958   0.01184432]
# Accion 2360
# Observación [-0.41988254  0.01253861]
# Accion 2370
# Observación [-0.36160928  0.00039866]
# Accion 2380
# Observación [-0.39599437 -0.00664023]
# Accion 2390
# Observación [-0.5137345  -0.01228956]
# Accion 2400
# Observación [-0.6404429  -0.01063671]
# Accion 2410
# Observación [-0.68277746  0.0030702 ]
# Accion 2420
# Observación [-0.5980861   0.01360634]
# Accion 2430
# Observación [-0.42876118  0.01553073]
# Accion 2440
# Observación [-0.3176205   0.00667527]
# Accion 2450
# Observación [-0.32816    -0.00827681]
# Accion 2460
# Observación [-0.4830018  -0.02120672]
# Accion 2470
# Observación [-0.6812862  -0.01618696]
# Accion 2480
# Observación [-0.73883295  0.00175355]
# Accion 2490
# Observación [-0.6418011   0.01476691]
# Accion 2500
# Observación [-0.47773075  0.01730579]
# Accion 2510
# Observación [-0.3476557   0.01020084]
# Accion 2520
# Observación [-0.3056427 -0.0032857]
# Accion 2530
# Observación [-0.42462966 -0.0178369 ]
# Accion 2540
# Observación [-0.594571   -0.01530423]
# Accion 2550
# Observación [-0.69202995 -0.00429001]
# Accion 2560
# Observación [-0.66169554  0.00648072]
# Accion 2570
# Observación [-0.54524463  0.01536866]
# Accion 2580
# Observación [-0.37301818  0.01617573]
# Accion 2590
# Observación [-0.284095    0.00084266]
# Accion 2600
# Observación [-0.35863557 -0.01336098]
# Accion 2610
# Observación [-0.53189164 -0.0201815 ]
# Accion 2620
# Observación [-0.72443825 -0.01693725]
# Accion 2630
# Observación [-0.8200171 -0.0037703]
# Accion 2640
# Observación [-0.7522341   0.01698468]
# Accion 2650
# Observación [-0.53422034  0.02479036]
# Accion 2660
# Observación [-0.33788586  0.01431628]
# Accion 2670
# Observación [-0.2751836   0.00071187]
# Accion 2680
# Observación [-0.36432552 -0.0157804 ]
# Accion 2690
# Observación [-0.5805883  -0.02277175]
# Accion 2700
# Observación [-0.76025015 -0.01435079]
# Accion 2710
# Observación [-0.81976473  0.00218122]
# Accion 2720
# Observación [-0.7149714   0.01673953]
# Accion 2730
# Observación [-0.4991677   0.02295943]
# Accion 2740
# Observación [-0.3074636   0.01316467]
# Accion 2750
# Observación [-0.22804123  0.00251741]
# Accion 2760
# Observación [-0.34624922 -0.02000266]
# Accion 2770
# Observación [-0.58217305 -0.02441094]
# Accion 2780
# Observación [-0.7742923 -0.0123058]
# Accion 2790
# Observación [-0.78959125  0.00600263]
# Accion 2800
# Observación [-0.6424099   0.01973287]
# Accion 2810
# Observación [-0.41975862  0.02213971]
# Accion 2820
# Observación [-0.2924538   0.00248588]
# Accion 2830
# Observación [-0.3462173  -0.01183299]
# Accion 2840
# Observación [-0.53847295 -0.0252961 ]
# Accion 2850
# Observación [-0.75749415 -0.01761256]
# Accion 2860
# Observación [-8.464273e-01 -6.615908e-04]
# Accion 2870
# Observación [-0.7317309   0.02126247]
# Accion 2880
# Observación [-0.48790202  0.02552442]
# Accion 2890
# Observación [-0.3025858   0.01106977]
# Accion 2900
# Observación [-0.2915913  -0.00861407]
# Accion 2910
# Observación [-0.441315   -0.01891576]
# Accion 2920
# Observación [-0.6008351  -0.01335313]
# Accion 2930
# Observación [-6.710009e-01 -6.332339e-04]
# Accion 2940
# Observación [-0.6233807   0.00927868]
# Accion 2950
# Observación [-0.49762514  0.01377511]
# Accion 2960
# Observación [-0.397859    0.00505917]
# Accion 2970
# Observación [-0.39754584 -0.00588814]
# Accion 2980
# Observación [-0.47713473 -0.00983766]
# Accion 2990
# Observación [-0.57498705 -0.00991287]
# Accion 3000
# Observación [-0.6606786  -0.00502912]
# Accion 3010
# Observación [-0.6879635   0.00222648]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 12
#      10     print("Observación", observation)
#      11 # Visualizar ejercicio
# ---> 12 env.render()
#      13 # Print del estado
#      14 # print(observation)
#      15 # Guarda en la variable action una de las acciones posibles elegida al azar
#      16 action = env.action_space.sample()
#
# File ~/The_Bridge/2026-02-DS-FT-BIL/2026-02-BILBAO-FT-Data-Science/.venv/lib/python3.11/site-packages/gymnasium/core.py:337, in Wrapper.render(self)
#     335 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     336     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 337     return self.env.render()
#
# File ~/The_Bridge/2026-02-DS-FT-BIL/2026-02-BILBAO-FT-Data-Science/.venv/lib/python3.11/site-packages/gymnasium/wrappers/common.py:408, in OrderEnforcing.render(self)
#     403 if not self._disable_render_order_enforcing and not self._has_reset:
#     404     raise ResetNeeded(
#     405         "Cannot call `env.render()` before calling `env.reset()`, if this is an intended action, "
#     406         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#     407     )
# --> 408 return super().render()
#
# File ~/The_Bridge/2026-02-DS-FT-BIL/2026-02-BILBAO-FT-Data-Science/.venv/lib/python3.11/site-packages/gymnasium/core.py:337, in Wrapper.render(self)
#     335 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     336     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 337     return self.env.render()
#
# File ~/The_Bridge/2026-02-DS-FT-BIL/2026-02-BILBAO-FT-Data-Science/.venv/lib/python3.11/site-packages/gymnasium/wrappers/common.py:302, in PassiveEnvChecker.render(self)
#     300     return env_render_passive_checker(self.env)
#     301 else:
# --> 302     return self.env.render()
#
# File ~/The_Bridge/2026-02-DS-FT-BIL/2026-02-BILBAO-FT-Data-Science/.venv/lib/python3.11/site-packages/gymnasium/envs/classic_control/mountain_car.py:271, in MountainCarEnv.render(self)
#     269 if self.render_mode == "human":
#     270     pygame.event.pump()
# --> 271     self.clock.tick(self.metadata["render_fps"])
#     272     pygame.display.flip()
#     274 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:

# %%
gym.__version__
# Out:
# '1.2.3'
