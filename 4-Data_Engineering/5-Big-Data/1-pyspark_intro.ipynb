# %% [markdown]
# # Pyspark Basic Introduction

# %% [markdown]
# ## Instalamos pyspark

# %%
# %pip install pyspark

# %% [markdown]
# ## Importamos pyspark

# %%
import pyspark
import pandas as pd

# %%
from pyspark.sql import SparkSession

# %% [markdown]
# El módulo .sql proporciona una clase llamada SparkSession, que es una entrada principal para trabajar con SQL en Spark. A través de SparkSession, puedes realizar varias tareas SQL en Spark:

# %% [markdown]
#     · Ejecución de Consultas SQL: selecciones, filtraciones, agregaciones y otras operaciones SQL en tus datos distribuidos.
#     · Creación de Tablas Temporales
#     · Lectura y Escritura de Datos

# %% [markdown]
# Leemos el archivo `test.csv`

# %%
type(pd.read_csv('./data/test1.csv'))
# Out:
# pandas.DataFrame

# %% [markdown]
# ### Vamos a crear una sesión.
# Esto nos da acceso a la API de DataFrame y Dataset, que básicamente nos sirve para ejecutar las distintas acciones y transformaciones sobre nuestros datos.

# %% [markdown]
# #### **Importante**: es necesario tener instalado JAVA 8 o superior para el funcionamiento de PySpark.
# 1. Instalar (https://www.java.com/es/download/ie_manual.jsp)
# 2. Reiniciar PC
# 3. Correr la celda y permitir cambios como administrador

# %%
spark = SparkSession.builder.appName('Practise').getOrCreate() # Inicia sesión para poder utilizar los comandos de spark
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 spark = SparkSession.builder.appName('Practise').getOrCreate() # Inicia sesión para poder utilizar los comandos de spark
#
# File c:\Users\urkow\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\sql\session.py:557, in SparkSession.Builder.getOrCreate(self)
#     555     sparkConf.set(key, value)
#     556 # This SparkContext may be an existing one.
# --> 557 sc = SparkContext.getOrCreate(sparkConf)
#     558 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     559 # by all sessions.
#     560 session = SparkSession(sc, options=self._options)
#
# File c:\Users\urkow\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\core\context.py:542, in SparkContext.getOrCreate(cls, conf)
#     540 with SparkContext._lock:
#     541     if SparkContext._active_spark_context is None:
# --> 542         SparkContext(conf=conf or SparkConf())
#     543     assert SparkContext._active_spark_context is not None
#     544     return SparkContext._active_spark_context
#
# File c:\Users\urkow\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\core\context.py:206, in SparkContext.__init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls, udf_profiler_cls, memory_profiler_cls)
#     200 if gateway is not None and gateway.gateway_parameters.auth_token is None:
#     201     raise ValueError(
#     202         "You are trying to pass an insecure Py4j gateway to Spark. This"
#     203         " is not allowed as it is a security risk."
#     204     )
# --> 206 SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     207 try:
#     208     self._do_init(
#     209         master,
#     210         appName,
#    (...)    220         memory_profiler_cls,
#     221     )
#
# File c:\Users\urkow\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\core\context.py:463, in SparkContext._ensure_initialized(cls, instance, gateway, conf)
#     461 with SparkContext._lock:
#     462     if not SparkContext._gateway:
# --> 463         SparkContext._gateway = gateway or launch_gateway(conf)
#     464         SparkContext._jvm = SparkContext._gateway.jvm
#     466     if instance:
#
# File c:\Users\urkow\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\java_gateway.py:108, in launch_gateway(conf, popen_kwargs)
#     106 # Wait for the file to appear, or for the process to exit, whichever happens first.
#     107 while not proc.poll() and not os.path.isfile(conn_info_file):
# --> 108     time.sleep(0.1)
#     110 if not os.path.isfile(conn_info_file):
#     111     raise PySparkRuntimeError(
#     112         errorClass="JAVA_GATEWAY_EXITED",
#     113         messageParameters={},
#     114     )
#
# KeyboardInterrupt:

# %% [markdown]
# Visualizamos la sesión

# %%
spark

# %% [markdown]
# Ahora vamos a leer `test.csv` a través de Spark

# %%
df_pyspark = spark.read.csv('data/test1.csv')

# %% [markdown]
# Ahora vamos a leer `test.csv` a través de Spark

# %%
df_pyspark.show()

# %% [markdown]
# Si nos fijamos, nos está mostrando nombres raros en las columnas y además la primera fila la componen los nombres de las columnas.
#
# Para evitar eso, necesitamos poner unos argumentos para evitarlo

# %%
df_pyspark = spark.read.option('header', 'true').csv('data/test1.csv')

# %%
df_pyspark.show()

# %%
df_pyspark = spark.read.csv('data/test1.csv', header=True)

# %%
df_pyspark.show()

# %% [markdown]
# Vemos el tipo de objeto que es

# %%
type(df_pyspark)

# %% [markdown]
# Vemos la información de las columnas

# %%
df_pyspark.printSchema()
