# %%
import def_ejercicio_1_1 as gh

# %%
import pandas as pd

# %%
gh.week_day(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 week_day(3)
#
# NameError: name 'week_day' is not defined
