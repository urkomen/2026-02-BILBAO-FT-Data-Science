# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics I

# %% [markdown]
# ## Ejercicio 0
# Imprime por pantalla esta cita con el siguiente formato
#
# ![imagen](./img/frase_Einstein.PNG)

# %%
print('¿Por qué esta magnífica tecnología científica,' 
      '\n\t que ahorra trabajo y nos hace la vida más fácil,' 
      '\n\t\t nos aporta tan poca felicidad?'
      '\n\t\t\t La respuesta es esta, simplemente: porque aún no hemos aprendido a usarla con tino.'
      '\n "Albert Einstein"')
# Out:
# ¿Por qué esta magnífica tecnología científica,
# 	 que ahorra trabajo y nos hace la vida más fácil,
# 		 nos aporta tan poca felicidad?
# 			 La respuesta es esta, simplemente: porque aún no hemos aprendido a usarla con tino.
#  "Albert Einstein"

# %% [markdown]
# ## Ejercicio 1
# 1. Escribe el nombre de la calle de tu domicilio en una variable
# 2. Escribe el numero de la calle en otra
# 3. Ciudad en una tercera
# 4. Codigo postal en la cuarta variable
# 5. Imprime las 4 variables concatenadas por pantalla
# 6. Crea una quinta variable que concatene todas ellas
# 7. Imprímela por pantalla

# %%
domic = 'Calle de la Alegría'
num = 42
ciudad = 'Bilbao'
codPostal = 48001
print(domic, num, ciudad, codPostal)
direccion = domic + ' ' + str(num) + ', ' + ciudad + ' ' + str(codPostal)
print(direccion)
# Out:
# Calle de la Alegría 42 Bilbao 48001
# Calle de la Alegría 42, Bilbao 48001

# %% [markdown]
# ## Ejercicio 2
# Repite el ejercicio 1, pero pidiendo estos datos al usuario mediante un input(), imprimiendo a continuación la dirección completa

# %%
domic = input('Introduce tu calle: ')
num = input('Introduce el número de la calle: ')
ciudad = input('Introduce la ciudad: ')
codPostal = input('¿Cuál es el código postal?')
print(domic, num, ciudad, codPostal)
direccion = domic + ' ' + str(num) + ', ' + ciudad + ' ' + str(codPostal)
print(direccion)
# Out:
# Mandarinas azules 43 Bilbao 48001
# Mandarinas azules 43, Bilbao 48001

# %% [markdown]
# ## Ejercicio 3
# ¿Qué variables están mal escritas y por qué? Realiza primero tu hipótesis y luego ejecuta las variables para comprobarlo. En ese orden :)
#
#
# 1. mi_variable = "Economía"
# 2. otra_var = "Ejercicio
# 3. True = "Ejercicio"
# 4. mi variab1e = "Alpha"
# 5. import = 40
# 6. 81mi_variable = "Agua"
# 7. mi_variable10 = 6

# %% [markdown]
# 2. Falta comillas de cierre al darle valor a la variable
# 3. *True* es una palabra reservada, no se puede usar como variable. Además, no deben comenzar con mayúsculas
# 4. Los nombres de las variables no pueden contener espacios
# 5. *Import* es una palabra reservada, no se puede usar como variable
# 6. Los nombres de las variables no pueden comenzar con números

# %%
mi_variable = "Economía"
print(mi_variable)
# Out:
# Economía

# %%
otra_var = "Ejercicio
print(otra_var)
# Out:
#   Cell In[6], line 1
#     otra_var = "Ejercicio
#                ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
True = "Ejercicio"
print(True)
# Out:
#   Cell In[7], line 1
#     True = "Ejercicio"
#     ^
# SyntaxError: cannot assign to True

# %%
mi variab1e = "Alpha"
print(mi variab1e)
# Out:
#   Cell In[8], line 1
#     mi variab1e = "Alpha"
#        ^
# SyntaxError: invalid syntax

# %%
import = 40
print(import)
# Out:
#   Cell In[9], line 1
#     import = 40
#            ^
# SyntaxError: invalid syntax

# %%
81mi_variable = "Agua"
print(81mi_variable)
# Out:
#   Cell In[10], line 1
#     81mi_variable = "Agua"
#      ^
# SyntaxError: invalid decimal literal

# %%
mi_variable10 = 6
print(mi_variable10)
# Out:
# 6

# %% [markdown]
# ## Ejercicio 4
# Realiza un conversor de grados Celsius a Fahrenheit. El conversor tiene que recibir el input del usuario y devolver la conversión.
#
# La conversión de grados sigue la siguiente fórmula: F = C × (9 / 5) + 32

# %%
print('Vamos a convertir temperaturas de Celsius a Fahrenheit')
temp_celsius = float(input('Introduce la temperatura en grados Celsius: '))
temp_fahrenheit = (temp_celsius * 9/5) + 32
print(f'{temp_celsius}ºC son {temp_fahrenheit}ºF.')
# Out:
# Vamos a convertir temperaturas de Celsius a Fahrenheit
# 15.0ºC son 59.0ºF.

# %% [markdown]
# ## Ejercicio 5
# Comenta  el Ejercicio 4. Pon un comentario multilinea y haz comentarios de cada linea de código

# %%
'''
Mostramos mensaje de explicación del programa.
Pedimos al usuario que nos proporciones la temperatura en grados Celius
'''
print('Vamos a convertir temperaturas de Celsius a Fahrenheit')
temp_celsius = float(input('Introduce la temperatura en grados Celsius: '))
temp_fahrenheit = (temp_celsius * 9/5) + 32 # Calculamos la temperatura en grados Farenheit a partir del valor introducido
# Devolvemos el resultado de una manera bonita
print(f'{temp_celsius}ºC son {temp_fahrenheit}ºF.')
# Out:
# Vamos a convertir temperaturas de Celsius a Fahrenheit
# 2300.0ºC son 4172.0ºF.
