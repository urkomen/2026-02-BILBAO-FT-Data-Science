# %%
import Tablero

# %%
coords = ['A1','j5']
indice = [Tablero.coords2index(coord) for coord in coords]
print(indice)
# Out:
# [[0, 0], [9, 4]]

# %%
def coords2index(coord: str):
    """
    Convierte una coordenada tipo 'A5' en índices [fila, columna].
    A -> 0, B -> 1, ..., J -> 9
    1 -> 0, 2 -> 1, ..., 10 -> 9
    """
    coord = coord.strip().lower()

    fila = coord[0]          # 'a'
    col = coord[1:]          # '5' o '10'

    fila_idx = ord(fila) - ord('a') # Convertimos a unicode y restamos con nuestro valor '0'
    col_idx = int(col) - 1

    return [fila_idx, col_idx]

# %%
coords2index('Z1')
# Out:
# [25, 0]

# %%
casillas = [(2,3), (3,3), (1,3), (2,2), (2,10), (30,6)]
for casilla in casillas:
        for ind in casilla:
            if ind > 9:
                print('error')
# Out:
# error
# error

# %%
import Tablero
import Barcos
import Fases_del_juego as fdj

# %%
tablero = fdj.inicio_hundir()
    
fdj.configuracion_hundir(tablero)
# Out:
# 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦
# 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦
# 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦
# 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦
# 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦
# 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦
# 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦
# 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦
# 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦
# 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦 🟦
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 tablero = fdj.inicio_hundir()
# ----> 3 fdj.configuracion_hundir(tablero)
#
# File c:\Users\urkow\Documents\Documentos_Clase\2026-02-BILBAO-FT-Data-Science\1-RampUp\9-Hundir la flota\Proyecto\Fases_del_juego.py:39, in configuracion_hundir(tablero)
#      28 '''
#      29 CONFIGURACIÓN
#      30     - Se colocan los barcos del usuario (modo manual)
#    (...)     34       1 barco de 4 casillas
#      35 '''
#      38 coords = ['A1','B1']
# ---> 39 Barcos.colocar_barcos(1, coords, tablero)
#      40 Tablero.mostrar_tablero(tablero)
#
# TypeError: colocar_barcos() takes from 0 to 1 positional arguments but 3 were given
