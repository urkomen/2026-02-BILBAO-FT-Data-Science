# %% [markdown]
# # Extrae los dominios de los correos con una expresión regular

# %%
import re

emails = '''
miguellc@thebridgeschool.tech
miguel.cruz@uc3m.es
miguel-12-2000@mi-correo.net
miguellc@s@thebridgeschool.es
'''

# %% [markdown]
# Ejemplo:
# * @thebridgeschool.tech
# * @uc3m.es
# * @mi-correo.net
# * @thebridgeschool.es

# %%
pattern = re.compile(r'@[^@]+$') # Serie de caracteres que comienza por @ y no contiene más @ hasta el final (por el último caso)

# Separamos líneas y ejecutamos filtro
for line in emails.splitlines():
    match = pattern.search(line)
    if match:
        print(match.group())
# Out:
# @thebridgeschool.tech
# @uc3m.es
# @mi-correo.net
# @thebridgeschool.es
