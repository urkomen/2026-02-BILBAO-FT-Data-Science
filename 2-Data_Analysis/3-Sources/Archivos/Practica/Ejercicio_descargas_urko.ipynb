# %% [markdown]
# ## Ejercicio descargas

# %% [markdown]
# Python es un lenguaje de propósito general, por lo que podemos desarrollar otros programas,
# aparte de ciencia de datos, que nos permitan montar dashboards, crear APIs o automatizar
# procesos. En este caso vas a automatizar un proceso, en el que tendrás que desarrollar un
# script que ordene todos los archivos de una carpeta, dependiendo de la extensión de los
# mismos.
#
#
# El objetivo es ordenar la típica carpeta de cajón desastre donde se nos acumulan archivos de
# todos los formatos como: imágenes, words, presentaciones, excels, ejecutables, zips, etc... Y
# que no vamos a ir viendo archivo a archivo, ordenándolos.... La solución suele ser eliminarlo
# todo. Vamos a intentar no tener que llegar a eso, ordenando los ficheros automáticamente en
# carpetas y revisar las que nos interesen. La típica carpeta donde aplicaríamos este programa es
# la de “Descargas”, donde se suelen acumular muchos archivos temporales.
#
#
# Por tanto, **el programa tiene que guardar los archivos de la carpeta “Descargas” (o cualquier
# otra donde acumules mucho archivo temporal) en los siguientes directorios dentro de la
# propia carpeta “Descargas”**:
# - Imagenes
# - Documentos
# - Software
# - Otros
#
# Cada vez que ejecutes el script, automáticamente se ordenarán todos los archivos en sus
# correspondientes carpetas.

# %%
doc_types = ('.doc', '.docx', '.txt', '.pdf', '.xls', '.ppt', '.xlsx', '.pptx')
img_types = ('.jpg', '.jpeg', '.png', '.svg', '.gif')
software_types = ('.exe', '.py','.ipynb')
ruta_desc = 'C:/Users/urkow/Downloads/archivos_mover/'
ruta_ordenados = 'C:/Users/urkow/Downloads/Sort'
img = '/imagenes/'
doc = '/documentos/'
soft = '/software/'
otros = '/otros/'

# %% [markdown]
# ### 1. Crea un un programa con el flujo principal y encapsúlalo en funciones.

# %%
import os
import shutil

# %%
# buscar archivos por tipo
# moverlos al directorio sort (copiar y borrar?)

# %%
os.listdir(ruta_desc)
# Out:
# ['1_Naked Statistics_ Stripping the Dread from the Data - charles Wheelan.epub',
#  '2026_ELEVATOR PITCH.pdf',
#  '2_Data Science for Business - Foster Provost & Tom Fawcett.epub',
#  '3_Python for Data Analysis - Wes McKinney.pdf',
#  '4_Python Data Science Handbook - Jake VanderPlas.epub',
#  '5_Ciencia de datos desde cero - Joel Grus.pdf',
#  '7_Hands-On Machine Learning with Scikit-Learn and TensorFlow - Aurélien Géron.pdf',
#  '8_Deep Learning with Python - François Chollet.epub',
#  'Ejercicios_Clases_Objetos.ipynb',
#  'Ejercicios_Colecciones.ipynb',
#  'ejercicios_Seaborn.ipynb',
#  'ejercicios_Seaborn_Danillo.ipynb',
#  'Ejercicio_descargas.ipynb',
#  'ELEVATOR PITCH Pieza_Tu_Puzle_Profesional.mp4',
#  'Estadistica-practica-para-ciencia-de-datos-con-R-y-Python.pdf',
#  'exoplanets - copia.ipynb',
#  'nuevo1.txt',
#  'Postman (x64).exe',
#  'python-3.11.9-amd64.exe',
#  'Python_Fundamentals.png',
#  'Reader_es_install.exe',
#  'README.md']

# %%
# Crear carpetas destino si no existen
for j in ["Documentos", "Imágenes", "Software", "Otros"]:
    os.makedirs(os.path.join(ruta_ordenados, '/', j), exist_ok=True) 
    # con .makedirs y exist_ok=True, evitamos que cree las carpetas si ya existen
    # con os.path.join suma mi carpeta_descargas con j para crear la nueva ruta

# %%
for i in os.listdir(ruta_desc):
    if i.endswith(img_types): # Quedarnos los que terminan en '.jpg', '.jpeg', '.png', '.svg', '.gif'
        shutil.copy(ruta_desc + i, ruta_ordenados + img)
        os.remove(ruta_desc + i)
        
    elif i.endswith(software_types): # Quedarnos los que terminan en '.exe', '.py','.ipynb'
        shutil.copy(ruta_desc + i, ruta_ordenados + soft)
        os.remove(ruta_desc + i)
        
    elif i.endswith(doc_types): # Quedarnos los que terminan en '.doc', '.docx', '.txt', '.pdf', '.xls', '.ppt', '.xlsx', '.pptx'
        shutil.copy(ruta_desc + i, ruta_ordenados + doc)
        os.remove(ruta_desc + i)
        
    else: # Quedarnos el resto de archivos
        shutil.copy(ruta_desc + i, ruta_ordenados + otros)
        os.remove(ruta_desc + i)

# %% [markdown]
# ### 2. Crea un programa standalone (main.py, funciones.py, variables.py) que realice la tarea sin necesidad de Jupyter notebooks.
