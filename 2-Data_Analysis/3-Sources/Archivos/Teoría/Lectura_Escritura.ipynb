# %% [markdown]
# ![imagen](./img/python.jpg)
#
# # Lectura Escritura
#
# En este módulo vas a ver diferentes maneras de leer y escribir datos desde archivos locales. Rara vez trabajarás únicamente con los datos que genere tu programa de Python, sino que lo normal será acudir a una fuente de datos, o leer de algún archivo.
#
# 1. [Archivos](#1.-Archivos)
# 2. [Abrir ficheros](#2.-Abrir-ficheros)
# 3. [CSV](#3.-CSV)
# 4. [Excel](#4.-Excel)
# 5. [JSON](#5.-JSON)
# 6. [TXT](#6.-TXT)
# 7. [ZIP](#7.-ZIP)
# 8. [pickle](#8.-pickle)
# 9. [Encoding](#9.-Encoding)
# 10. [Archivos y carpetas](#10.-Archivos-y-carpetas)

# %% [markdown]
# ## 1. Archivos
# Antes de ir a leer o escribir archivos, es importante saber exáctamente qué es un archivo. **Un archivo es un conjunto de datos almacenados en el ordenador en forma de bits.** Los datos se organizan en un formato específico, pudiendo ser un archivo de texto, un ejecutable... pero en el fondo todos esos archivos se traducen a nivel binario para el procesado del ordenador. Los archivos se componen de:
#
# 1. **Header**: metadatos del archivo (nombre, tamaño, tipo...)
# 2. **Data**: contenido del archivo
# 3. **End of file (EOF)**: caracter especial que indica el final del archivo.
#
# ![imagen](./img/file.png)
#
# #### File path
# Hay tres elementos que tenemos que conocer cuando leamos un archivo:
# 1. **Folder path**: en que lugar del ordenador está el archivo. Y no solo eso, si no en qué directorio está apuntando el programa de Python.
# 2. **File name**
# 3. **Extension**: lo que va después del punto
#
# Fíjate en la siguiente imagen:
#
# ![imagen](./img/path.png)
#
# * Si estamos trabajando en el directorio *to*, accederemos a *cats.gif* como `cats.gif`
# * Si queremos leer *dog_breeds.txt*, hay que ir un directorio hacia atrás, `../dog_breeds.txt`
# * Y si queremos acceder a `animals.csv`, son dos directorios hacia atrás: `../../animals.csv`
#
# Siempre podemos poner la ruta absoluta (`C/Users/usuario/Archivos/Bootcamp/Python/animals.csv`) para el acceso a cada archivo, **aunque no es lo recomendable**.
#
# [Buena guía para iniciarse en la lectura/escritura de archivos con Python.](https://realpython.com/read-write-files-python/)

# %% [markdown]
# ## 2. Abrir ficheros
# A lo largo de este notebook verás diferentes funciones para leer archivos, en función de la extensión cada uno. Estas funciones provienen de otras librerías y nos facilitan mucho la vida a la hora de leer o escribir archivos. No obstante, Python tiene sus propias funciones *built-in*, con las que no es necesario utilizar otros paquetes.
#
# Para ello **usaremos la función `open`**, que devuelve un objeto de tipo `File`, con unos métodos y atributos propios empleados para obtener información de los archivos abiertos. `open` sigue la siguiente sitaxis:
#
# ```Python
# file_object  = open("filename", "mode")
# ```
#
# El primer argumento es el nombre del archivo, mientras que en el modo tendremos que especificar si queremos leer, o escribir. Por defecto leerá, es decir, el parámetro valdrá *r*, de read. [Te dejo el enlace a la documentación para consultar el resto de modos](https://docs.python.org/3/library/functions.html#open).
#
# Vamos a probar a leer un archivo. La siguiente sintaxis de línea se utiliza porque en algún momento se tiene que cerrar el archivo. Se abre, leemos, realizamos operaciones, y cuando acaba el `with open()`, se cierra el archivo. **Leer y escribir mientras los archivos están abiertos nos dará errores**.

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\urkow\\Documents\\Documentos_Clase\\2026-02-BILBAO-FT-Data-Science\\2-Data_Analysis\\3-Sources\\Archivos\\Teoría'

# %%
with open('./data/dog_breeds.txt', 'r') as open_file:
    all_text = open_file.read()
    print(type(all_text))
    print(all_text)
# Out:
# <class 'str'>
# Pug
# Jack Russell Terrier
# English Springer Spaniel
# German Shepherd
# Staffordshire Bull Terrier
# Cavalier King Charles Spaniel
# Golden Retriever
# West Highland White Terrier
# Boxer
# Border Terrier

# %% [markdown]
# El método `.read()` nos devuelve un string con todo el texto, que no es lo ideal para tratar luego los datos.
#
# En el siguiente ejemplo vemos como también lo leemos, pero en este caso cada línea la guarda en una lista.

# %%
with open('data/dog_breeds.txt', 'r') as open_file:
    all_text = open_file.readlines()
    print(type(all_text))
    print(all_text)
# Out:
# <class 'list'>
# ['Pug\n', 'Jack Russell Terrier\n', 'English Springer Spaniel\n', 'German Shepherd\n', 'Staffordshire Bull Terrier\n', 'Cavalier King Charles Spaniel\n', 'Golden Retriever\n', 'West Highland White Terrier\n', 'Boxer\n', 'Border Terrier']

# %%
import pprint
pprint.pprint(all_text)
# Out:
# ['Pug\n',
#  'Jack Russell Terrier\n',
#  'English Springer Spaniel\n',
#  'German Shepherd\n',
#  'Staffordshire Bull Terrier\n',
#  'Cavalier King Charles Spaniel\n',
#  'Golden Retriever\n',
#  'West Highland White Terrier\n',
#  'Boxer\n',
#  'Border Terrier']

# %%
with open('data/dog_breeds.txt', 'r') as open_file:
    for line in open_file.readlines():
        print(line, end = '')
  
print('Fin')
# Out:
# Pug
# Jack Russell Terrier
# English Springer Spaniel
# German Shepherd
# Staffordshire Bull Terrier
# Cavalier King Charles Spaniel
# Golden Retriever
# West Highland White Terrier
# Boxer
# Border TerrierFin

# %%
with open('data/dog_breeds.txt', 'r') as reader:
    # Read and print the entire file line by line
    for line in reader:
        print(line, end='')
# Out:
# Pug
# Jack Russell Terrier
# English Springer Spaniel
# German Shepherd
# Staffordshire Bull Terrier
# Cavalier King Charles Spaniel
# Golden Retriever
# West Highland White Terrier
# Boxer
# Border Terrier

# %% [markdown]
# Si queremos escribir

# %%
with open('data/preguntas.py', 'w') as new_file:
    new_file.write("print(\"Hola mundo\")\n")
    new_file.write("#Esto se crea?\n")
    new_file.write("#Segunda linea\n")
    new_file.write("#Tercera linea\n")
    print("Ya se ha escrito")
# Out:
# Ya se ha escrito

# %%
with open("data/preguntas.py", "r") as new_file:
    linea = new_file.readline()
    print(linea)
    print(new_file.readline())
    print(new_file.readline())
# Out:
# print("Hola mundo")
#
# #Esto se crea?
#
# #Segunda linea

# %% [markdown]
# Opción "w" para escribir. Si no existe el archivo lo crea. Si existe se destruye su contenido.

# %%
with open('data/class_hlf.py', 'w') as new_file:
    new_file.write("class Barco():\n")
    new_file.write("\tamarre = 'Barcelona'\n")
    new_file.write("\teslora = 4")
    # new_file.write("Pregunta")
    print("Ya se ha escrito")
# Out:
# Ya se ha escrito

# %%
with open('data/class_hlf.py', 'w') as new_file:
    new_file.write("class Barco():\n")
    new_file.write("\tamarre = 'Bilbao'\n")
    new_file.write("\teslora = 10")
    # new_file.write("Pregunta")
    print("Ya se ha escrito")
# Out:
# Ya se ha escrito

# %% [markdown]
# Opción "a" para añadir, append. Si no existe lo crea. No destruye el contenido si ya existe. Agrega.

# %%
with open('data/class_hlf.py', 'a') as new_file:
    new_file.write("\n\nclass Tablero():\n")
    new_file.write("\tjugadores = 4")
    # new_file.write("Pregunta")
    print("Ya se ha escrito")
# Out:
# Ya se ha escrito

# %% [markdown]
# ## 3. CSV
# ***Comma Separated Values*. Es el estándar de la industria que se utiliza para leer/escribir datos en formato tabla**, en dos dimensiones. Se llaman *Comma Separated Values* ya que todos los valores de las columnas van separados por comas, y las filas por saltos de línea. **Su extension de archivo es `.csv`**. Además, el 99% de las veces llevan la cabecera de columnas en la primera línea. Aunque no siempre se dará el caso, depende de la manera en la que se haya generado el CSV.
#
# **Es el archivo más común utilizado para guardar datos tabulares, puesto que ocupa muy poco espacio** ya que es simplemente un archivo de texto plano, con todos los datos separados por el caracter coma. Y además, sencillo de entender, los datos no van en un árbol json o xml... Si lo abrimos como texto plano, son los datos separados por coma, tal cual.
#
# Por supuesto, tenemos el otro gran protagonista en cuanto a almacenamiento de datos en formato tabla, **el Excel**. A ver, son cosas diferentes. El Excel tiene sus formatos (.xlsx, .xls), que encima son muy eficientes ya que el dato va comprimido, pero no deja de ser un software de pago para tratar los datos, mientras que **el CSV es un formato estándar que se utiliza en todos los sistemas operativos para el exportado/importado de datos**.
#
# Como decíamos al principio, los CSVs se llaman *Comma Separated Values* porque todos los valores van separados por comas... bueno, esto no es del todo cierto ya que **puede haber otro caracter que no sea la coma**, como por ejemplo el punto y coma. ¿Por qué? Simplemente porque si tenemos datos decimales, separados por comas, no vamos a saber distinguir cuando una coma es de un decimal, o es el separador de columnas.
#
# **¿Cómo podemos leer un CSV en Python?** Con Pandas! [Aquí tienes la documentación](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html)

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('data/laliga.csv')
df.head()
# Out:
#    Unnamed: 0   season  division  round           localTeam    visitorTeam  \
# 0       26201  2005-06         1      1  Atletico de Bilbao  Real Sociedad
# 1       26202  2005-06         1      1              Alaves      Barcelona
# 2       26203  2005-06         1      1            Valencia          Betis
# 3       26204  2005-06         1      1  Atletico de Madrid       Zaragoza
# 4       26205  2005-06         1      1               Cadiz    Real Madrid
#
#    localGoals  visitorGoals        date   timestamp
# 0           3             0  27/08/2005  1125093600
# 1           0             0  27/08/2005  1125093600
# 2           1             0  27/08/2005  1125093600
# 3           0             0  28/08/2005  1125180000
# 4           1             2  28/08/2005  1125180000

# %% [markdown]
# **Parámetros interesantes del `read_csv()`**
# 1. `sep`: el separador de los datos, por defecto es coma, pero podría ser otro como veremos en ejemplos posteriores.
# 2. `header`: dónde se encuentran los nombre de columnas. Por defecto es en la primera línea.
#
# Probemos a leer el CSV desde otra ruta del ordenador

# %%
tu_ruta = 'data/laliga.csv'
df = pd.read_csv(tu_ruta)

df.head()
# Out:
#    Unnamed: 0   season  division  round           localTeam    visitorTeam  \
# 0       26201  2005-06         1      1  Atletico de Bilbao  Real Sociedad
# 1       26202  2005-06         1      1              Alaves      Barcelona
# 2       26203  2005-06         1      1            Valencia          Betis
# 3       26204  2005-06         1      1  Atletico de Madrid       Zaragoza
# 4       26205  2005-06         1      1               Cadiz    Real Madrid
#
#    localGoals  visitorGoals        date   timestamp
# 0           3             0  27/08/2005  1125093600
# 1           0             0  27/08/2005  1125093600
# 2           1             0  27/08/2005  1125093600
# 3           0             0  28/08/2005  1125180000
# 4           1             2  28/08/2005  1125180000

# %% [markdown]
# Una de las columnas, la podremos usar como index

# %%
df = pd.read_csv('data/laliga.csv', index_col = "Unnamed: 0")
df.head()
# Out:
#         season  division  round           localTeam    visitorTeam  \
# 26201  2005-06         1      1  Atletico de Bilbao  Real Sociedad
# 26202  2005-06         1      1              Alaves      Barcelona
# 26203  2005-06         1      1            Valencia          Betis
# 26204  2005-06         1      1  Atletico de Madrid       Zaragoza
# 26205  2005-06         1      1               Cadiz    Real Madrid
#
#        localGoals  visitorGoals        date   timestamp
# 26201           3             0  27/08/2005  1125093600
# 26202           0             0  27/08/2005  1125093600
# 26203           1             0  27/08/2005  1125093600
# 26204           0             0  28/08/2005  1125180000
# 26205           1             2  28/08/2005  1125180000

# %%
df.index
# Out:
# Index([26201, 26202, 26203, 26204, 26205, 26206, 26207, 26208, 26209, 26210,
#        ...
#        36675, 36676, 36677, 36678, 36679, 36680, 36681, 36682, 36683, 36684],
#       dtype='int64', length=4940)

# %% [markdown]
# Si queremos pasar el índice a una nueva columna, simplemente creamos una columna nueva

# %%
df['nueva columna'] = df.index
df.reset_index(inplace=True, drop=True)

# %%
df.head()
# Out:
#     season  division  round           localTeam    visitorTeam  localGoals  \
# 0  2005-06         1      1  Atletico de Bilbao  Real Sociedad           3
# 1  2005-06         1      1              Alaves      Barcelona           0
# 2  2005-06         1      1            Valencia          Betis           1
# 3  2005-06         1      1  Atletico de Madrid       Zaragoza           0
# 4  2005-06         1      1               Cadiz    Real Madrid           1
#
#    visitorGoals        date   timestamp  nueva columna
# 0             0  27/08/2005  1125093600          26201
# 1             0  27/08/2005  1125093600          26202
# 2             0  27/08/2005  1125093600          26203
# 3             0  28/08/2005  1125180000          26204
# 4             2  28/08/2005  1125180000          26205

# %% [markdown]
# Podemos resetear también el índice, y poner ahi un numérico que vaya desde el 0 al número de filas.

# %%
# Resetear el index. Drop= True para que no lo conserve
df.reset_index(drop=True)
# Out:
#        season  division  round           localTeam    visitorTeam  localGoals  \
# 0     2005-06         1      1  Atletico de Bilbao  Real Sociedad           3
# 1     2005-06         1      1              Alaves      Barcelona           0
# 2     2005-06         1      1            Valencia          Betis           1
# 3     2005-06         1      1  Atletico de Madrid       Zaragoza           0
# 4     2005-06         1      1               Cadiz    Real Madrid           1
# ...       ...       ...    ...                 ...            ...         ...
# 4935  2017-18         1     38          Villarreal    Real Madrid           2
# 4936  2017-18         1     38  Atletico de Bilbao        Espanol           0
# 4937  2017-18         1     38           Barcelona  Real Sociedad           1
# 4938  2017-18         1     38            Valencia      Deportivo           2
# 4939  2017-18         1     38  Atletico de Madrid          Eibar           2
#
#       visitorGoals        date   timestamp  nueva columna
# 0                0  27/08/2005  1125093600          26201
# 1                0  27/08/2005  1125093600          26202
# 2                0  27/08/2005  1125093600          26203
# 3                0  28/08/2005  1125180000          26204
# 4                2  28/08/2005  1125180000          26205
# ...            ...         ...         ...            ...
# 4935             2  19/05/2018  1526680800          36680
# 4936             1  20/05/2018  1526767200          36681
# 4937             0  20/05/2018  1526767200          36682
# 4938             1  20/05/2018  1526767200          36683
# 4939             2  20/05/2018  1526767200          36684
#
# [4940 rows x 10 columns]

# %%
# Para cambiar el indice
df.index = range(1, df.shape[0] + 1)
df.head()
# Out:
#     season  division  round           localTeam    visitorTeam  localGoals  \
# 1  2005-06         1      1  Atletico de Bilbao  Real Sociedad           3
# 2  2005-06         1      1              Alaves      Barcelona           0
# 3  2005-06         1      1            Valencia          Betis           1
# 4  2005-06         1      1  Atletico de Madrid       Zaragoza           0
# 5  2005-06         1      1               Cadiz    Real Madrid           1
#
#    visitorGoals        date   timestamp  nueva columna
# 1             0  27/08/2005  1125093600          26201
# 2             0  27/08/2005  1125093600          26202
# 3             0  27/08/2005  1125093600          26203
# 4             0  28/08/2005  1125180000          26204
# 5             2  28/08/2005  1125180000          26205

# %%
# Dimensiones
print(df.shape) # Ambas
print(df.shape[0]) # Filas
print(df.shape[1]) # columnas
print(len(df)) # Filas tambien
# Out:
# (4940, 10)
# 4940
# 10
# 4940

# %%
df.head(2)
# Out:
#     season  division  round           localTeam    visitorTeam  localGoals  \
# 1  2005-06         1      1  Atletico de Bilbao  Real Sociedad           3
# 2  2005-06         1      1              Alaves      Barcelona           0
#
#    visitorGoals        date   timestamp  nueva columna
# 1             0  27/08/2005  1125093600          26201
# 2             0  27/08/2005  1125093600          26202

# %% [markdown]
# También es posible aplicarle nombres de columnas en la lectura de los datos

# %%
df.columns
# Out:
# Index(['season', 'division', 'round', 'localTeam', 'visitorTeam', 'localGoals',
#        'visitorGoals', 'date', 'timestamp', 'nueva columna'],
#       dtype='str')

# %%
df = pd.read_csv('data/laliga.csv',
                 names = ['Indice', 'Temporada', 'Division', 'Jornada',
                          'Equipo local', 'Equipo visitante', 'Goles local',
                          'Goles visitante', 'fecha', 'timestamp'],
                header = 0)
df.head()
# Out:
#    Indice Temporada  Division  Jornada        Equipo local Equipo visitante  \
# 0   26201   2005-06         1        1  Atletico de Bilbao    Real Sociedad
# 1   26202   2005-06         1        1              Alaves        Barcelona
# 2   26203   2005-06         1        1            Valencia            Betis
# 3   26204   2005-06         1        1  Atletico de Madrid         Zaragoza
# 4   26205   2005-06         1        1               Cadiz      Real Madrid
#
#    Goles local  Goles visitante       fecha   timestamp
# 0            3                0  27/08/2005  1125093600
# 1            0                0  27/08/2005  1125093600
# 2            1                0  27/08/2005  1125093600
# 3            0                0  28/08/2005  1125180000
# 4            1                2  28/08/2005  1125180000

# %%
df.dtypes
# Out:
# Indice              int64
# Temporada             str
# Division            int64
# Jornada             int64
# Equipo local          str
# Equipo visitante      str
# Goles local         int64
# Goles visitante     int64
# fecha                 str
# timestamp           int64
# dtype: object

# %% [markdown]
# Si queremos cambiar los tipos de los datos, en la propia lectura

# %%
df = pd.read_csv("data/laliga.csv",
                usecols = ['Unnamed: 0', 'division', 'localTeam'],
                dtype = {'Unnamed: 0': str,
                         'division': np.int16, # np.int64
                         'localTeam': str})

df.head()
# Out:
#   Unnamed: 0  division           localTeam
# 0      26201         1  Atletico de Bilbao
# 1      26202         1              Alaves
# 2      26203         1            Valencia
# 3      26204         1  Atletico de Madrid
# 4      26205         1               Cadiz

# %%
df.dtypes
# Out:
# Unnamed: 0      str
# division      int16
# localTeam       str
# dtype: object

# %% [markdown]
# **¿Cómo leer un archivo CSV que no esté separado por comas?**
# Probemos a leer un archivo CSV, que no tiene comas como delimitador

# %%
df = pd.read_csv("data/laligaPC.csv")
df.head()
# Out:
#   Unnamed: 0;season;division;round;localTeam;visitorTeam;localGoals;visitorGoals;date;timestamp
# 0  26201;2005-06;1;1;Atletico de Bilbao;Real Soci...
# 1  26202;2005-06;1;1;Alaves;Barcelona;0;0;27/08/2...
# 2  26203;2005-06;1;1;Valencia;Betis;1;0;27/08/200...
# 3  26204;2005-06;1;1;Atletico de Madrid;Zaragoza;...
# 4  26205;2005-06;1;1;Cadiz;Real Madrid;1;2;28/08/...

# %% [markdown]
# Lo lee todo como una única línea ya que no encuentra comas. **Se recomienda trabajar con CSVs cuyo separador sea el ; así evitamos problemas por los decimales**.

# %%
df = pd.read_csv("data/laligaPC.csv", sep=';')
df.head()
# Out:
#    Unnamed: 0   season  division  round           localTeam    visitorTeam  \
# 0       26201  2005-06         1      1  Atletico de Bilbao  Real Sociedad
# 1       26202  2005-06         1      1              Alaves      Barcelona
# 2       26203  2005-06         1      1            Valencia          Betis
# 3       26204  2005-06         1      1  Atletico de Madrid       Zaragoza
# 4       26205  2005-06         1      1               Cadiz    Real Madrid
#
#    localGoals  visitorGoals        date   timestamp
# 0           3             0  27/08/2005  1125093600
# 1           0             0  27/08/2005  1125093600
# 2           1             0  27/08/2005  1125093600
# 3           0             0  28/08/2005  1125180000
# 4           1             2  28/08/2005  1125180000

# %% [markdown]
# ¿Podemos tener otros caracteres que separen los datos?

# %%
df = pd.read_csv("data/laliga4.csv")
df.head()
# Out:
#   Unnamed: 0~season~division~round~localTeam~visitorTeam~localGoals~visitorGoals~date~timestamp
# 0  26201~2005-06~1~1~Atletico de Bilbao~Real Soci...
# 1  26202~2005-06~1~1~Alaves~Barcelona~0~0~27/08/2...
# 2  26203~2005-06~1~1~Valencia~Betis~1~0~27/08/200...
# 3  26204~2005-06~1~1~Atletico de Madrid~Zaragoza~...
# 4  26205~2005-06~1~1~Cadiz~Real Madrid~1~2~28/08/...

# %%
df = pd.read_csv("data/laliga4.csv", sep='~')
df.head()
# Out:
#    Unnamed: 0   season  division  round           localTeam    visitorTeam  \
# 0       26201  2005-06         1      1  Atletico de Bilbao  Real Sociedad
# 1       26202  2005-06         1      1              Alaves      Barcelona
# 2       26203  2005-06         1      1            Valencia          Betis
# 3       26204  2005-06         1      1  Atletico de Madrid       Zaragoza
# 4       26205  2005-06         1      1               Cadiz    Real Madrid
#
#    localGoals  visitorGoals        date   timestamp
# 0           3             0  27/08/2005  1125093600
# 1           0             0  27/08/2005  1125093600
# 2           1             0  27/08/2005  1125093600
# 3           0             0  28/08/2005  1125180000
# 4           1             2  28/08/2005  1125180000

# %%
df = pd.read_csv("data/laligaPC.csv", sep=";")
df
# Out:
#       Unnamed: 0   season  division  round           localTeam    visitorTeam  \
# 0          26201  2005-06         1      1  Atletico de Bilbao  Real Sociedad
# 1          26202  2005-06         1      1              Alaves      Barcelona
# 2          26203  2005-06         1      1            Valencia          Betis
# 3          26204  2005-06         1      1  Atletico de Madrid       Zaragoza
# 4          26205  2005-06         1      1               Cadiz    Real Madrid
# ...          ...      ...       ...    ...                 ...            ...
# 4935       36680  2017-18         1     38          Villarreal    Real Madrid
# 4936       36681  2017-18         1     38  Atletico de Bilbao        Espanol
# 4937       36682  2017-18         1     38           Barcelona  Real Sociedad
# 4938       36683  2017-18         1     38            Valencia      Deportivo
# 4939       36684  2017-18         1     38  Atletico de Madrid          Eibar
#
#       localGoals  visitorGoals        date   timestamp
# 0              3             0  27/08/2005  1125093600
# 1              0             0  27/08/2005  1125093600
# 2              1             0  27/08/2005  1125093600
# 3              0             0  28/08/2005  1125180000
# 4              1             2  28/08/2005  1125180000
# ...          ...           ...         ...         ...
# 4935           2             2  19/05/2018  1526680800
# 4936           0             1  20/05/2018  1526767200
# 4937           1             0  20/05/2018  1526767200
# 4938           2             1  20/05/2018  1526767200
# 4939           2             2  20/05/2018  1526767200
#
# [4940 rows x 10 columns]

# %% [markdown]
# **Escritura de CSV**
#
# Para escribir un CSV usamos el método `to_csv()`. Tienes [el enlace a la documentación para ver más detalle](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_csv.html).

# %%
df.to_csv("data/laligaWrite.csv", sep = ';', index = False)

# %%
df.to_csv("data/laligaWrite.csv", sep = ';')

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/ejercicio.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>Ejercicio CSV</h3>
#
# Crea un fichero de CSV llamado ejercicio_clase.csv en la carpeta de data a partir de estas Series con separador de ; y leelo a continuación.
#
#  </td></tr>
# </table>

# %%
dummy = {"colA": range(5),"colB":range(6,11),"colC":range(20,25)}
df_dummy = pd.DataFrame(dummy)
df_dummy
# Out:
#    colA  colB  colC
# 0     0     6    20
# 1     1     7    21
# 2     2     8    22
# 3     3     9    23
# 4     4    10    24

# %%
df_dummy.to_csv("data/ejercicio_clase.csv", sep = ';', index=False)

# %%
df_dummy_read = pd.read_csv("data/ejercicio_clase.csv", sep=";")
df_dummy_read
# Out:
#    colA  colB  colC
# 0     0     6    20
# 1     1     7    21
# 2     2     8    22
# 3     3     9    23
# 4     4    10    24

# %% [markdown]
# ## 4. Excel
# ¿Qué empresa no trabaja con Excel? **Nos vamos a encontrar los formatos de datos de Excel en cualquier sitio**. Las extensiones de archivo más habituales son `.xlsx` y `.xls`. Por suerte, **`pandas` tiene métodos para leer los formatos de archivo de Excel**.
#
# El problema que presenta este tipo de lectura de datos es que **no es un formato tan cerrado como el CSV**. En el CSV tenemos una estructura compacta, con todos los datos separados por comas y con una línea de cabecera en la primera fila. El Excel permite tener datos en un formato mucho más flexible, con tablas en cualquier sitio de las hojas, información en varias hojas y demás.
#
# Teniendo esto en cuenta, y sabiendo bien el formato del Excel en cuestión, podremos leerlo sin problemas con `pandas`, debido a la cantidad de argumentos que tiene la función `read_excel`. [En la documentación tienes todo el detalle](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_excel.html).
#
# Leemos nuestro archivo de laliga, pero en este caso en Excel

# %%
# %pip install openpyxl

# %%
with open('data/laliga.xlsx', 'r', encoding= 'ISO-8859-1') as open_file:
    all_text = open_file.read()
    print(type(all_text))
    print(all_text)
# Out:
# <class 'str'>
# PK
# odX_rels/PK
# odXj¿¼ÆæJ_rels/.rels­ÁJÄ0_%Ì};ÝDd³{ao"õÆdÚ-m3!µûöFba<d¾ÿûÃl÷ó4WN¹`a]Õ`88ñ}è,<5÷«0Y)x%°gØï¶<|ìc6²£j¼EÌîÈåJ"rÓJHË1uÉ
# Ô1nêúÓw,¦¡Ô±ZðâÄcUh`SäßdIÛöïÄ½LôL$ò¬<ûU,	´/ÝÌÁ[HøÄSº\'Vò¤ôI='´¹(4ø&ixþû/¾\Ö.¸ØÝ;PK
# odX	docProps/PK
# odXxl/PK
# odX	xl/theme/PK
# odX¹B$¬uxl/theme/theme1.xmlíY[oÛ6þ+Þ[ù&Ç
# ê/Í¦
# ·CiXS¢@ÒIýV´ë½ØÛmZ`/Ý¯ÉÖaëþ]lQ6%í2thmÀ¿sç9"å«×!)ºVýrÍB$r¹G#¿kÝ
# /u,$<ÌxDºÖHëúµ«xS$$(Â!oO&Ô%h,#¹»V T¼iÛÒ:yL"pbCáÛÀÇ )dv£VkÛ!¦µ>`ð)\&Ý5)ÖÖËa©àÚµjéÇBGu-Pâñãy ,ûÚU{ÉÄw~J¼9_ÎàM)ðÇ	ckµV{k)¿É_Ç
# 6íA{)/`×Oë^+Çj ìÖ »¿ÑoÖKxM~s
# ¿å$ß¾Yà[køá°UÇ·
# ¼³w¶¯l÷Ëòß^ÃoÔ¶ú­>FÓ5t`HS^B&íáwÆ([[]¤ªÖZïs1@\¬hÔ<&ì®Ã± 8Q7	Öf2+×H.øúÅ¯_<C¯_<=yôüäÑÏ'<ú
# Ð4V]ëãGFÆWß}þ×7ÑÏ¾}õäË¿#ßÿíÇOýåP/¿zúûó§/¿þìïàÑHt£­K-ÇçãØ!caæÀ à(À¼5ÇLÃ
# T`ÆÝPápTDí03EàÙ}³{³m.twv°ÂYäkÊwSL¸JºÅÌÌbX»TÙ«Jî><bDD¡^@¢±Åìu|¢Ð=¶1ÕCrRs¦B^æzéØ¼öî¢mÎh)×æèìÁJÇ¬öÉxÏuy«@7Ìp© Ó>a
# <"¥Æs8®gCïÑÓ~[ÌÍöîb¡èTCî±yhDöù´à0Ö°71çFìGr
# K£}®tsiT¬çÈ<àh5ÝÉÄùÊú.%¹^.;Ôf¢`IÆæz³	&ð¼¿:uH£ÓÚ6£Ð·ßç¶½-vf½û?·è>EûÖûý¡C¿z¥ÿ³¾\´b[ßk§bÂÊ÷2v¨æÜià¬7b:Hûü8Û\]	çÞ#ÁÕ'TAM=ÕàË\´/QÌ%.¬JÙéÏÙ!§Õ÷2r³V+ÎJK1éÈº¢f"à¬Êo§¬OÕVì*ØÖÇxILNÞ ÔÛ
# Ý²E.2ucêÍ3¨óÏñ)Õ·SvlÚ®´*´9"{½ìXT!Ìü¨k¹
# ÚÆ UB»A.»Ö6Z:³c­hÓ{$wØ1ú[«ô·¤!Rõ±2®tjñÖ%:ù
# §µHÑ4Éf§~qVØ«%	qU¥æs|¦8¼cäQØÊ_½ð4h4ÓÙ1Þ¶X}»Ó1÷£ûÞ/mHGyvíï+ÎûëJ²raWÛôÒ<íFÉíZ\¨CêìR]`4ä(µ%oª+VÉ5ÓÉÈz¨êgnC
# ]Nýaõ¼óE.å}fi®³ë6J³øo¡`Ñ,ò@¤¸Õ¤Ù¦êûÃwxÓªØà¾5(iKéÊ´Gªö$¸òv&ïAÛ0;ÜpÎü áhèëT¸¬ØÅø$-÷VÜ¥N^KâLîh¾%¢.vua»É"¬°®íÍÃê¢êT{½mí`Öþâãû »§S2{ô½Åß
#  Ç.X¯ý
# PK
# odX*}n8docProps/core.xml¥]OÂ0ÿÊÒûítl¶¨áJ1ïöëGÚêàß;£ÜyÙ¼Osú¶ït|¡Êä%	a¥2¼¬é$!r#yk
# ÖdÌJ8&¬Ç'oú¨0$½Ç&\M¶1:Ä5YO>\[¯yì~¾A((ÆÈ%ÂÔFrRJ1*Ý§o-j41@åpa#z®^¤Vqïð*zGzv]uåöûçð¶||*shJ i*)ðÈ£õ0Õò}«kòn`ØçH¡Lú	ì¸Ï9y-ïVÒ´¤´LédìfÊJÑÛÙ{¿©>Múõ,i*øóÛÍ7PK
# odXxl/worksheets/PK
# odXÕ°K=-ýíxl/worksheets/sheet5.xml¬½Ý²ìÆq­û*Þo±*ÔBÒ­Ùè«'ÎÏ5MQÃ"© )Ë~ûÓk°W
# Â¶äÌÙUÙßB_eøÝÿüoÿúÙ¿ýÃß|ÿÝï?~sûü³¯¿ûêû?}óÝ¿þþóÿçÿ¾ÿöùg?þôåwúò¯ß÷õï?ÿÏ¯üüþáwÿøþûñ/_ýÓgÏ¿ÿîÇßþ~úÛo¿øâÇ¯þòõ·_þøïÿöõwÏÈ¿ÿáÛ/zþ×þõÿöÃ×_þéý¾ýëóíV¾øöËo¾ûüðÛ"ñýÿüÍW_ÿñû¯þþí×ßýôÏùáë¿~ùÓsö?þå¿ýx|Ú·_E>îÛ/ø·¿ÿí|õý·{~Ä¿|ó×o~úÏ÷ýü³o¿úíþ¯ß}ÿÃÿò×gÕÿ1å/¿:>ûý¿ÐÇûÍW?|ÿã÷þé7Ïûy¢\sÿ¢ñü¤?üîýÿ÷~øÃï¾ÿûOýæ»¯ÿÏýø÷oúÏõë¿~ÿß~ûü?üîÿJûÓ7Ï?Búì¯ÿüûÏÿ×ôÛGîuùôóÿ~óõ?~üä?öÐ¿|ÿý¿}ü/ûÌç}{ÿ:£ÿéë?ù÷¿þô}ÿíëoþõ/?=ÿ1,Ï?ÖúÛ?ýç¿þñ«ç7þüßÌï~õý_|ÿß}ûÍÇ8ÏoìËÿxÿ¿?þô¿²éù%þã?ýôç¼ýf©%Ïm©Óûÿ?ÿì«¿ÿøÓ÷ßþ?'|þÙ¿|ýãO÷o>úó§ÿósç?wþïÏ­~nNéøÐ)§ðÇ¦?6yÓíg?5ÿü©ÙûÔö)×öß;?vùùcÿþØö_;ÿnËÏ[.þÜúóçV÷ßÂtúsÛÏÛÜÏÓÊ<ý÷·ðçö?·_ûolºÇÄí&üâ?/þyÌ½¶üò§/ÿð»¾ÿÇ/¡ýðþÿüÀÿ: ?ÿìýÿ´ß<83ýô¿>±ï¡gäÇçÿ÷ßÿpûÝÿþq´3ÖfÌdL6ãógÌ6ãlÆÛ?3Ò'ÙfÜ9c±xb36Î¨6cçjÍxðgôÿÊøâdÄeqßGÉÿü6Ë|ï|ýg|ùçwÙ|[ÿûÓ¿¿ý£½Íô-Oðâî¤À§|øt ½}Þ¡ªû03æåÖS¹Ý^úúSèëOðõÃ?è5
# ¾þ$¾~{KüÝÂÐw'¾âé¿âMÄö4øúÓ¯ÿúsèëÏðõCk|ýY|ý"öù»Å!'[_|ýù×ýKèë_àëï`]_ÿ"¾~{[ø»_ð»?áñ¯_Äv¨ªÃ÷XàëÚíöâ×_B_¯þ}­eðõñõØ[áïN~w'¥Ã×/FØLeðõÁ×_~ý×_C_¯þ	®uðõWñõØ[¥ïvÆS¯§ÞúË_ñVÅ¿þ:øúë¯ÿú[èëoðõÃá½¶Á×ßÄ×/bo¿[<õ:)xêmâÇ§ýmðõ·_ÿõ÷Ð×ßáë_µ¾þ.¾~{ëüÝâ©×IÁSo_¿}ï¯¿ÿú¯ÿ£Fìà÷uý9á	O@*øösÐ|Ãxörðlk@3Ø±8aÿú$ OÐús 1)"ø6±íÎx.örðd¬ÙLÏX. á	l}sF:<)¶$Ý]çàqóAÍ`Cq¯hqI·4¿J"æÅ1Úé:ÌxRjl?I°ùâïÿÝÉAø f°MÊ¡8DºDL'pd\X§$OÊíÇ#	G;à¼ý ÙL0!<"/ ³å	tÖiäËfûñHÂñá$8/­>¨A¶IY3WPÓ$ZuÙbóæ?Ôë4RçI¹ó$ôõmb5F9¸;9xQñAÍ`SÁsHHÄzÆáuYô¤4zû6-ùîåÌHBÌ`S3Ø¡8D½DL§'ði\.[§POÊ¨'!µo#Ìtà\uú0)«VÓÛ¡8D»DÌ¬'Pk,sFn=)¹¶$Øñ"úîåÐ1!ÙÔôv(Î!Ñ=9æØ386^¼¬óÈ±gåØ³Ðß·yìÏw/	5Mw(IÌ·HÄ{ÇÆKÄu9ö¬Û~<`ÆÇ»×NjMw(Î!1]@"ØpÇÆSæ:[Î²ç,ZÂo³ãÏ¸øçäpÛùÓA$!,â
# þð=ftì~k¯®vÌ1ÇÁ±ñÂdG=+Ç6A"áø3{ø[ÁsH c!sì/è×yäØ³rìYîÛì86íÄp	ÕïP\A±|ÌèØ½çü*cÏàØøó°Î#Çc ´¥½l
# ÍÊ±Õôv(Î!}DÌ±gpl<ô×yäØ³rl$?ã
#  ý	ú
# îPCûcÏàØ¸ä¼Î#Çc `¦½NuÔ6Ü¡8:ö1ÇÁ±±Ìu9ö¬ÛãØt{øY9¶ÞÅ9$Ð±Ï9öÚ´Î#Çc ûóÝÉ¡-jÍ3è#èØ'H¤c'plü·¦c'åØ&$ãÏ´sh+Áf´ò6 Ð±Ï9vÇNèØiäØI9¶		§G×N^®v¨l&H$¦	tì3$bÀ±:v9vRmI8þý	/W;ÐèM÷«	»ÎËëÛ»û»Á±mðîð[¼"èc;9´ÍXÍ`SÁ=¡ctc'pìFc pü	'	åØ*¸'tl"/ sìÐ±ÓÈ±rl$NûNõ'Ì tëêc'tl"±\@"æØ	;¡c§c'åØ&H$>6öì¼"¡úØI9vBÇ&å1ÇNàØ	;;)Ç6A"á86NîwJBä·¤úØ	HÔHÄ;c'tì4rì¤ÛãÏ¸ÚáäP;)ÇVÁ=¡cvc'pìFc'a¸oÉñgìÙy9¸ËFÍ`K¢É½'tl"Ñ=sìÐ±óÈ±³rlDÙñg$áäÐ¾Ø,D~SÓÛ3:6È·HÄ;cgtì<rì¬ÛÓ£Æ3¶ÇD"¿©éí»"	pìòË{ÅsÌ±38vFÇÎ#ÇÎÊ±³h1¿eÇqµÃÉ¡À,¶ojz{FÇîH{æö*cgpìGc ûóÝË!Ê±M×b3:6@Ç>C"x;58v¦û©7TË;ª³"áø3®Åz9Ø)R3Ø²êcgtl"}DÌ±38vFÇÎ#ÇÎÊ±MH8þLw·;9¸£ÀÖ$T;£c	tì3$bÁ±3:v9vVmDbÜ£¾;9´ËFÍ`SÁ=£c	tì3$bÁ±3:v9vVmDÂñgì:9Ô=5Ð[Ýw
# ÅTGFÇ^zõNsìÑ±óÈ±³rl$>¶mk@ª
# Å9$Ð±Ï9vÇÎèØyäØY9¶	@ÛË¡cBÝE{âèØ'H,1Ç^À±3:ö2rìE9¶	"Åñg<c{9xÆV3Øaù;Ç$tì3$b½c/èØËÈ±åØ&H$}l'Vm
# HBõ±¡8:ö1Ç^À±tìeäØrl,H"ÐÇörè)Aª­;WðÂcÇnÓT_~PSÌ±pì{9ö¢ÛÓÇ&ãýäl
# HBõ±¡8DºDÌ±pì{9ö¢Û³WûN­«l*¸Cqõý±c·ù_]\O/Ç^èñeÃçÉ-ÓÇÆu'/WÅÍ ô3åØPCb¹DÌ±pì{9ö¢ÛãÏØ=ur¨{ºVõfDeD¢\@"æØ8ö½{QmDbìÏw'öv¨lêc/èØD¢^@"æØ8ö½{QmDÂéQÓ1áäàºÁ¦ûM$Ú$b½c/èØËÈ±åØ&H$Æþ|wrhçÙ"åÛ"|_Ð±Dÿõ$JÌ±8ö]F]c (ã{­ï^þ:©l*¸tl$Qn9vÇ.èØeäØE9¶		Ç±qUÜÉ¡>¶ûØjz{AÇ&Ó$b]À±:v9vQmIúØ^=
# Võ±MW¡¸û)»§¹¾ºÚQb]À±:v9vQmDÂñg\ur¨{ªf°©àÅ9$Ò$b]À±:v9vQmDÂñg4;'vAè×I=ósHäHÄ»ctì2rì¢ÛÓ£ÆNC¢¢[Moâ
# î1zpì§wàÃÂÁ±=-|ø¸pù¼ð¢HîÇvrh¿ÁVïPC¢\@"æØ» ccåØ&H$ÆÏ3»;9Ô(ª]cCqzcpì]F]c pzÔØ³órèÚIíWÁsH´HÄ»ctì2rì¢ÛãÏtØ+^Ävð­(Çâý×¨1Ç®àØ»»*Ç6A$Q½âxL89ünõ\q5½cõvcWpì]G]c <óÌË!¢U½©éíPCbºDÌ±+8vEÇ®#Ç®Ê±M°!@ÛÉ¡NQ½U!à{EÇÆÕÝ?>BùE1Ç®àØ»»*Ç6A"áø3®:9Ô°5 ¤H c	tì3$b]Á±+:v9vUmD"ÐÇörð­f° @ÇÆ·ÿÙÒí6µWQc]Á±+:v9vUmDÂñgtl/	1­
# ß+:6X. sì
# ]Ñ±ëÈ±«rl$ç;9´ßÉÏÆ¬ª]Ñ±D¹DðÝ\àØ^Î5|;|=WU$Ïwr¨{j!ò]èØD¢^@"æØ»¢c×cWåØ&H$ÏwrhoGU­¦·Wtl"Ñ. sì
# ]Ñ±ëÈ±«rl$ç;9t'KU]cWtl"Ñ=sì]Ñ±ÛÈ±rlDmü<³»;
# Ô¶&|oèØHÂ~ôI1ÇnàØ
# »»)Ç6A"èc{9DBõ±ð½¡cé1ÇnàØ
# »»)Ç6Á$o³vrhPÍ`SÁ+¸õaÿúIbIåÕûìZÌ±8vCÇn#ÇnÊ±MHîÇörpU¼	ÞðsH¤HÄ»c7tì6rì¦ÛãÏ¸*îäÐ5Mw(®à®àGCÇþø|¾WIÄ»c7tì6rì¦ÛÄøáw/×bÍ èM96ç@Ç>C"æØ
# »¡c·c7åØ&H$¦wÿßý¡Võ¦;ç@Ç>C"æØ
# »¡c·c7åØ&H$Ç¦óC¯aV{Årl(Î!}DðUØàØÞ=|¶|vS$}l/	µW\w(Î!}DÌ±8vCÇn#ÇnÊ±MHúØ^®Å6åØM96ç@Ç>A¢Ç»c7tì>rì®ÛDô±ÚÛ¡f°©àÅ1}DÌ±;8vGÇî#ÇîÊ±MHúØNí(P3ØTpâèØgHÄ»cwtì>rì®ÛoÂh¼xrr¨i§¦°©àÕÜ*ÿè ÙÓQÄ$»dãkÓ×>ì®$Û	cÐ¸ëäÐ5­+Ëêé1Ëî`Ù-»,»+Ë¶AB1Vè»CË±j
# [W­l¨ÎA/@ÓìÝQ³ûH³»Òl$Cã®'ÖcÕ6[!¢ÏÆ;H<{Óôê§óìÝÑ³ûÈ³»òl$N3dÚjÓE¿zSóÛ¡:E¹EL´;vGÑî#ÑîJ´mP-úîäÐý,j
# 	âý,P¢^"fÚL»£i÷iweÚ6H(¦Ó¶MT5Mw¨ÎAÑ.@SíªÝQµûHµ»Rm$GcÕÉ¡=j
# 
# îP¢ÿzÓ-&ÛïyÚöñË4ìg "#,ÛÚnö+ä46ÅK),¡À§¥ï÷¼O¨¤÷¡¨(÷(SqÔ/©¼$ÚcÂ%sÝ±HÊt¿ç*háG¢¢<¢Q	l)÷hUJ!*jW9Yðáp,#ÝæúòS¹¦[ÌÇßóò#CQQJQ¦h}{IÔqRÊ§Q¼ÖÂ"=*Øÿ>E%¦æïy
# ºù¡¨(;(S	ÜÎí%Ñ;nÓÜ±H
# öÂOQYú{¡~d(*JÔ!ÊTÆ~wp1QNc³QþÃ¶8SÁ¾ø)*1aÏ3TÐØEE9;DcíØòh×ÄÇÚEzT°G~JÌÝßó÷#CQQúQ¦2~õ×ÝMÂ­©¨n9Yð¤,ãùS_^~fÎtiü{¡d(*Êä!ÊTmçØ
# ñ¨[+§±ÉèEzT°w~JÌèßóTú#CQQRQ¦Ø¦î%Ñ¾;+ªEzT°~ÊtûéTÈí§¡ÛOÒím¨LvºD{Lì@d¶P¤2aK¨LØS?E%èö¸=D×#CQno£L%ÐZ÷hÆ&£;éQÁþú)*A·Àíñk[EEº½ÎDeüÚ°»D+.°÷MFw,²à(cJsZò«»¨¤n_Ûzd(*Òím©·¬ßÝ$:¯t{(Ò£® tû	Ü]EEº½2ÇíiuÒI¢U|9ÍFùXÉC*ù
# *A·ÀíñL»t{e*¶óyÅéÕÓ:Ø$ì}Ñô¨,WP	ºýnÿ×#CQno£Le¬íw7|eûÛ7(¨ÛãmÝ(ãI%çéÕÍ*Ótû	Ü½z=2éö6ÊTÆÚ~wpÏ©IîX¤G¥^A%èö¸=þ0¬G¢"ÝÞFJàe^w½l)DEº=éQiWP	ºýnÿN×#CQno£Le¼õýî&ñ±¢6ÈÛ(WúJ¿ÊtûÜ¯J×#CP¥ÛÛ(QÇs»{ItwV\Ô$w,Ò¡2ß® tûÜ=Ö#CQno£Le¬íw7®Í@t^1Qò(Ò£2]A%èö3¸=þ;]EEº½&¢âh;­9IÜ_¥Û«IîXdÁÛÃð÷O*}é/÷Wæ ÛÏàöø¾t{e*¶3§oÏTdß~æ¿ctûSTn?ÛãÔzd(*Òím©n_÷¸¿¢¦±ÉèE¼ÿ?¥tËååÕÉ9èö3¸=þz¬G¢"ÝÞFJàVv/×Í@øB9Éô¨,WP	ºýn'ÑõÈPT¤ÛÛ(S	<ÝM¢þÆ&£;éQ)WP	ºýnäë¡¨H··Q¦¸ÅÝM¢u°Yº½-¨Ô!z ÛÏàöXìzd(*Òím©8nÏ¿`ãúì@ì+Âüw,Ò£Ò® tûÜWÑ×#CQno£L%pë»Ä«³ìÛÏÂüw,Ò£Ò/ nÀíñ$ºJno£D%µýî&ÑÙ>Îü&£;éPI·+¨Ý>Û'rû4tû$ÝÞFJ¤oï$ñn$ÝÞJT¦!é
# *A·OàöÜ>
# Ý>I··ÑLT shÍXMcÑ,øÐüýÊRò«O|þU
# ¸}"·OC·OÒím©µýî%q8I·WÜ±HJºJÐí¸}"·OC·OÒím©·Ûß½$Þ¥§¦±Ù(­¸$t{¦nJÐí¸}"·OC·OÒím©nwÈWÔ46(¨ÛãÃfðéO*e¹½Ü·OA·OàöÜ>
# Ý>I··Q¦xdÄ]¯$ûö&J+ùP¤GÝþ Û'pûDnn¤ÛÛ(S	¼ÍKâ¾½Æf£L¥© Û¢tûnÈíÓÐít{e*ûëÝ$¾{òt{(Ò£nJÐí¸}"·OC·OÒím©nµ÷¸Cdß^Ew,Ò£nJº}·OäöyèöYº½xºDWÆf :¯déöP¤C%£Û¢tûnoÞ]EEº½2À#å½$Þg¥ÛgéöP¤GÝþ Ûgp{|Üzd(*Òímt!*¶ÓyÅIâ|5ÍFélE|Ð>ý©/Sé/ï¦ÈA·ÏàöÜ>Ý>K··Q¦éÛ{IÔ·WÓØdtÇ"=*é
# *A·ÏàöÜ>Ý>K··Q¦éÛ{I´¯¦±ÉèE|ÌÓþþIe^wSä ÛgpûLnn¥ÛÛ(Sôí$^3ÎÂÞ79Éô¨,WP	º}·ÏäöyèöYº½2HßÞIâ=.Yº½îX¤G¥\A%èöÜ>Ûç¡Ûgéö6ÊT"}{'wS¨il6ÊTÐíJ½JÐí3¸=¾¹t=2éö6ÊT"}{/zjJTÐíJ»JÐí3¸=¾ÿi=2éö6ÊT·ç+cÇíØu¿A¡DÝ©ô¨,A·_Àí3¹ý2tûEº½ÅÑvºóhuRMc³Qú[ÐíÊr»JÐípûÜ~ºý"ÝÞFJ¤oï$ñ>c5ÍF
# º=S® tûÜö³t{-D%Ò·÷hÌBTäýöPdÅÇ¤= 'Z_
# ÂtûÜÊ°t{e*¶Óê¤Dë`jÒéQA·?E%èö¸ýBn¿Ý~no£LÅiÉó±2~àÞ;íM©ä!tûSTn¿Ûãû×#CQno£LÅq{êEzI|¶÷Û«IîXdÅ"ð÷O*­Ü^ÞM±Ý~·Ç·¶¬G¢"ÝÞFÊXÛï^ï¦°¥y¿=éQA·?E%èö¸ýBn¿Ý~no£LÅq{Z3vxÞ"vÝo2ºctûSTn¿Û/äöËÐíéö6ÊT¯yw¨C¬¦±ÉèEzTÐíOQ	ºýn¿Û/C·_¤ÛÛ(SkûÝKâÝjîX¤GÝþtûn¿Û¡Ûéö6JTJ¤oï$ñn
# 3Ý)Qdßt¨tûSTn_Àí¹}º}no£L%Ò·÷ÈWl)DE>Kô¨ Û¢tûn/¦ZEEº½V¢yN¾Ä+.Eº}n_Ðí©C\Àí[zù
# S	º}·Ç)¬G¢"ÝÞFÊx»ýÝM¢®Wö¾Ù(SA·§u°n¿LÓë÷Û ÛpûBn_n_¤ÛÛ(S<'ßKb*²oo%*èöL%_A%èöÜ¾Û¡Ûéö6ÊT<ÿEúöjò±nÏT+¨Ý¾Ûrû2tû"ÝÞFãöÔõòÈíìÛ«èEzTÊTn_Àí¹}º}no£LÅÑv¦éÛéöEöíº=S©WP	º}·/äöeèöEº½2ç1ydN÷íÕ46(¨ Û3v ÛpûBn_n_¤ÛÛ(SqÜÖÁ$îøL>K¯ Û3~tû
# n_ÈíëÐí«t{%*uüz»»D¾R¥ÛWéöÝ¨ÔÛTn_Áí+¹}º}no£LÅÑvÚMá$ñqn¯&¹c_­ñ¿Ro¯ßo_n_Áí+¹}º}no£¨DúöN÷"Õ46(¨Ûãïã>}z^¬¶öòK
# º}·¯äöuèöUº½2ç~{êz9IÜ·WÓØ P¢TÒTn_Áí+¹}º}no£L%²'ßK¢³}}{Ý±ÈGâÊxR)õõ'²× ÛWpûJn_n_¥ÛÛ(SÜoï$ñ±Æf£LeRY® tû
# ní_EEº½2Àë½$î¯¨il6ÊTÊJ¹JÐí+¸=>Èw=2éö6ÊTmçóD+.UØû:¤R¯ tû
# n_ÉíëÐí«t{e*¶E:I¼wRMcÑô¨´+¨Ý¾ÛWrû:tû*ÝÞFJäYz^­¸¨il2ºc~tûn_ÉíÛÐít{%*-Ò·÷è¼Ò¤Û«IîX¤C¥Ý® tûnßÈíÛÐít{e*¾½Ä÷¯è¼¢¢;éQ® tûnßÈíÛÐít{íDe¼Ýþî&ÑÆf£LÜ)øORúë}ûtûn_EEº½2ÈýöNïkÂÞ7e*iH%]A%èö
# Ü¹t{e*¶SØK¢5ã&:óäEV|ÐãþþIe®¯¯· Û7pûFnßnß¤ÛÛ(Sq´ÁÆ÷?Øø¼"¥EzT+¨Ý¾Û7rû6tû&ÝÞFãö|¬>Èil2ºcr Û7pûFnßnß¤ÛÛ(SqöäSßÞIâ¾}nß¤ÛCz Û7pûFnßnß¤ÛÛ(SìÉ÷hÅEMc³Q>Û·!v Û7pûFnßnß¤ÛÛ(S¼ßÞIâ]zMtæ79Éô¨ô¨ô Ûwp{|ïz*]º½>~þÝKâ]zf z+N}{(Ò¡ÒoWP	º}·ÇÈ­G¢"ÝÞFJä~{'÷¸hÅEMrÇ"=*ÓTnßÁí;¹}º}noG¸GÛùXqøXOËÛä$w,²âCQð÷O*µ·wSô ÛwpûNnßnß¥ÛÛãö|¬8Iäö]ØûÓ *èöLÝþ ÛwpûNnßnß¥ÛÛJÄí½$:Ûwéö]öí;º=='¿£Û·öúsò{Ðí;¸}'·ïC·ïÒíLÅÑvr{/Ï+Òí»tûnÏTÐíOQ	º}·ïäö}èö]º½©8ÚÎT"ÏÉ·y¿}G·g*èö§¨Ý¾ÛãÃI×#CQnoG`*Ûó/Øøaúì@Q{ò;º=SA·?E%èöÜÁ´t{;S<'ßK¢u°.ì}it{¦nJÐí;¸}'·ïC·ïÒíL%ò|/¯åsòM®ÓÑí
# ºý	*ó-æöïy
# ºýñËTìg ©a¹ââ&á±bB_Ñd*PäY*1·ÏûÊ§ãTFno?©LJ oï&¡¯À@DE¹=éQA·?E%æöïy
# ºý¡¨(·&¢Øï%ÑV9ÍFñlEV|¬ó>}J-ßæWwSÌ·Û¿ç*èöG¢¢ÜF`*cm¿{It§ÁÛctÛ¿ç*èöG¢¢ÜF`*¶ã~0/véÉil2ºc|Û¿ç*èöG¢¢ÜF`*NßÁ·g*jO>L¨Ûã#Ððé©´ß)1ßbnÿg¨ Ûr{©Þç&áÞI;ÿ©¾=éQ)WP¹ý{¡nd(*Êía¦xÄTÄ[î69Éô¨Ô+¨ÄÜþ=ÏPA·?2åö0S	ìÉ÷è<;º½²¯´!vÛ¿ç*èöG¢¢ÜF`*=ù^Ý)ab*ê9ùX¤G¥_@e
# ºýt*äöÓÐí'éöv¢2öä»I¸ÇB*&J¾E:T¦ÛTn?Û£Á­G¢"ÝÞÀT¾=ýyILEº½îX¤GeºJÐí'p{¼´YEEº½a&*ã[éï^u½ì@ô¦&¹cLÿ¿R¿Ýê«»)æ)èö¸=^®G¢"ÝÞÀTm§ÕI'W''aïäEzTÒTn?Ûã¥Ízd(*ÒíL%ð~{/º^v Üf£|^ÉC*ù
# *A·Àíña=2éöv¦âh;ö"Ý$Z3VÓØl®¡È/qxÀ§¤Ò_~{Á<Ý~·ÇÎõÈPT¤ÛÛJ`O¾D{\` ¢¢úöX¤G¥\A%èö¸=þ\EEº½©8ÚÎ¿`NWÔ|9Éô¨Ô+¨Ý~·ÇÎõÈPT¤ÛÛ£í|¶/|ºßô¨´+¨Ý~·ÇUôõÈPT¤ÛÛÊ¸%wø¼"Ý^MrÇ"=*ý*sÐígp{¼þYAenoG *óXÛï^í3ÓØdtÇ"*óí
# *A·Áíñçz=2éöv¦Øï&Ñ:®M®Á HÊt ÛÏàöhpë¡¨H··#$¢éÛ{IÔõ¥ÛÛit{ÚM1£Ûi~y7ÅtûÜÿ1¯G¢"ÝÞÀTm§óDûÁì@L%ýò´ctûSTn?Ûã×¶t{;Sq´Vò$^TÓØdtÇ"=*èö§¨Ý~·ÇÎõÈPT¤ÛÛÊXÛïnõ"Õ46¥(²âkhðé©ôöòn9èö3¸=®×®G¢"ÝÞÀTï·÷xçÁdßô¨ Û¢tûÜ=Ö#CQnoG`*cm¿»Iü¦Þoo£|¬Ô!tûSTn?Ûc±ë¡¨H··#0Çíi7Ä»)fÑß`D¥
# © Û¢tûÜ/mÖ#CQnoG`*ã[éïn_K·eßô¨ Û¡nÀí±ØõÈTt{;QIãW×ßÝ$Úã¢¦±ÉèE:Tºý)*A·OàöÜ>
# Ý>I··#0HßÞKb*bÒyô¨ Û¢tûn+[EEº½!À;ðÜ$º3áxr;Yñå@øû)ßæ©¾¼"Ý>ÛãCÖ#CQnoG`*ÛSÅK¢®ÎöIÿEzTÒTnÀí¹}º}noG`*ÛÓD]/5ÍFJRÉWP	º}·OäöièöIº½©8{òiÍØKâcåÓhÍ8I·OèöLe¹JÐí¸}"·OC·OÒíLÅq{>V·§®Æf£´Ðíñ]EðéO*é^ÞãnÀí¹}º}noG`*¶ÓÄ«jîX¤G¥^A%èö	Ü>Û§¡Û'éöv¦âh;_9|¬È=ùIÿEzTÚTnÀíña?ë¡¨H··#0GÛi7D»)tû$Ý>¡Û3~tûn·4¯G ¥ÛÛJv´®$ÞÑÅ®ûMNrÇ"*öïÏR	º}·ÏäöyèöYº½©8ÚNÇDÇÆÓ *èöLeºJÐí3¸}&·ÏC·ÏÒíQ?ÿî%ñqnEWÇ"+¾ÞìE>©´y~y7Eº}·ÏäöyèöYº½©8ÚN¾â%Ñ:Xö¾Á4JRA·?E%èöÜ>Ûç¡Ûgéöv¦2~þÝKâ®Æ&£;Yñ¥søû'~{ùÍsº}·ÏäöyèöYº½©¥ç&ñ/¸£~³Qþ[TÐíOQ	º}·Ç2¬G¢"ÝÞÀTïÀóxïd»î7e*eHÝþ Ûgp{¼!p=2éöv¦xÄ½H;QQÏÉÇ"=*èö§¨Ý>Ûgrû<tû,ÝÞÀT·g*N+Ä×`ê9ùX¤GÝþ ÛgpûLnn¥ÛÛÊXÛï^ïhÍÂÞ79Éô¨ Û¡²Ý~·ÏäöËÐíéöv¢²8nO¾â%Q/RMci (Ò¡² Û¢tûÜ~!·_n¿H··#0HßÞIâÝjîX¤GÝþ Û/àö¹ý2tûEº=@T"}{'É9VÔsòaDÜ_Ðø"§<å¹¼¼b	ºýn·4¯G¢"ÝF *=ùN÷"aïÒÙô¨¤+¨Ý~·ÇÛiÖ#CQn#Èýö^õWì@DEº=éQÉWP	ºýn¿Û/C·_¤ÛD%Ò·wxÁä³ô HÊr Û/àö¹ý2tûEº=@T"nï%ñ±"Ý~nEV|Åì|RY¦ßâ9/A·_Àírûeèöt{¨ï%ñ.=5ÍFJR©WP	ºýn¿Û/C·_¤ÛD%ð|/»^ìÛ«èEzTÚTn¿Û/äöËÐíéö0Q	<'ßMb*²o¯¢;éQéP)A·/àöxCàz*Eº=TJä9ù^õWÔ46¥=.P¤C¥Ü® tûnÑ×#CQn#GÛÉW$ÞMa"*Òí¡HÊt ÛpûBn_n_¤ÛÛ*Q<KÏIâ®WùMNrÇ"+¾böÿ¼.¾¥éåÝ%èöÜ¾Û¡Ûéöv¦2Öö»ÄÇtû"Ý¾ Û3t ÛpûBn_n_¤ÛÛ£í´:é%ÑJ~»î7Ý±HJ¾JÐí¸}!·/C·/ÒíLÅÑv²H/º^j2t{|_$|úÊ4½ü¾È¹Ý¾Ûrû2tû"ÝÞÀT<õW$îéöj;éQ)WP	º}·Ç7Ö#CQnoG`*cm¿{I¼KOMcÑô¨Ô+¨Ý¾ÛãVÎõÈPT¤ÛÛJä~{'ûöv ¢"¥WÐíJ»JÐí¸}!·/C·/ÒíL%Ò·÷Ø"Å46Ý±HJ¿J
# º}·/äöuèöUº½¨ÔHßÞIâ­Utæ79Ét¨ÔÛTn_Áí+¹}º}noG`*gé9IÜ·WÓØ`DÝ©LWP	º}·¯äöuèöUº½¡ñëíîn­ä«il0
# ¢n/É~À§ìy¥òòntû
# n_ÉíëÐí«t{;Sqúö´:é%ñ±"÷äWaþ;éQA·?E%èöÜoXEEº½©·Ûß½$îÛ«il2ºctûSTn_Áíq#Ôzd(*ÒíLe¬íw7úöUØû&£;Yñò(òI¥Î¯¿°Ý¾ÛWrû:tû*ÝÞÀT"}{'Wò«èÌor;éQA·?E%èöÜ¾Û×¡ÛWéöv¦yÄ¿`rO¾Ò3Z¡H
# ºý)*A·¯àöÜ¾Ý¾J··#0HßÞIâ^d}{5Éô¨ Û¢tû
# n_ÉíëÐí«t{;Sôí$ÞMa"*Òí¡H
# ºý*-èö
# Ü¾Û·¡Û7éöv¢Òm'*^ùÝ±HJC·?E%èö
# Ü7
# ®G¢"ÝÞÀT"}{/5MFw,Ò£nJÐí¸=n#XEEº½¡È|'W\Ì@´£UMrÇ"k§^dC·o}y¹ÙnßÀí¹}º}noG`*¶Ó±Ä{òÕ46Ý±ÈÚi¬¡Û÷öúýö-èö
# Ü¾Û·¡Û7éöv¦âh;u½$îEªil6Êçt{¦nJÐí¸}#·oC·oÒíLe¬íw/÷¸¨il6ÊTÐí
# ºý)*A·oàöÜ¾
# Ý¾I··#0ñ#ðïnuìÛ«IîX¤GÝþ Û7pûFnßnß¤ÛÛ£íÔtxÆf£|¬ Û3tûSTnßÀíq#Ôzd(*ÒíLÅq{êE:I¼w²É¾}æ¿ctûSTnßÀí±	·t{;SkûÝKâ¾½Æ&£;éQA·?C¥Ý¾Û7rû>tû.ÝÞ@Túx»ýÝM¢k05MFw,Ò¡ÒÑíOQ	º}·ïäö}èö]º½©8}{úsxçV\Ô$w,²vzT·O·òúýö=èöÜ¾Û÷¡Ûwéö&/Gx;ÂÚ"$^ÉWÓØlÎ+Pd»ÑÜ>ÍyzùNtûnßÉíûÐí»t{u¨8ÚN+ùN÷íÍ@|¬È=ùP¤G%]A%èöÜ¾Û÷¡Ûwéö&êPôí$^3VÓØ P¢TòTnßÁíqÁzd(*ÒíMÔ¡éÛ{Iü&Ý^Ew,²Ýf¢nÒ\_^ìA·ïàö¸½t{u¨Dúö^­äwéö]tõw,Ò£R® tûnßÉíûÐí»t{u¨DúöNïqéÂÞ7Ý±HJ½JÐí;¸=6Ö#CQno¢Èsò$vû.Ý^MrÇ"=*í
# *A·ïàö¨Oë¡¨H·7QJ¤oï$ñn
# 3+ò~{(Ò£Ò=t¹ý{¡ndü2ûHÅFÊ}{/öÛð­86T°H¦E¥sû÷¼O¨,7tû#CQQno£@ßÞK¢=.r2iHÝþÛ¿ç*èöG¢¢ÜÞFñ{oGXöíÝ$\ÓØdtÇ"Û
# ×ÁàïTZ~ùÝésû÷<CÝþÈPTÛÛ¨C%°'ßK¢®DTÛctûSTbnÿg¨ Ûr{u¨_]÷h%ßg{9Éô¨ Û¢sû÷<CÝþÈPTÛÛ¨Ce¬íw/úöv ¦"´·cíkÆPäJ_~·jºÅÜþ=ÏPA·?2åö6êP	¼ßÞK¢|(¨¨¾=éQA·?E%æöïy
# ºý¡¨(··QJà9ùn+ÊíetÇ"=*èö§¨ÄÜþ=ÏPA·?2åö6êPqÜ'¯ÁÛÛ(SA·g*èö§¨ÄÜþ=ÏPA·?2åö6êP	Üoï&á:åöX¤GÝþ)èöÓ
# ¨ÛOC·¤Û(S÷Û»IØõ²IÿE:T&tûSTn?ÛãÏõzd(*ÒíMÔ¡xN¾Dg{3¾é¦ATÐí
# ºý)*A·ÀíÑàÖ#CQno¢ø¢ö·#,»^n­©il2ºc
# ?ý?åçÿ¼üvè4Ý~·ÇëõÈPT¤Û¨CÅÑvìzyI¼6	{ßä$w,Ò£® tû	Ü× Ö#CQno¢GÛiÅÅKâóêÛC¡D%©ä+¨Ý~·Çë¡¨H·7Qãö´ï%Ñ:Æ&£;éQY® tû	Ü§³t{u¨o¥¿{IÔ·ÓØdtÇ".ú<àïTôòoÓtû	Ü§³t{u¨DÜÞI¢]zrJTêJ½JÐí'p{\¯]EEº½:TïÀóhçÆ&£;éQiWP	ºýnW¥ë¡¨H·7QJ oï%ÑÞI(¨¨÷Ûc~9èö3¸=i×#CP¥Û(Sm'_qh7Æ&£;éPoWP	ºýn®°t{u¨8}{êzyIdjîX¤GeºJÐígp{tõÈPT¤ÛhJD%Ò·w¸©¦±Ù(­NB
# ¿|úJ//ßoæ ÛÏàöx¦]EEº½:T·§|/ÖÁféö*ºc
# ¿9åå¶¼|WQn?Û£2¯G¢"ÝÞD*¶Óê¤D;Zí@LEÝoEzTòTn?Ûã7²t{u¨µýî%q×KMc³Q¦²©,WP	ºýn¿ë¡¨H·7QJà9ùnuÕ46e*àöøñORÒËwà¥9èö3¸=*ózd(*ÒíMÔ¡xN¾Ä{\fÙ·¥ÛCz ÛÏàöxi³t{u¨öä{I¼wRMcÑô¨´+¨Ý~·ÇKõÈPT¤Û¨CÅq{þshÍXMcÑô¨ô¨¤ Û'p{<®G ¤Û(SI¶Ó5Ä»)èÌo6Jç(Ò¡nWP	º}·ÇMóë¡¨H·7QJà9ùnùÆiHeºJÐí¸=nwXEEº½¦LTm§þÄë`f >V¤Û't{ÚMÀí§Ú¿¼"Ý>ÛãBÕzd(*ÒíMÔ¡â´äi%ßK¢ü$Ý^MrÇ"=*èö§¨Ý>ÛãOÌzd(*ÒíMÔ¡¸ßÞKâqndß>¡Û3tûSTnÀíñk[EEº½:T·ç_0':ÄIØûÓ *àöxz}@O*5¿ünÕnÀí¹}º}no¢GÛ©¿â$ñJ¾Æ&£;éQA·?E%èö	Ü>Û§¡Û'éö&êP	Üoï%ñ.½$ì}³Q>Û×!tûSTnÀí¹}º}no¢ÇíÙWÆÜû`â_0éöP¤GÝþ Û'pûDnn¤Û¨C%Ò·÷¨o¯¦±Á4JRA·?C%Ý>Û'rû<tû,ÝÞDJÜoï$ñ-©¨IîX¤C%£Û¢tûnÉíóÐí³t{u¨Dî·wx¨H·"UpûëËO¢J9èöÜ>Ûç¡Ûgéö&xoGX÷í½$ZqQÓØlÎöPdÃ|úË\^~gwÊA·ÏàöÜ>Ý>K·7Q£íÔ_ñ¨¿¢¦±ÉèEzTÒTnÁí3¹}º}no¢ÇíÄT¤ÛgéöP¤G%_A%èöÜ>Ûç¡Ûgéö&êPÜoï$ñîï,Ý^MrÇ"
# ÂþþI%åß­rÐí3¸}&·ÏC·ÏÒíMÔ¡âh;W$Z3VÓØdtÇ"=*å
# *A·ÏàöÜ>Ý>K·7QÊøÕõw7:ÄYº½QA·g*õ
# *A·ÏàöÜ>Ý>K·7QJà9ù^÷í³t{5Éô¨´+¨Ý>Ûgrû<tû,ÝÞD*Îv{>V·ç+céö¶P¢nÏTúT Û/àöÜ~ºý"ÝÞDÊéÛ{IÔ··!Eöít{¢²Ü® tûÜ¥v=2éö&êPôí$ÞM¡¦±ÉèEzT¦+¨Ý~·_Èí¡Û/ÒíM=àë®D×`jò±nOøô'r{ýnÕ%èö¸ýBn¿Ý~no¢qKþî%ñJ¾Îöj;éQA·?E%èö¸ýBn¿Ý~no¢§%O«^­/ÂÞ7Ý±H
# ºý)*A·_Àírûeèöt{u¨w÷xÍxn¯&¹ctûSTn¿Û/äöËÐíéö&êPqúöÔ!ö¨ClK!*rO>éQA·?E%èö¸ýBn¿Ý~no¢HßÞKb*ò~ûEÿEzTÐíOQ	ºýn¿Û/C·_¤Û¨C%Ò·wxç-¨H·"=*èö§¨Ý~·_Èí¡Û/ÒíMÔ¡2Öö»ÄçÑßlÁú
# ºý*%èöÜ~!·/C·/ÒíM©§%Oé%Ñ5X}{5Ét¨tûSTn_Àí¹}º}no¢GÛi7Ä«¶¢"¥E6l? ÈTúë÷Û ÛpûBn_n_¤Û(®d¼aÝ·wxÅÅBT¤Ût{ºS¢ Û·R^¾S¢Ý¾Ûrû2tû"ÝÞD*¶Ó±DkÆEº½-¨ Û3tûSTn_Àí¹}º}no¢GÛéÌK¢5MFw,Ò£nJÐí¸}!·/C·/ÒíMÔ¡âh;í¦p¸ooK!*Òíº}&*èö}_¾S¢Ý¾Ûrû2tû"ÝÞD*÷Û{I¼óHMcB
# º=SA·?E%èöÜ¾Û¡Ûéö&êPq´Ïö÷ÛÃ@DELrÇ"=*èö§¨Ý¾Ûrû2tû"ÝÞD*ãGàßÝ$>¯H·WÜ±H
# ºý)*A·/àöÜ¾Ý¾H·7QJ¤oï$ñ.½":óîX¤GÝþtû
# n_ÈíëÐí«t{e*5²'ßIâý`UöíUtÇ"*Ýþ ÛWpûJn_n_¥Û¨C%Ò·÷È"«°÷ÍFÉ"+º=SA·?E%èöÜ¾Û×¡ÛWéö&7-½aÝõòhuRMc³Q¦nO÷WpûZ~JÐí+¸}%·¯C·¯ÒíMÔ¡éÛ{IÔ_QÓØdtÇ"ûW*¸ý©ûWjÐí+¸}%·¯C·¯ÒíMÔ¡éÛ;I¼fl¢7}(+yH%_A%èöÜ¾Û×¡ÛWéö&êPqÜzN÷"Õ46e*ËÊr ÛWpûJn_n_¥Û¨CÅq{¦â¸=+Òí«ìÛCr ÛWpûJn_n_¥Û¨CÅq{Ztx^n¯&¹cz ÛWpûJn_n_¥Û¨CÅÑv¾2¼¯J·7Q>VÚJ»JÐí+¸}%·¯C·¯ÒíMÔ¡yÄ»)ªt{5Él¸Yñÿ¤RÓíåütûn_ÉíÛÐít{e*-ò|';Äf z>XnE:TÚí
# *A·oàöÜ¾
# Ý¾I·7Q£íd^Ydn¯&¹c
# 7`=àï§§A~|½ý«TnßÛ×ßCÜ@{{'*ÒíUôíêV¤DÆM¶íÕ,v¬±ãÒüý´|¼ÛúåÓJª}Kt¥¥!©ö*úvDGD×ÅjMFw¬±ãÒüýJûË;\ZÐì[(d+-¡H³WÑ·#ªN_qøçKnÈ=(ù
# (A±o@!YiË{};¢Ú $|öÍ;íoQ³Ø±FÊr ×·PÈUZB^¯¢oGÔ|ßÔðrx#gÑkô + µ¾UBªÒêÔz};¢ÚT¼$¾úOÈ·u:R¯´úÖ
# JBV¯¢oGT7ì$Ö¶or;ÖèAiW@	J}ë
# ß<Üúz};¢º3ì$qg¸ÝöîX£¥_¥¾ß
# õ ûm¥K§WÑ·#ª[NË£­¡t©ôPcgy´U<¡ÔéuyìA¥ï@¡dP¤Ò«èÛÕë,N>üÖYL¨±ãÍ;¨búø`éùåu4úFÏw÷¡Ñwiô]öÛÕma/®¾ºhÇor;ÖØqÏþ~Zj=±¢¾ÑóÃ}hô]½ 8²Nû%$ÞgÆ!y4Q>RÒJºJÐè;=ß7ÜFß¥ÑwáÒoGToøöH»4ú.[õPcÇ=W¨ñ	¥=¡¾ÑómÃ}hô]½ 8FÏGDk÷j2e¹JÐè;=ß5ÜFß¥Ñw±ýýíªsøÝKâÅf£ !r Ñw0z¾i¸¾K£ïÂ¥ß¨îÓ{I´tß¥Ñ«è5zPêPFßÁèùá>4ú.¾öùÛÕ½$¾áNÍb³Qö6Ò®4úFÏ·÷¡Ñwiô]tÏß¨Z¾{I¼_Íb³Ø±FJÿõP^òg  Ñ¿Å~BÊZ¼$\Jþ`ÇÁ/9Çkd(ð÷g¡Äþ=Ï@A£?2eô0A	ì¿÷è.n;^Û(S°FÊtÑ¿ç(hôG¢ÞFñ%GTvÝ$\Ú~5vÜø§¥¥¥¾º o1£Ï3PÐèE½2@ÞMB£³Øl/±ÆÛðéO(9çW$ó-fôïy
# ý¡ (£·QâôèÑSÜ$<ÑC%EÝX5zPòPbFÿg  Ñ
# 2ze(Nû/Ý$>§¨½ã5zP+ Äþ=Ï@A£?2eô6ÊPö;®{I´q*!(jë=ÖèA)W@ý{Fd((Êèm¡t÷¨ÉeÇá#E=
# kô Ô+ Äþ=Ï@A£?2eô6ÊPÆÏ¹¿»Iì)jã½òFÏPÚPbFÿ÷)ºQøÈPPÑÛ(C	</ÏK¢m«r
# ê$(hô¥_e
# ýFO÷	Ê$~Ýñ·#*÷{I´*A(ðýkt L·+ ~£§ÛEý$Lûíj£wh3TBP¤ÑOhôeºJÐè'0zºKøÈPP¤Ñ(¾zðÊÎ£ý;èÕw¬±7¼Aþþ	¥7Nä)hô=Ý$|d((Òè'áÒoGTnðhé*!(j×=ÖØ>{þ~Zú-·W{ôy
# ýFO
# 4ze(NûÛÁnÿ|©GåÉè5zPòPF?ÑÓ-ÂG"ÞDJà)øn­}MÒèmeBY®4ú	î>2iôè¿Q¹qÂK¢Ý,v"jô + ~£§E½2uÚ8á%Q*!(ªG5zPêPF?ÑÓýÁG"ÞDJàøn-HªYl6ÊPÚJ»JÐè'0zº=øÈPP¤Ñ(C	<%ÏKâvð$}³QZû=(ý(sÐèg0úFF?~Fo¢evÚït¢wh3TPTtÇ(óí
# (A£Áèý<4úY½2GÖÉè$ºÕCk_³ðýkô LW@	ýF.»
# 4zÅQÝöhíKÍb³Qúù{§3}_ÊË¯ÈsÐèg0zü7²
# 4ze(¬Ó2ÄK÷³4z¥=ÔØ;¾)j|B)ËËoÈsÐèg0úFF?~Fo¢%Ò£÷Hg±¯~Ñkô  Ñ4ú¾ÑÏC£¥Ñ(Côè$î§ÌÂÙ7e(Ë
# ý)(A£Áèý<4úY½2ñ-òw7Oôj×=ÔIPÊ
# ý)(A£Áèý<4úY½2HÞK¢e5MFw¬ÑF
# JÐèg0úFF?~Fo¢%Ò£÷ø"^Ew¬ÑF
# JÐèg0z¼\E½2HÞKâKbµëÞFùÒPÐèÏ@IA£O`ô8õÈP4z%()Ò£wxßW+¨ÑÐèOA	}£ïdôihôI½2HÞIâI8û&£;ÖèAA£?%hô	¾Ñ§¡Ñ'iô&¯<¢ºì$ñ¤­ È½­±ßðøû©Üj-//³¤ Ñ'0úNFF¤Ñ(Cq\NoP³Øl¾ÒJºJÐè}'£OC£OÒèM¡DzôNo0ãÐ¤ã5>¡à3$áïPZyù9>Ñw2ú44ú$ÞDÊXÖï^wÕ,6Ý¡FÊr Ñ'0úNFF¤Ñ(CqdV$ÞÍbÆá#E½­ÑR®4úFßÉèÓÐè4ze(½Ä;$èÂor;ÔèB©W@	}£Ç¯|=2iô&ÊPÆo©»»I|¢WOÆsÜ¡FJ»JÐè5úéFFF¤Ñ(Côè½$ZT³Øl\¶FJ¿J}¾2ú<4ú,ÞD	Jôè$Þ÷eÞD	­Ñbk<%hôy(dôyhôY½2HÞK"£7ãÐÏîP£eºJÐèóPÈèóÐè³4zÅQÝvxXÍb³QF¿ øô©L©M//³ä ÑçPÈèóÐè³4ze(ÑóÂI¼ö¥f±Éè5ºPÒPF3@!£ÏC£ÏÒèM¡cwHm%E}ÎC(ù
# (A£Ï@!£ÏC£ÏÒèM¡8FÏ'úñÖüv>§H£Ï`ôø½üýJþ¸ôõ* ÑçPÈèóÐè³4ze(WØ¹Iä)Y8û&£;ÔèB)W@	}®>>K£7Qâ=yÄG5
# ê$(¥^%hô¹2ú<4ú,ÞDJd×½Äñ²4zÝ¡FJ»JÐè3=þ ¯G"ÞDJàY÷n)r×}=úÜPúP Ñ/`ôø/p=2E½%ðú:/{ô4z5Çjô ,·+ ~£Çé¬G"ÞDÓ£§/'·­ªYl6JGÊ2
# ¡LW@	ýF?ë¡ H£7Q|¥àÕG'{ôØW¿Ù(CA£Ç@O(½ï£_F¿Ñã?ÓõÈPP¤Ñ(CqÎ)N7¹Ô,6e(hôþ Ñ/`ôhÊë¡ H£7QÂ²Î«ÄNoP³ØlV4zF
# JÐè0z\è[E½2Çè©Éå%Q?eF¯æ¸CO(øøû©Ì·úò[!ò4ú]E½2§ýN«ÄN·Í8E½½jt¡+ ~£Çw=2iô&ÊPÆêïnm1R³Ø NFÏPêPF¿ÑãtÖ#CAFo¢Å1z¾úrhØVBP¤Ñ/hô¥]%hô=þ3]E½2çyZt¸ógßdt](ý(%hô~&£/C£/ÒèM ÇèéDï$q^ÍbÑjô ÛPF_Àèñ_àzd((ÒèM¡8FO«ÄNß^W³or;ÔèB®4úF?èë¡ H£7ÑNP"=z'$Õ,6Ý¡Æ~Ã)<àïP_4úFë¡ H£7Q2n¿ß½$^º·iô%
# ¡¤+ ¾ÑãtÖ#CAFo¢ÅÙPONïf1ãðÏ¼¾ä!| Ñ0z<Ë®G"ÞDJ¤Gï$q;¸H£WÑj|B¡Wu4úÒ¦÷} Ñ0z<®G"ÞDJ¤Gï$ñ¤Å&£;ÔèBA£?%hôMy=2iô&ÊP"=z//åñÔw¨ÑF
# JÐè=þ,¬G"ÞDJä>z'·©YlP'AiC(hô§ ¾Ñã¿ÀõÈPP¤Ñ(CÜGï%ñ^öè4úÒPÐèÏ@©A£¯`ôøÛ±JFo¢¥FÞ^ç$ñÉ*öÕoP'B©·F
# JÐè+=JÂzd((ÒèM¡Dî£wxß¡H£¯Ó
# ý)(A£¯`ô¾¾J£·ÑQÜHï$ñ:KMz5Éì7ü·ù¿Jzy3q
# *}¥O¤ôu¨ôU*½2qþî&Ñ©^McÑt©¤+¨¾Ó'rú:tú*ÞFJäVz/y+½äE>©Ð!*H}[yyQ
# J}©O$õu(õUJ½2È½ôNß£bK!*²O_!å
# *A«¯`õ¬¾­¾J«·Q¦¹ÞIâÍ_jJTÊJ¹JPë+h}"­¯C­¯Rëm©·ÕßÝ$ZlQÓØll¥Ö!z ×WðúD^_^_¥×Û(SÜNï$ñö/5ÍFémµµ
# ©´+¨Å¾Øgû:û*ÅÞF#í´Üâ%Ñ®*{õ*ºC.~4ûfÉìÛÐì4{%*Í±vZtxÆ&£;éQi·+¨Õ¾ÚgRû6Tû&ÕÞFóø;:Û;I¼ÙÈDÇîP¤KeºJÐí¸}&·oC·oÒímt"*ãwÔÝ½$îw5éöj;ù¤B{(º}»å·· Û7pûLnßnß¤ÛÛ(SqvàÓ±Ä
# /3SýúnÏTÐíOQ	º}·ÏäömèöMº½2§aOé%ÑK
# {5Éì7¼èy`O*ýörÃ¾Ý¾Ûgrû6tû&ÝÞFÓ§æ°Äë`f >VùïP¤KÝþ Û7pûLnßnß¤ÛÛ(SkûÝKâWö¾Ù(ÿ!tûSTnßÀí3¹}º}no£L%ò¤<'·5aïÒMD­© Û¢tûnÉíÛÐít{e*ë$Þ2©¦±Ù(¹}kC*èö§¨Ý¾Û/äömèöMº½2È³ò¼$öéö*ºC.tû3TzÐí;¸ýBnßnß¥ÛÛ(Qé¶½DÇÆf£D¥ßFT:ºý)*A·ïàö¹}º}no£L%Ò·wx/®Áºtû>
# © Û¢tûn¿Û÷¡Ûwéö6:HßÞK¢þÆ&£;ù¤B»):¸ýS!ûË»)zÐí;¸ýBnßnß¥ÛÛ(Sq´ú+Nï¦0Ñ<ºtûTÒTnßÁírû>tû.ÝÞFÓ§ÕI'WòÕ46¥+ãn_JF*}yy7Eº}·_ÈíûÐí»t{e*¾½Ä+ùjîP¤Ke¹JÐí;¸ýBnßnß¥ÛÛ(Sôí$Þã¢¦±ÉèEºTÊTnßÁírû>tû.ÝÞFJ¤oï$ñ.Ý^Ew(Ò¥R¯ tûn¿Û÷¡Ûwéö6ÊT"}{/,²{ßä$w(Ò¥Ò® tûn_ÈíûÐí»t{e*¾½Ä;Ì@LE>¿£Û3þë©,·Û¿ç*èöGÆ/S±T T°ì{I´J*6T H
# qJÌíßótû#CQQnQ¦xnb;Wä$w(Ò¥2]A%æöïy
# ºý¡¨(·h"*¶ã±+ùv ¦¢Üì7\âxÀßOå)¿ºb¹ÅÜþ=ÏPA·?2åöe*Î}ö¸fì%QßJ!*Êí¡HJºJÌíßótû#CQQnQ¦â<:»^^õWä46Ý¡HJ¾JÌíßótû#CQQnQ¦âh;ÿî´·ñ/ºÓ|RÁ7ABO*Óíöêåsû÷<CÝþÈPTÛC©nµwpJ!*Êí¡HJ¹JÌíßótû#CQQnQ¦2Þnw°¿¥õô<(Ò¥R¯ sû÷<CÝþÈPTÛC©u÷¨iâ_0õø<(Ò¥Ò® sû÷¼O©Ttû#CQQnQ¦x"¾ÄÇºÛ^Nr"]*ý*SÐí'pûJn?
# Ý~no£De
# ôí½$êC)HeR}{(Ò£2Ý® tû	Ü¾ÛOC·¤ÛÛ(S	ôí½$Ú¥'§±A¡DeR® tû	Ü¾ÛOC·¤ÛÛh&*â»I¸:)§±Ù(+àö¸HûOR)S{u7Å2Ý~·¯äöÓÐí'éö6ÊT{ò½$^¤Û«IîP¤KÝþ ÛOàöÜ~ºý$ÝÞFJ oï%ÑJ¾Wò¡P¢nKç(ãI¥ÞWwS,SÐí'pûJn?
# Ý~no£L%ð\|/úörJT!tûSTn?ÛWrûièöt{e*¾½}{9MFw(Ò¥nJÐí'pûJn?
# Ý~no£L%Ð·÷h±Æ&£;éRA·?E%èö¸}%·n?I··Q¦èÛ»I´oÂ­6Ê×`mHÝþ ÛOàöÜ~ºý$ÝÞFJ oï%ÑÎ#;­¸LÂüw(Ò¥nÊtûÜ¾ÛÏC·¥ÛÛ(Q#}{/Îö³t{5Éô¨Ìèö§¨Ý~·oäöóÐígéö6ÊT"}{'vÙèÊØDélTÐíOQ	ºýnßÈíç¡ÛÏÒímt!*Çã{I¼:9Ë¾½-¨ ÛÓnÜ¾Ìszy7ÅtûÜ¾ÛÏC·¥ÛÛ(SqÜ'Ü^McB
# º=SIWP	ºýnßÈíç¡ÛÏÒím©^bï&Ñ5Ù·ÑíJ¾JÐígpûFn?Ý~no£L%âöNw½Ô46åó
# º=¾>ýI%M·wSÌA·Áí¹ý<tûYº½2HßÞIâÕI3+Òígt{¦R® tûÜ¾ÛÏC·¥ÛÛ(S	<#ßKâÝjÒÖÝ©Ô+¨Ý~·oäöóÐígéö6ÊTXÛy?Ä»)Ô46Ý¡HJ»JÐígpûNn?Ý~no£L%p¿½ÄâYìºß P¢nÏTúTRÐí¸}'·OC·OÒím¨¤HßÞK¢±Æf£øl
# (Ò£nWP	º}·ïäöièöIº½2ÇíÉ"½$ºSÓØdt"ûtÃ{áï§Ò^vûtûnßÉíÓÐít{-De¬íw7V't{Ý¡È~Ã
# X(ãy¬äöòtûnßÉíÓÐít{e*ãíöw/WòÍ@t^QÜ¡H
# ºý)*A·OàöÜ>
# Ý>I··Q¦2~LÞÝKâ=.Iº½îPä
# ­N&tû¥¼ü%Ý>Ûwrû4tû$ÝÞFÊXÛïn­ä'aïäEºTÐíOQ	º}·ïäöièöIº½2ñcòî^÷Wl)DEº}*C*èö§¨Ý>Ûwrû4tû$ÝÞF£íÔôøl/÷ä«IîP¤KÝþ Û'p{üÎ×#CQno£L%ð</÷%ÑßlV\RRA·?E%èöÉºý§ãTn¤ÛÛ(S	¼ÏM¢^¤zItõw(Ò¥nJº}¾rû<tû,ÝÞFJôí$ÞyÅ®ûMNr"=*Ýþ Ûç	¨Ûç¡Ûgéö6ÊTÆÚ~whÅEMcÑ|RÁ÷zÁß?©åõûísÐíóTÈíóÐí³t{­D%ð,=/W'³t{Ý¡È~ÃÆÊJ»¥öò:Xº}N@Ü>Ý>K··Q¦â¸=­;I¼:iK!*ÒísRIWP	º}Î@Ü>Ý>K··Q¦éÛ;IÜõÊb×ý&'¹C.| Ûç¨Ûç¡Ûgéö6ÊTÏÒó¸ë¥¦±Ù(ÿÛcóï>}|³êËïXrÐís*äöyèöYº½2ÇíJ¤o¥ÛgÑÕß¡HJ¹JÐís*äöyèöYº½2GÛ©Cì$±Eøl/Ý>×!z ÛçTÈíóÐí³t{e*ã[éï^w½Ô46Ý¡HJ»JÐí3¸=vÖ#CQno£LÅiÉó±2Þ¸ÿJ!*ÒísRéPYn¿ÛãUéz*t{%*Ëø1yw/÷«il6Jë`ËmDe¹]A%èö¸=>ìn=2éö6ÊTíöteì$ñV3WÔ$w(Ò¥2]A%èö¸=þ\¯G¢"ÝÞFQqöäÓ/Äç3uÕ$w(²ß°%û¿R)ùõñtûÜÿ	®G¢"ÝÞFJ¤oï$q×ËÄTÒ/I;éRA·?E%èö¸=Üzd(*Òím©Dî·w¸ëµÈ¾½äE>©ÐÎ£Ý¾Î¯¯/A·_Àíqep=2éö6ÊTÆÚ~÷xÍXMc³Q>Û/C*èö§¨Ý~·ÇÓñzd(*Òím©Þç%q×KMcÑt© Û¢tûÜ¿¶õÈPT¤ÛÛ(SqÜVò$îz¢"Ý~©C*èö§¨Ý~·Çå¥õÈPT¤ÛÛ(SqÜúöNïSÓØlÏömHÝþ Û/àöø¾t{e*géyI|¶ÓØl©ô!tû3TJÐí¸ýLn_n_¤ÛÛ(Q)ÛÓn
# /,RMcBJ¹¨tûSTn_ÀíÑàÖ#CQno£LµwS8I|_¤Æf£t
# V¦!tûSTn_Àí±ØõÈPT¤ÛÛh'*¾½Äb5ÍFéÌÙ'ÜTòOJs}y7E	º}·ÇõÈPT¤ÛÛ(SqZò´æ%Q{ßdt"]*é
# *A·/àö¨ë¡¨H··Q¦2~þÝKâ=.f Zq)Âüw(òI_Àí{J¯?'¿Ý¾ÛãÃzd(*Òím©DúöN÷WÔ46Ý¡HÊr Ûp{üõXEEº½2HßÞK¢ÕÉ":óîP¤K¥\A%èöÜ®×#CQno£L%ò,=/ÁäýöEtõw(Ò¥R¯ tûn?ë¡¨H··Q¦¹ßÞIâ^dö¾ÉèEºTÚTn_Àíñ$ºt{e*NKú+Nï<*ÂÞ79Ét©ô¨Ô ÛWp{\¯]A¥J··Q¢R<­{Iäöf ¢¢&¹Cz»JÐí+¸=þz¬G¢"ÝÞFJä9ùNï31ù,=[¤Kï·?E%èöÜ>Û×¡ÛWéövQ¸½ÄWÆjîPä
# í¦¨èöm_ÞMQn_Áí¹}º}noG`*·wø¼¢¦±Ù(+èöLÝþ ÛWpûDn_n_¥ÛÛJÄí$¾2®ÒíÕ$w(²Ox÷¿Rééõ·Ô ÛWpûDn_n_¥ÛÛJÄí½$>Û'áor;éRA·?E%èöÜ>Û×¡ÛWéöv¦âh;+ãò?À@DEº}-C*èö§¨Ý¾Û'rû:tû*ÝÞÀTÆ¯®¿{I¼fl"*FéITµ© Û¢tû
# nÈíëÐí«t{;S?ÿî%9WÆMR{òkRA·?E%èöÜ>Û×¡ÛWéöv¦yÄg{éövD¥© Û¡ÒnßÀí3¹}º}noG *-r¿½ÄkÆf z
# Bæ¿CnJÐí¸}&·oC·oÒíL%âöNïÒSÓØdt"]*èö§¨Ý¾Ûgrû6tû&ÝÞ0Èsò½$º2VÓØlp{\^xÀ§OõúòntûnÉíÛÐít{;SqÜ®Á$Þ¦¦±Á4JRIWP	º}·ÏäömèöMº½©wÈWt{5Ét©ä+¨Ý¾Ûgrû6tû&ÝÞÀTmç³ýxàÆÓ *èöôöûéO*K~ýí-èö
# Ü>Û·¡Û7éöv¦yÄ{\Ô46Ý¡HJ¹JÐí¸}&·oC·oÒíL%ò|'ï*jÒíÕ$w(Ò¥R¯ tûnÉíÛÐít{;S¼ÏIâû"ìÛ«èEºTÚTnßÀírû6tû&ÝÞÀT"ïÀóÜßùïP¤K¥_@¥Ý¾Û/äö}èö]º½¨t§%OT$¾[µË¾½äEzTìß¥tûn¿Û÷¡Ûwéöv¦âh;Ý)á$ñ]Ef ¦"ûöÝ©LWP	º}·_ÈíûÐí»t{;ÂLT¾=¹½Ä+ù]Øû&£;Ù'ü}|@Sne~y7Eº}·_ÈíûÐí»t{;Sq´®Á¼$êÛ«il0
# ¢TÒTnßÁírû>tû.ÝÞÀTÆÚ~wÈWÔ46åcÜWÙðéO*Sn/ï¦èA·ïàö¹}º}noG`*¶SØIâG]Øûf£LeRY® tûn¿Û÷¡Ûwéöv¦q{/¯Áäü.ºú;éR)WP	º}·_ÈíûÐí»t{;SìÉwxV'M:¤R¯ tûn¿Û÷¡Ûwéöv¦Ùï%ñ±ìÛ«IîP¤K¥]A%èöÜ¾Û÷¡Ûwéöv¦Ùï$q¥Îü&'¹C.þë©<ý&Då=ÏPA·?2~ý¤# #,ûö^íâÝP¤C<K%æöïy
# ºý¡¨(·JàYznöWì@x¶iiHeºJÌíßótû#CQQn#$¢â¸=®¹ILE¹½îPdðp}@O*¥WwS[Ìíßótû#CQQn#0qKþî%QENc³Q¦TÐíOQ¹ý{¡nd(*Êía¦xD+ù0QQnE>©LDÝ¾./¿Å³Übnÿg¨ Ûr{©8Ú«^­äÛøL¹=éRA·?E%æöïy
# ºý¡¨(·JàýönZ¤-RNr"]*èö§¨ÄÜþ=ÏPA·?2åö0S	ôí½$ê¯Èil6ÊÇJRA·?E%æöïy
# ºý¡¨(·J oï&á±ÁÛC.tûSTbnÿ÷)|ïzd(*Êía¦èÛ{I´óÈ»¿å$w(Ò¥nÊtû	Ü_þ¶Ê$ÝÞ@T¦À³ô¼$Ú;i¢óäEzT&tûSTn?ÛãËßÖ#CQnoG`*ãGàßÝ$º2½or;éRA·?E%èö¸}%·n?I··#d¢¸ßÞMÂ®Æ&£;ù¤»)àï§O^ÝMQ¦ ÛOàöÜ~ºý$ÝÞÀT}{/×Á&aïäEºTÒTn?ÛWrûièöt{;S	Üoï&ÑÙÞÄçéöº=¾>>àåwà)èö¸}%·n?I··#0Àýö^u½ì@|¬H·ÐíÊr ÛOàöÜ~ºý$ÝÞÀT}{7Ï+ê~{Ý¡HJ¹JÐí'pûJn?
# Ý~noG`*¾½»ôì@|¬H·ÐíJ½JÐí'pûJn?
# Ý~noG`*¾½Db;SQ{ò¡HJ»JÐí'pûFn?
# Ý~noG`*Ûó±DkÆØu¿Á4
# º=SéPn?Û7rûyèö³t{;Q#}{'vÉil2ºCùv ÛÏàöÜ~ºý,ÝÞÀT"}{/©H·WÜ¡HÊt ÛÏàöÜ~ºý,ÝÞ°ñvû»Ä+.v ¢"Ý~·ÇÜð÷O*­wSÌA·Áí¹ý<tûYº½©8nOë`N¯ä«il6Jgû9
# © Û¢tûÜ¾ÛÏC·¥ÛÛJ¤oï$ñJþ,ì}ip{|ìÀ|Réåå79èö3¸}#·n?K··#0HßÞIâG³t{5Ét© Û¢tûÜ¾ÛÏC·¥ÛÛJ¤oï%¯¨il2ºC.tûSTn?Û7rûyèö³t{;Sôí$îz©il6Êç:¤nJÐígp{|-òzd(*ÒíL%ð,=/whÍXMr"]*èö§¨Ý~·ïäöóÐígéöv¦éÛ{I|¬¨ûím>¤nJ
# º}·ïäöièöIº½¨¤Àýö^ïTÓØdt"=*	Ýþ Û'pûNnn¤ÛÛJàYznõWÌ@ôùïP¤KÝþ Û'pûNnn¤ÛÛ
# QkûÝM¢þ©èEö	Ññ"§r^ÞMnÀí;¹}º}noG`*¬í¼ï$ñqö¾Á4JRIWP	º}·ïäöièöIº½©î·÷x7Eö¾Ù(í¸=>8åE>©,åå7tûn/]EEº½©Dúö^+êYz2ºC.å
# *A·OàöÜ>
# Ý>I··#0HßÞIâ=.jîP¤K¥\A%èö	Ü¾Û§¡Û'éöv¦éÛ;I¼ÇEMcÑt©Ô+¨Ý>Ûãw¾t{;SìÉw¸©¦±ÉèEºTÚTn¬Û§¹}º}noG`*·÷hÅEMcÑt©ô¨ä ÛçP!·ÏC·ÏÒíD%Þç%qØD¾¢&¹C|»JÐíóTÈíóÐí³t{;SamçÝNïSÓØl®ó4¤2]A%èöy*äöyèöYº=@Tmg*÷ÛÛÈ"³tûnO»)2¸}¾µòòntû
# ¹}º}n#ÇíùÌiîÓêdno¢ø®"(Ò¥® tû
# ¹}º}n#GÛ©¿â$q8K·ÏÒí3º=SÉWP	º}^
# ¹}º}n#GÛJàYzv >VÔsò¡HÊr ÛçTÈíóÐí³t{¨Þoï&ñ/t{åcÝßâ	þ¤2ÕßâYrÐís*äöyèöYº=@T·§5c';ÄjîP¤K¥^A%èö¹rû<tû,ÝF *¶E:I¼ÌDTäünÏTÚTnÁíñªt=2éö0Qq´v´zILE=KÏF
# º=SéPYn¿Û£W¯G ²H·Êâh;u$î«il2ºCåv Û/àö¹ý2tûEº=@T"}{/,RMc³Q:Vt{¦2]A%èö¸=ÊÙzd(*Òí¨DúöN÷"í@DEîÉ_Àíñaøû©.sùìe	ºýn®°t{;Sq´®$îÛhuREw(Ò¥® tûÜ¿õÈPT¤ÛÛ£í´ââ$ñ±Æf£üTòTn¿ÛãÏõzd(*ÒíL%âöN÷WÌ@|¬H·_!å
# *A·_ÀíñL»t{;SqZòÔt¸¿¢¦±ÉèE>©à>àï?>[§¾þäÜ%èö¸ýDn¿Ý~noG`*ÛÓJ¾Ä»ôÔ46Q©C*õ
# *A·_Àí±ØõÈPT¤ÛÛÓ·çk°Èýöt{Ý¡HJ»JÐíp{üwºt{;SÜoï%ýÿ¬½Q´¸Ò³;¥¶o9«ª¡æ? S]{«CÒ'Gòs»CoÙÑÏÎL$@g«qï­Ð¤¤Ò ²%½ýÞ_¶_
# Ce³Þ>®@T6áí)"­H%TéÔk{¨l¯'¨$½ýÞ/möKá¨XoW`*s{%¢ÄÅmã°ÕT¦'¨$½ýÞ¿Ó÷Ká¨XoWèD%sn¯Dt
# æ¶qÄ*}mèí)qÙÐÛ·þùÙ·¤·ßÀÛãç~)ëíã
# LEx{ÊÁN½Ü6Xe*èí
# zû[TÞ~oñÒ~)ëíã
# Le<nÿ­D|¾â¶qÄ*Soú¿þK¥·Ïº%½ýÞ¯öKá¨XoW`*cÛþ­Dä»m±ÊTÖ!ôö·¨$½ýÞC¿ýR8*ÖÛÇxu=å`BÄ§^a!zÊtÜQÙTÐÛß¢ôöx{¼HÚ/£b½}\©ä¿'Ü6[=¡II½ý-*Io¿·Çÿlû¥pT¬·+0ÌýöJÄ¿öÖÛoöÜ~kC*èíoQIzû
# ¼=þîÂQ±Þ>®ÀTÄëíØEfî·ßì¹ýf½ýÖTÐÛß¡RÞ¾·ÇïôýR*Õzû¸Q©çä+¥a!J\\õ&Þþ¤·¯àíñ;}¿õöq¦yñ¹}X©Xo_§!ôö·¨$½}o¿·¯Co_­·UüüºÊþXèÊ¸÷~ØMÐä/¨·ßÖ×çOd¯Io_ÁÛ/äíëÐÛWëíCUPGòô»"D|¾[!*f'4)©,OPIzû
# Þ~!o_Þ¾ZoªJæYzBÄ'Ä±¢b6yB¿Tèíµ öùÓ@kÒÛWðöyû:ôöÕzûPTm§ó!âi
# ·#Vù×½=SY ôö¼=¾âb¿õö¡*¨s{:">·wÛ8b© ·g*ÛTÞ¾·ÇùîÂQ±Þ>TÌ¹½·wÛ8b© ·g*õ	*Io_ÁÛ/äíëÐÛWëíCUPÉÛ+ÛÇõö½=SiOPIzû
# Þ¾·¯Co_­·UA%sn/D|é¶qØê	MJ*ý*-éíxûBÞ¾
# ½}³Þ>TJË<'_xÆÅmãUú¬4ôöD¥½ ôö
# ¼}!oßÞ¾Yoª°íN
# Ï¸ÄVÉoèíÊô¤·oàíyû6ôöÍzûPÅï¯«ìçØ
# Q±çö
# ¼=>Rðj^?½%½}oß/£b½}¨
# *cÛþ-EteÜ¬·w<¡IIeyJÒÛ7ðöøÌýR8*ÖÛª 9·W"þ¬ØsûfÏíx{|Ðãüõ©ôÏÚÞ¾·/äíÛÐÛ7ëíCUPÉÛEÆVÉoëÊú¤·oàíyû6ôöÍzûPT2çöBÄç+ÍÛ7{nß¶!í	*IoßÀÛòömèíõö¡*¨dÎíOÝ6[=¡II¥>A%éíxûBÞ¾
# ½}³Þ>TÌ¹½ñ<ÛÆ«ü»ÒTÚTÞ¾·_ÉÛ·¡·oÖÛª ¹ß^xú;,Äß`ÖÛ·>¤Ò ÒÞ¾·ÇÇ+ïÂPéÖÛ*Séûí'Zc+H¥[oß_#*ýõ¤·ïàíñ!rû¥pT¬·UA%s¿½ñ^·Þ¾[oß§!é	*IoßÁÛ¯äíûÐÛwëíCÈ¿®²?õR"º2îöÜÞUOh²ÿwLâ¢Þ¾N?½'½}o¿·ïCoß­·UAelÛ¿3ãn½}¨2eH½ý-*IoßÁÛ¯äíûÐÛwëíCUPÉÛ+ù·#Vé^¯Øä/¨ ·¯ýó§ö¤·ïàíWòö}èí»õö¡*ÛN§^BÄçönG¬ògeRAoJÒÛwðö+yû>ôöÝzûPT2ÏÉW"J'»9?`DeRAoJÒÛwðöøÀÅýR8*ÖÛª yN¾ñÛÆ«üY©C*èíoQIzûÞÁ´_
# GÅzûPT2ÏÉ">­{¿}lRRAoJÒÛwðöyû>ôöÝzûPT2ÏÉW"¾2¶÷Û»ê	MJ*èíoP©¯·ÿÓ*èí/ÅÿM%þ
# ¤«Då*ÛÄEð×*v'4)¨À¿¿K%çíÿt
# zûKá¨8o«Jâ~{%¢É£¸~V`DeRAoJÎÛÿéôöÂQqÞ>Vqäÿë*Û³H%¢b»%*èíqþúTÛ2}üéúÊyû?] ÞþR8*ÎÛÇª "¼=zI¦q!þ¬çBÊò·ÿÓ*èí/£â¼}¬
# *ãGà+zÅ{¿=4ùKÈMNÿ>.äã§ÖWÎÛÿéôöÂQqÞ>VÄ¹½Ñä´BTÌ&OhRRY óöº@½ý¥pT·UA%qn¯DtêâÏÉ&%í	*9oÿ§TÐÛ_
# GÅyûXTçöRÄTÌÓòXe*èíJ}JÎÛÿéôöÂQqÞ>VÄ¹½ñ7É·<¡II¥=A%çíÿtÿ¥RÑÛ_
# GÅyûXT÷Û+ÍÃBDÅÜBJÊôöxûJÞ~zûÉzûPe*SâÜ^èÌmãUúÐÛéõ¤·ÀÛã|÷Ká¨XoªJâÜ^hJ/.D¿ö®zBÊô¤·ÀÛã£ýöKá¨Xoªxãø×Uöß`BÄ9X'`D¼=&?Ðä/Ñ}L%éí'ðö¼ý4ôöõö¡*¨ûí)":·VÉ&%ôö·¨$½ýÞ¾·Þ~²Þ>TÄ¹½Qo·qØê	MþRY
# xûþzÕO§)êôöxûJÞ~zûÉzûPTçöRÄTÜ¹½­Ð¤¤²>A%éí'ðö¼ý4ôöõö¡*¨$Îí¦)ì6h¨lC*ÛTÞ~o_ÉÛOCo?YoªJâÜ^8sÛ8b' II¥>A%éí'ðöøÈØýR8*ÖÛª 8·":õrÛ8b©´!ö¤·ÀÛã±öKá¨XoªJâÜ^èÔkrçöÐ(QéC*ý*sÒÛÏàíyûyèígëíC©Ìûí&ì6ØR_#*óë	*Io?·oäíç¡·­·UA%q¿½Ñ7Xl¨Xo?OC*ÓTÞ~oßÈÛÏCo?[oªøø±¯«ìÏ"|·ÃVOh²Ïøjø÷¿TÖyýxbNzû¼}#o?½ýl½}¨
# *ÂÛóg%q¿}\~WÜ&OhRRY ôö3xûFÞ~zûÙzûPT·§tRø³b¦îØQ)C*èíoQIzû¼=>pq¿õö¡*¨$¥'E4MâÏÊ«QoÙç4ùKe>~^Þ~oÙ/£b½}¨
# *÷ÛKz¹mÐ(QÙTÐÛß¢ôö3xûFÞ~zûÙzûPTï·"þ¬Xoª+Q©C*èíoQIzû¼}#o?½ýl½}¨
# *âVzq"º×Z!*æTÿ&%ôö·¨$½ýÞ¾·Þ~¶Þ>Tñ<þ¬$o·qÄ*%.sRAoÊôöxûNÞ~zûÅzûPe*ËØ¶+Û/Æ½v'4©¨,èíoQIzû¼}'o¿½ýb½}¨
# *çäK}-ÖÛ»MÐ¤¤Þþ¤·_ÀÛããÊöKá¨Xoªøë¯«ìO½íÝ6X¥ÄeAoOÓñ¯Oí5-¯§)¤·_ÀÛãCöKá¨Xoª°íÇõöz{¦²<A%éíðö¼ý2ôöõö¡*ÛNñùÊb¦îØQAoÏTÊTÞ~oßÉÛ/Co¿Xoª°íä¯¸m±Êß`èíñ}ð×©ÌÓÇï¬KÒÛ/àí;yûeèíëíCUPÉÛOS,Æ½v'4)©lOPIzû¼}'o¿½ýb½}¨
# *bÜ¯ÇÀ?q!ÊÁÜ&OhRR©OPIzû¼=þ7ß/£b½}¨
# *s{!â³ÈÅzûPåo0ôöL¥=A%éíèíÿûûuQzûÅzûPT2çöBÄG9?`D½=SéP)Io_^@¼}zûb½}¨2¹ß^ø¸Xoï6yBJü÷w©$½}
# yû2ôöÅzûPT2÷ÛÏèw¥çBÊô¤·/3P!o_Þ¾Xoªø*¤¯«ìO½s°Ø
# Q±3ù¼=¾ÄáÚ´ü~ÛL%éíËTÈÛ¡·/ÖÛª 2¾þ[ø,¶BTìýöeRY ôö¥òöeèíõö¡*¨dî·"NòÃBü
# öß*z2¤R ôöe*äíËÐÛëíCUP?&ï[xÆ%,DÓ±Q¢²©¬OPIzû²òöeèíõö¡*¨÷-EtnâÏ½ß¾lC*ÛTÞ¾T BÞ¾½}±Þ>Tñcò¾ÏWõö®zBJ}JÒÛTÈÛ¡·/ÖÛª 2·ÿV"+ædþ°<¡II¥=A%éíx{lv¿õö¡*¨ûíÊø¦ü ¢bgòKRéPYÞ~oßû¥0TVëíC©¬ÂÛÓ5ñÝª±¤ªt
# ¶·Ç×ý@¿TÊüñ¤êôö+xû¼ý:ôö«õö¡*¨#yò+BÄÓß«õön'4)©LOPIzû¼=:¸ýR8*ÖÛ*¾P÷ë*ûS/!âtrµÞ~µçö+x{|áÉ49µùµ|üDöº&½ý
# ÞmÀ~)ëíCUP¶MS¬ÖÛ»MÐ¤¤²<A%éíWðöè«÷Ká¨XoªÊøÕõßRDgnl¨!ò¤·_ÁÛc2¸_
# GÅzûPT·'¿"Dä»m¶zBÊú¤·_ÁÛc³û¥pT¬·UAEØvÊ|·%*ÛÊö¤·_ÁÛOäí×¡·_­·UAelÛ¿§)Vëíc£D¥©Ô'¨$½ý
# ÞÍÙ~)ëíCUPÛ+O­ÖÛ»MÐ¤¤Ò ôö+x{¼þÙ/£b½}¨
# *wàIÿ®ØûíÝ&OhRRéPÙÞ~o7îÂPÙ¬·U¦²eî·"¾ÏmãUòöÛkDe{=A%éí7ðöxUº_
# GÅzûPT2÷Û+%.q!¢b¿MC*ÓTÞ~Þ¾ñ=ÄØ^Dþÿâß`*¦úuUÃG!âãÍZ{·{\ðíþýÔjÿüÅuKZûm(dW¶ÅZ{Wýºªþ·^èºx³ÎÞíâÄå	(Ig¿Bne+C(ÖÙ»ê×Uõ?õJÄ?*öf{·{TPÊPÆ~[
# mB±ÆÞU¿®ªO&')Â:týåª'ö¸àeèt1µöªýóß¤¯ß6B^eÛP¬¯wÕ¯«êVÑóO\¡¸×ßa
# Êö¤­ß¢­o|ûðVP¬­wÕ¯«êsI!Â{+ÿë0;=*(õ	(IW¿5ÂN¥
# ¡XWïª_WÕÇBÄQ[ç°Õ{TPÚP¦~ëJB±¦ÞU¿®ª8">íÚÌ´ý«üÒPúPjÒÓ×@¡3ÈúA©ÖÓ»ê×Uõ¡¤±¥ëÐ×«Ø£R_O@IZú::¬Óµô®úuU½£"N¿Â:Å:zèQAtô=ß9\¾ZG_Óþºª~Uøâ^jo«'ö¸à÷ôøe½ñ:Âtô=ß8\¾ZG_Óþºª~Lx^Òíâ°Õ{TP' $}GÏ÷
# ×¡£¯ÖÑÇÃ§ãG!â#·ÃVOìqÁ/Çø÷¿P¶V>Ì«IG_ÁÑómÃuèè«uôqy2¾ÑXX®¾ÜOìQAAGJÒÑWpô|×p:új}5Gä_WÕß°"D|[ç°Õ{TPÐÑßtô5:úÎ7
# ×¡£¯ÖÑWsBþuUý¬¤ñ«ÛÅa«'ö¨  £¿%éèk(äèëÐÑWëèã
# E8z¾$S¬£w»8±Gý-(IG_;@!G_¾ZG_Íìû×Uu±Ö·ñL[ç°Õ{TPÐÑßÒ¾½
# 9ú6tôÍ:úfã¿®ª¿YEø¶f}³ô
# =AièèoAI:ú6rômèèuôq"Ì:]+ÝmçvqØê=ÒÉüû©oíõ¹£oIGßfB¾
# }³>Té%-3~¯D³¸]¶zbK¡¥£ïíÆ
# ZÒÑ· £oCGß¬£U9£">ärëv'ö¨ ,O@I:úV
# 9ú6tôÍ:úfÆÞ¿®ª$¹I»Ç{TPÊP¾­}:úf}3Nûëªúã`!âC.·#V)Â¿)+BéËÇÙWK:ú¶rômèèuôÍ]U¬D»]±ÊP¶!í	(IGßÀÑó­Âmèèuô¡ÊP£ç¯/!âz{Fïöxb
# J}JÒÑ7pô|§p:úf}3ñ_WÕOH
# ã¹]¶zb
# J{JÒÑ7pô|£p:úf}3gç_WuàSÄ=õüõeçî]õÄþtô=ß'Ü¾[Gª¥gÎè'Ü.X%(Ð£Ò_O@I:úoîCGß­£U26ëßJÄ)qXÆVÝOìQAtô=ß%Ü¾[GªôêÁy¾qÌÒÍ,Àa÷xbK¡ì+þû©¿Ê×ô¤£ïàèù&á>tôÝ:úPe(Â¬Ó0ñ!Wì XGßÑÑ3å	(IGßÁÑó=Â}èè»uôÝLÃ]UF/D<8áÖ9bSÐÑÓcðcÿBéíãô¤£ïàèùá>tôÝ:úPe(c³þ-E}¹]Ð'AAGÏPÖ' $}GÏ÷¡£ïÖÑ*Cõo)¢¥Ï~Øê=*(ÛP¾£çûÐÑwëèC¡ãwY§YÜ.è  £g(õ	(IGßÁÑóýÁ}èè»uô¡ÊP2gôBÄs_n­Ø£Òtô=ßÜ¾[Gª%sF/D|ìvqØê=*(ýÿJ{åý.@AG)þo(ño XE(WÕÑ+ÍC'%Vñ7{d(Ðã](9Gÿ§PÐÑ_
# Å9úXe(bê¡òÿsôØ£2=%çèÿt
# :úKá 8G«øÂÁ«jc)B÷ø{ìq¡@¿P¶úñÃ
# Ú+çèÿt
# :úKá 8G«EÑãàñ'eù¿¿ è £_1û¡Ôõã©ûöÊ9ú?]þR8(ÎÑÇ*C}á!W\½Ýã=*(èèoAÉ9ú?]þR8(ÎÑÇ*CIÑ+¥Äqþ¤8G=*(èèoAÉ9ú?]þR8(ÎÑÇ*CI<ú^h%®Ã7u=*(èèoAÉ9ú?Ý¡àöKá 8G«E8zþú"4qþ¤¸3zìQAAGJÎÑÿétôÂAq>VJâ¥vJD'qþ¤8G=*(èèoAÉ9ú?]þR8(ÎÑÇ*CI¼ÓNøÞÑC¥¡ £¿eJ:ú	=~wìÂ@¬£Ì¼û×UµJDs_Ð	Bq{<±GeBGJÒÑOàèñ»z¿uô¡ÊP£§OÑýd}¨RÌ=.+¾!züÒÊÇ·B´)éè'pôxU³_
# Å:úPÅ×^UÝ+Ù]±
# :úBPÀÑO¯Ï_3Ø¦¤£ÀÑãÛ÷Ká XGª%q½ÑàtBPß?±GeyJÒÑOàèñµû¥pP¬£U8£W"$c'ÅÑcËºpôÓôZ>Î¾¦¤£ÀÑãóP÷Ká XGª%qF¯DtÈ×ÁûSb¡ £g(ëP~G¿£~²>TJbê^øÞMÝÇ*CAGÏP¶' $ýoÙ/b}¨2Ä}ôJD'qò)n'ö¨ Ô' $ý6÷Ká XGª%ñd<%¢£¸C±~BGÏPÚP~GïpÛ/b}¨2qFÏæqlûÿë0wF=*(ý(sÒÑÏàèñeaû¥0PfëèC Ìâø~è|ÛÅ«äSftôe~=%éègpôý<tô³uô¡ÊPÆ½ûV"û²»8b~ègtôezJÒÑÏàè9úyèègëèC_.xU}ö%D|Fïvq@ýFÙ×~§³¯9éègpôý<tô³uô¡ÊP2gôBÄç)n­Øã²Qö5££¯¯öqö5'ýoØ/b}¨2Ì½£ëy­£tô· $ý'öKá XGªelÖ¿¥èÍtÿ}ý-(IG?£/äèç¡£­£U"ßù2~|Þ?qº$vÕ{TPÐÑßtô38zCÛ/b}¨2áè)T":yëð×ºÇtô· $ýÏÜöKá XGªEÑÓ!ñ4Kì ¿b
#
# :ú[P~Ggnû¥pP¬£U2¨ÿV"ûÍ)ü«¥¡ £¿eI:úýJ~:úÅ:úP%(8~§Yb%¢OÊbæê»Ç{Ptô· $ýÏÜöKá XGª%3u/D<bÖ¡ßÅ:zèQAAGJÒÑ/àè1`Ø/b}¨â+¯ª["NãÙX¥ìz\*Å,8ú¹}þJÁ¶$ý~%G¿ýb}¨2ñ-òßJÄç)±b=ô¨ ,O@I:úýJ~:úÅ:úPe(â¡weü»â:übNðOìQA)O@I:úýJ~:úÅ:úPe(Â¬óoÊøøÿÄuø7Å=ë{TPÖ' $ý~%G¿ýb}¨2ñûæ¿¥ÌcXbÅ:zèq©øªèñÊïOýÇ)ñtô8úý2tôuô¡ÊPÆ¯ÿV">yt»8lõÄú¤£_ÀÑãIÂ~)ëèCGOÙñÉãbýb=ô¨ ´' $ý¯Ð÷Ká XGªelÖ¿ç¾{F¿¿b
# JJI:ú~#G_¾XGª¥ãwî'$c¥¿bJy=%éè8ú}:úb}¨2aÖé7EøÞíâ>	Ê42=%éè8ú}:úb}¨vxÖ½QöÖ¡¯/W=±Ç¥QÌRÀÑ/åß§~
# %éè8ú}:úb}¨2áèùëklûÿ½zTP' $}G¿£/CG_¬£U9£"(Æ³±Êpôm!(àèu?~HI:ú~#G_¾XGªEÜ"O1ñàDX¿¾¬£õ	(IG_ÀÑoäèËÐÑëèC¡dÎè¹Ü.XåOÊ6²=%éè8úJ¾}±>TJæ^ø8¸SøÃVOìQA©O@I:ú¾£/CG_¬£U9£W"rôÅ:úb=ô¨ ´' $}G_ÉÑ¡£/ÖÑ*CÉÑu(%v{<±G¥?eM:ú}%G¿ýj}¨5sF/D|òÖ!(«uôÐ£²¾tô+8úJ~:úÕ:úPe(3z!â¹¯°E÷n'ö¨ LO@I:ú=ïìÂA±>V_DE¸uú¥">z\Í1ü«ôh¼-=å,+Zúúû?}L%iéW°ôûìÂQ±>V8§ôK8S	U¦© §¿E%ééWðô<ý:ôô«õô±ÊTÄ	<SI¼Þnã°ÕTTÐÔß¢4õ+úJ¦~úÕúXe*ã¡úo%â¤8¶BTì½ô+ºz¦®þ¤«_ÁÕWrõëÐÕ¯ÖÕÇ*S;öo%â3áÕ÷ÃVOlRQA[JÒÖ¯`ëÙúuhëWkëc©}÷­D<>b*ö¤~E_ÏTÐ×ß¢ôõ+øúF¾~úúÕúúXe*ã;å¿¥?+î÷±º4öLý-*Ic¿±ÇýR8*ÖØÇ*S?üî[x¦xµÎ~5'ù'6©¨ ³¿CeK:û
# =Ú§ýR*uö±JT6aí)Ã"kÙy?lõÄ&ï6¦%ß&¼%­ýÖ¾µßÖ~³Ö>VJæ´^xVÒmã°ÕTTÐÛß¢ôöxûFÞ~zûÍzûX°íô»"Dmö¸>6JTÐÛw¢Þ¾¼Jù8qÙÞ~o_¨û¥pT¬·U¦"l;BÄ¿ö±¢bÿM**ËTÞ~oÝýR8*ÖÛÇ*Sö4Ú"D|¹ÙûÍØCKðöeZ^?»pKzû
# ¼}#o¿
# ½ýf½}¬2ñaü·qf¢k°P¥[ IEe}JÒÛoàíñ£»_
# GÅzûXe*b¾%¢3¯°S±ÞTT¶'¨$½ýÞ·³_
# GÅzûXe*·ÙIÿÚÛûê7ãüOlRQ©OPIzû
# ¼}'o¿
# ½ýf½}¬2ÄêÏ7s,@£D¥
# ©´'¨$½ýÞ¾·ßÞ~³Þ>VJâ
# õRÄ~ÅÎáÇFJRéP©Io_ÁÛwòöuèí«õö±JTjâõRDÛÆa«'6)¨@7©$½}oßÉÛ×¡·¯ÖÛÇ*SÉÛÏÅV¹óþÄ&é	*Io_ÁÛãóýR8*ÖÛÇêLT·§ß!âÄ¥÷~Ä*ýÚCK§t²¢·ßJÿ8¬Io_ÁÛãvöKá¨Xo«LEØvJ\ÓÉ°]Uëí¡IE½ý-*Io_ÁÛwòöuèí«õö±ÊT·§tRÈEVëíÝ&OlrÁÿ?ðï©Ôeý8¬Io_ÁÛwòöuèí«õö±ÊTmg*BD9XX®ÁÜ&OlRQAoJÒÛWðö¼}zûj½}¬2ÌCð§)b+DÅlòÄ&ôö·¨$½}
# Þ><±ç¢2ôöÕzûXe*Â¶Ó4ñ<ÛÆ«ü»Þ© ·¿E%éík*äíëÐÛWëíc©ä¿çÁÂB4;ª|eÞ© ·¿E%éík*äíëÐÛWëíc©d/D|WµÞÞUOlRQAoJKzûö*äíÛÐÛ7ëíc¨´Ìð¼½ÛÆ«D¥¡·'*
# ½ý-*Ioß& BÞ¾
# ½}³Þ>VJæIøJDÓßÍ¸÷%*èí
# zû[TÞ¾Í@¼}zûf½}¬.DelÛ¿Ï"º?b?+±ÉWx?ÐÆÔ×¶¶ôöm*äíÛÐÛ7ëíc©mû·ñ¹½ÛÆa«'6©¨,OPIzûV
# yû6ôöÍzûXe*ã§â}K]¹mÐ(Q)C*å	*IoßV BÞ¾
# ½}³Þ>VÊxÜþ[øÔ+¶BTìÓð¡ÉÙö´ñK¥Ïg'[ÒÛ·
# ¨·oCoß¬·U¦yxq"¿ÒÌ©þM**ÛTÞ¾·ÇÿîÂQ±Þ>VJæÜ^x",ÄTÌ©þM**õ	*IoßÀÛãvöKá¨Xo«L%óÒz%b¿bgò=·&ö¤·oàíÑPìÂQ±Þ>VJæ­õBÄ­nG¬òqRéPéIoßÁÛã¶ýR*ÝzûX%*]É"<rÛ8lõÄ&þzJÒÛwðöøÁýR8*ÖÛÇ*SÉÛÏ¸¸m¶zbÊô¤·ïàíñGt¿õö±ZÊø
# vßJÄçön­ØdÁÿcüÀ¿úV¶åãÄ¥'½}oW¥û¥pT¬·U¦2¶íßJÄga!J\Ü&OlRQY ôö¼=ng¿õö±ÊTÆÏÇûV"N'Ý6X¥_ûÞ©'¨$½}o?·ïCoß­·U¦"¼=%ùJDç+a!:_éÖÛwôö¨·ßÖõõñó&{ÒÛwðöøí±_
# GÅzûXe*ã÷ÒKS±ÑëæTÿÄ&í	*IoßÁÛÏäíûÐÛwëíc©dÞ^/D|ê[!*ö~ûÞ©Ô'¨$½}o?·ïCoß­·U¦y}½ñ<X7îý°<±IE¥=A%éí;x{¼*Ý/£b½}¬2ñcï¿g'Ý6[=±IE¥ÿ¿Sé¯·ÿÓ*èí/ÅÿM%þ
# ¤U¤ríD«á<XícÓIl©@w©ä¼ý.PAo)çí¡ÊT÷Û+Ý	­éÿfvbÊô·ÿÓ*èí/£â¼=TW¢x<¾¡ñgÅy{l²àÿ9àßO½¾¶öéÝýóöº@½ý¥pT·*S¶|%¢Ì8.ÄTÜL>6©¨,OPÉyû?] ÞþR8*ÎÛC©ßOÿ­DNÚm±ÊTÀÛãWÆüõ_*ÓZ>=·ï¯·ÿÓ*èí/£â¼=T°íèWÎí¡¢âfò±IEe}JÎÛÿéôöÂQqÞªLEÉcf,E8âo0çí±IEe{JÎÛÿéþKeAo)çí¡ÊTÆ/´û"þ]q÷ÛÛMØ¤¢R óöº@½ý¥pT·*SGò8¦Dä"ãBLÅy{lRQiOPÉyû?] ÞþR8*ÎÛC©$fò¥W·UþµïC*ý*SÒÛOàíñÿû¥0T&ëíc¨Ls{%¢É£¸ý®¸MØ¤ 2½ ôöx{üÿé~)ëíc©$Îí&âBô
# æª'6©¨LOPIzû	¼=~1ìÂQ±Þ>V7¢8·W"Jòí6X¥o0h²àÏëüõ_*[]>¦èSÒÛOàíòöÓÐÛOÖÛÇ*SIÜo/Eôk?YoªüYYTÐÛß¢ôöxû¼ý4ôöõö±ÊT÷Û+ÍÅøÌÝoMü$þÀ¿ÿ¥R×þé¹}Þ~o¿·Þ~²Þ>VJâ~{%¢S/»ÃVOlRQAoJÒÛOàíòöÓÐÛOÖÛÇ*SGò¸(Sqçö±Êß`Û
# zû[TÞ~o_ÈÛOCo?Yo«L%q¿½ÑK\WÜýöØ¤¢Þþ¤·ÀÛòöÓÐÛOÖÛÇ*SßJÿ­D|b*îxØ¤¢Þþ¤·ÀÛòöÓÐÛOÖÛÇ*SÉ+ÍNB+DÅÛc
# zû;Tæ¤·ÁÛòöóÐÛÏÖÛÇ*Qm§tRhZA*³qþ'6)¨ÌèíoQIzû¼}!o?½ýl½}¬2Ì¹½ÑDk\¾Á\õÄ&ôö·¨$½ýÞ¾·Þ~¶Þ>V+Q¿Þî[è,,wàÙMØdAðÿ~êm®íãi9éígðö¼ý<ôö³õö±ÊTÄýöôk/D|B<[o%*èíÊò¤·ÁÛòöóÐÛÏÖÛÇ*S?&ï[ÈÛÇV»ßTTÊTÞ~o_ÈÛÏCo?[o«L%q¿½ñ©ÛÆa«'6YÐLÿÀ¿ÿ¥²l¿S¢ÏIo?·/äíç¡·­·U¦¸ß^8ÉwÛ8 Q¢Þ©lOPIzû¼ýJÞ~zûÙzûXe*Â¶_Q"þµ·ÞÞmòÄ&ú¤·ÁÛ¯äíç¡·­·U¦"äé|Exòh¶ÞÞmòÄ&ö¤·ÁÛ¯äíç¡·­·U¦xN¾ñ¯½{ÝäM**ý*KÒÛ/àíWòöËÐÛ/ÖÛÇ*QYÏÒS">·_ì¹½«Ø¤ ²¼ ôöxû¼ý2ôöõö±ÊTÏÒS"ÒsÛ8lõÄ&é	*Io¿·_ÉÛ/Co¿Xo«¨dÎíÎWÂBô
# ¶Øs{h²àù´1õ^Zý8qYÞ~o¿·_Þ~±Þ>V°íäíÏíëíëí¡IEeyJÒÛ/àíWòöËÐÛ/ÖÛÇ*SI¼ß^øÔk1S÷G¬ÒY$4YðçõÚø¥²Öò±·_Þ~o¿·_Þ~±Þ>V8·'¿"D<;b*«¥²©¬OPIzû¼ýJÞ~zûÅzûXe*÷ÛK]»m¶zbÊö¤·_ÀÛoäí¡·_¬·U¦"Îíù³xN>´BTì¹=4©¨Ô'¨$½ýÞ~#o¿½ýb½}¬2aÛé,RøÜÞmãU¦ÒTÚTÞ~o¿·_Þ~±Þ>VxLS"¾2¶çö¡ÊTúJJIzûÞ~#o_Þ¾Xo«D¥#y:"ööa!ò+Åz{hRP)¯'¨$½}o¿·/Co_¬·U¦"fòÉOèÌUOlRQ ôö¼ýFÞ¾½}±Þ>V;QÉÜo/D<M[!*ÖÛôö¸Ä6æ_ }þ8q)Io_ÀÛoäíËÐÛëíc©mû·ñYdX¦)qþ'6©¨,OPIzûÞ~#o_Þ¾Xo«L%s¿½_qÛ8b©·GðýÊT?~Nþ/í$ðöyû2ôöÅzûXe*gé)Ï¸ãÞh¨¬C*ëTÞ¾·ßÈÛ¡·/ÖÛÇ*SÉÜo/D|Bâ_{{nM**ÛTÞ¾·¯äíËÐÛëíc©mû·1{n_ó?±IE¥>A%éíxûJÞ¾½}±Þ>V8·ç+ãÄsòí6Xåß6¤Ò ôö¼}%o_Þ¾Xo«Le|+ý·ÑYd±çön'6©¨ô¨¬Io¿·¯äí×¡·_­·U¢²fî·W"òöa!º2^ó?±IA%¶qJÒÛ¯àí+yûuèíWëíc©dî·"q­S=±IEezJÒÛ¯àí+yûuèíWëíã
# /¢x¿½·_í¹ýjÿM4Ó?Ðä/­×ïì^Þ~o_ÉÛ¯Co¿ZoW`*âÜ?+ãòÿ1ëí¡IE½ý-*Io¿·¯äí×¡·_­·+0·W"º2^í¹}ÜQAoÏÉ&yÔöñsòûôö+xûJÞ~zûÕzû¸SÉ<KOØ¯¸m±ÊôöL½ý-*Io¿·¯äí×¡·_­·+0aÛéÊXøÊØmã°ÕTTÐÛß¢ôö+xûFÞ~zûÕzû¸SI¼OÄ5=·wÕTTÐÛß¢ôö+xûFÞ~zûÕzû¸SI¼OøÜ>.DT¬·_ÑÛ3ôö·¨$½ý
# Þ¾·_Þ~µÞ>®ÀT2ÏÒ"á"í³ôV{n¿¢·g*èíïPÙÞ~oßÈÛoCo¿YoW *[f&_8!·ÉT6ôö·¨$½ýÞ¾·ßÞ~³Þ>®ÀT2Þ^ø,2,D~ÅmòÄ&ôö·¨$½ýÞ¾·ßÞ~³Þ>®0ÌýöJDSz=·w<±Éqàüûù5-¯ùãi-éí7ðö¼ý6ôöõöq¦"l;MS(VÌ6[=±Éqàüû©´Ï¿%½ýÞ¾·ßÞ~³Þ>®ÀT23ùBÄÓßº?ì&OlRQ)OPIzû
# ¼}#o¿
# ½ýf½}\ÛN~ExJÏmãmuHe}JÒÛoàíyûmèí7ëíã
# L%3/D<Má¶qÄ*¯@Êö¤·ßÀÛwòöÛÐÛoÖÛÇÊØ¶+ßUä¶qÄ*ùhRQ©OPIzû
# ¼}'o¿
# ½ýf½}\©ÿ-EìW¬·Uþ¬´!ö¤·ßÀÛwòöÛÐÛoÖÛÇJâýöJÄ3ùq!¢bª'6©¨ô¨Ô¤·¯àí;yû:ôöÕzû¸Q©gé	ßC\ÍÉüÛ@*Ð¤ R_OPIzû
# Þ¾·¯Co_­·+0ÌL¾ñxa!:õr<±IEezJÒÛWðöøß|¿õöq¨|ò+BÄéd5S÷ÝäM<ÐøÿK¥¿¶§)jÒÛWðö¼}zûj½}\©q{þoOgq!¢bÏí¡IE½ý-*Io_ÁÛwòöuèí«õöq¦9·"N'Ý6[=±ÉÇL?ðïÿ¥Ò?{AMzû
# Þ¾·¯Co_­·+0Ì¹½q:é¶qÄ*VÖ!ôö·¨$½}oßÉÛ×¡·¯ÖÛÇJæ9ùJD~%,Ä¿+öÜTTÐÛß¢ôö5zûéEÞ¾½}µÞ>®ÀT2ÏÉ"ÒsÛ8`D¥© ·¿E%éík*äíëÐÛWëíã
# L%ó,=!âÉ#·ÃVOlRQAoJÒÛ×TÈÛ×¡·¯ÖÛÇJf&_xv²ù¶ATú
# zû;TZÒÛ·P!oßÞ¾YoW *-3¯DDÅmã°ÕTzû[TÞ¾M@¼}zûf½}\©dÎí&Ü6X¥k0hRQAoJÒÛ·¨·oCoß¬·+,DelÛ¿¥üÛÆa«'6YðHöþýü×iúx¢%½}[
# yû6ôöÍzû¸SßJÿ­DN6ãÞ»ÉTT'¨$½}+@¼}zûf½}\©s{q"¦pÛ8lõÄ&ò¤·o+P!oßÞ¾YoW`*çäz¹m±Ê¿+èíéímE*ýó·´¤·oP!oßÞ¾YoW`*cÛþ­D<ï¶qÀ6
# z{¦²=A%éíx{üÿé~)ëíã
# L%sn/D|¾ÒÌÉüa«'6©¨Ô'¨$½}o?·oCoß¬·+0ÌL¾ñ	±ÛÆ«L½=SiOPIzûÞ~"oßÞ¾YoW`*s{!âf½}³Þ¾¡·g*ý*=éí;x{¼´Ù/¡Ò­·+9·"U¤ªôYéèíJ=A%éí;x{öKá¨XoW`*s{%b*v&ßmòÄ&é	*IoßÁÛc³û¥pT¬·+¢9·W"ÊãBDÅz{h²àPÉüûùµüÚ§)zÒÛwðöøu½_
# GÅzû¸S¶®ÎWâBDå¿ÕBT!å	*IoßÁÛã¥Í~)ëíã
# L%ó<%"oï¶qÀ6JR)OPIzûÞ¢º_
# GÅzû¸SÞ®2c·¶ATÀÛc?ð×©üþ´|<ãÒÞ¾·Ç¯ëýR8*ÖÛÇJæÜ^øÔ«Ûs{W=±IEe{JÒÛwðöxãâ~)ëíã
# L%sn/D<¥âk0{nM**õ	*IoßÁÛãÈé~)ëíã
# L%sn/D<y"*öÜTTÚTÞ¾·ÇëýR8*ÖÛÇJæ~{%â_{{¿}7ÎÿÄ&þÿNeú58),ÿ.èîßÿü$ wÝÎTHßû­¾|R¯ÌÿÂm@9ÿ?aFÿ-±ÕÇE ñÜ<¼TÖ*ô°^øòI½J@Ó#rÿÂ=ÿ[b9×¬(q/¾TQ k­È=Fz]qlî{ýTçéÓqß¿sÿÿ@hÿßÈ¸$¦òñçGªètÌoåðåz0¸(üOaðX@.ÀE aôñLYªhÃoåÀ­0 ð}¸À/ "ù9 \&ð?a¡À[b¹XýRE§þ°ø3;=©WÓ{rñÀÿæoä\D¸K÷ãZÈÅÔ«AÁ=@¹¤àÂÿZ0*xK, à"Pb@ªèÌÆoåðåz03¸(üOajðX@.7ÀE ÄÝüZ%ÿÃïô¤^% îÊåÿ@ ¼%pH`8-U4!kaäæwzR¯&	·MÙ$a$ÿ»¿%ÐäDF³REãN~+ùzU&LîÊ&	$	ØòþX@>I@b"@Iæp°Å¹Ô«IÂ=@Ù$a$¿Õ÷·ÄòIB\dc@"#à¯8¥þ»¾ß·Â0IÀÙìu~eÞ>îøý+Ù$a$aá$a'	Oâ"àËl¥Âi\ù$aÂ$AZM&HN¦q0ù$!."Ï¤Kq-ä^ÓG½J@å@Ù$a$aá$a'	Oâ"ðØTªhJ
# ×b@ÿ-ãs³¨W	h}P6I IX8IÆIÂä¸xº¿TÑa¬%~|0aïÅ^éãþþl0AP8IÆIÂä¸$6ªJ%¾âÜè/Ô«TM&H
# '	Ó8I|R%Î&7àwzR¯P{P6I I($Lã$aòIB\DJ#HÍ¹ù­¾|R¯PÐMfH
# '	ó8I}a@sj&A¨Ä÷l¢Ãïô¤^ ù l0CP8IÇIÂì¸IP*Îâf$¸òI½J@Ó#²IÂIBá$a'	³Oâ"o3ø*q4¨àð;=©×/&ð/üêËëó¡9$Ì$Næq0û$!."ñ	*ñ	òIÛéI½J@$ÜMfH
# '	ó8I}R3	B%Îf$Ì>I^WüÀö:¿ÖßïÏFæl0CP8IÇIÂì¸I*14â¶ràVÐ:´>($Ì$Næq0û$!."i¾Ì*1vÖÂ»GýNOêUÚMfHVNæq0û$!."[Ä'h7ük«8$@¯P}P6I!IX9IÇIÂì¸xRTÕÙ'	n§'õ*µGey$Ì>I@HêýLB(>Ô´de$,>I0 Ed<-Tbp1®EÜNOêUZ^Ê&	$	+'	Ë8IX|2*º×b@¦|R¯Ð l°@°r°Å'	J<Õ@«8,u[9p+*~p_@ë²~>4²de$,>IEPj&A¨ÄªÛÊeþ
# ^% å@Ù$a$aå$a'	O`$2>òV*¾Ìkñêbz0I¸($,$¬$,ã$añI,ÂD ~DÀS=n+n­c@$ÜMHVNq°ø$a@b&}P©«8óæÁÊâ+tÂ?Øë/ mþø·¿%$,$l$,ã$añI,ÂDFÀGÞJÅF5®ÅüÝ
# Ð«IÂ=@Ù$a$aã$a'	O`$zJ\$ø$Áíô¤^% LîÊ&	$	'	Ë8IX|0 ÔLPÑß¸rO@¤^% Ln*Ù$¡@°qPÆIBñI,BJj&A¨Äwñ3	®|R¯
# PÁ$á lP IØ8I(ã$¡ø$a@©¡cWÅ'	¡,Mc@$ÜM
# $	'	e$$ÄE:Óü§Tõ¸­P0Ià¡IÂ6×çC#%$H6NÊ8I(>I@ãû¾¥JÌ$¸­¸I´<($H6NÊ8I(>I@©¡vn+Å¼§úø4Ï¿ò÷¯dIÂÆIB'	Å'	q(5 Tbh$¬ÅQÛéI½J@ë#²IB$aã$¡â¸4¾¥J¸­¸´mÊ&	ÊIB'	Å'	q(5 Tbp1¬%>Aî­	Ô«TM
# $	2NOâ"Pj&A¨ÄwXKø $@¯P{P6I($TNÊ8I(>I@©¡cWÅ'	ÅÏ$@¯PÐMVH*'	ë8IX}a@kâ
# ZÅaéêgBÇ® Wh}=($¬$TNÖq°ú$!."3o©cWn+/Ô«4=($¬$TNÖq°ú$!±ç¯w}0 TìâZÈÏ$@¯+>à{ýTËúùÐÈMVH*'	ë8IX}Ê
# HÄ'($ÄµI^% LîÊ&	+$	u$¬>eHdâIk1 ÷zEêuÅÇFüà_øÔ_°øûW²IÂ
# IBå$a'	«OBYÓlTìÂZ|·Â0I0I¸($¬$TNÖq°ú$! Ä[´J|Å¹÷2`¿{²IÂ
# IBã$a'	«OBYJ¼ AªÄà¢ÛÊáË'õ*apP6IX!IÀ×rïoäPVDF |Èxì*®Å|°b apP6IX!Ih$¬ã$aõIB(+@©¥â,nõIÛéI½J@$Ü´e
# ÆIÂ6N6$²´3o©cWIØ|°aÀ6LîÊ&	$	m$l>eHd|-Tb&!6Ä|°a apP6IØ Ih$lã$aóIB(ãÏÿ×»>I*1<ï¶røòI½®øàüó«.åãÑýþl°AÐ8IØÆIÂæPVDÀÇ
# B%ÒìÍDßéI½J@Ë#²IÂIBã$a'	OBYJÍ8°s[9 ÌQôºâq~p_@e¹ñz-$l$àr÷·ÄòIB(+@b&A|ÄL¸HøïZòIô*­Ê&	$	m$l>eHÜÝÀIP©Í'	®|R¯Ð l°AÐ9IØÆIÂæPVDÀYRñ÷fÜ
# ªc@õ@Ù$a$¡s°Í'	¡¬¥ÞÝ TâDÕmå²øµ1  l°AÐ9IØÆIÂæPVR3	J%>Aþq+¨õ'ÕlP!Iè$ÔqP}ÊPM='A©Ø¨V?PMÐpR¯
# P}=($THð-áû[bù$! ÔLRñ'(¬Å¿Aq+hM*$	ø_K, $2þü½ëã¡3	Õ¾|R¯+>[ê{ýÔ×/¬Ù$¡BÐ9I¨ã$¡ú$! 1mÀQPU·ûe@Ë&	÷e
# IBç$¡êPVDÀa©Pãj¢Ãïô¤^W|ø×þùÕ^Ë×ÓÔlP!Iè$ÔqP}Ê
# 6DÞÀ'ªÕDÅEÂ:´>($TH:'	u$T$²4~¿ã·VñLBõIÛéI½J@Û#²IBIÂ¿LßÆIBõIB(+@©w8ª>Ipåzê#²IBm:NªOBYÓâ"!5b@fdá¤^%  lP;â$¡êPVÄ8I*1¸è¶r@Y|úPPË&	í8Ihã$¡ù$! 6~¿ã·T$Ámå2^ özP6Ihâ$¡æPVR3	B%f³ÝV_>©W	hzP6Ih3â$¡æPÆ¯¥¯w}p`§Tõ¸­¸I4HÚºÞxEZË&	m@$´qÐ|Ê
# Hø*N¨ÄwX¯â\ù¤^% å@Ù$¡ÄIB'	Í'	¡¬iN³Jy»­P.{²IB['	m$4$²$2N³JLõ4$4$4L LîÊ&	m@$´qÐ|Ê
# Ià©¥ ÿ®µ2 $4Lø5
# ­ÜxÁSË&
# ü³¿%OBYJÍifèàð;=©W{²IB$aâ$¡æPVR3	B%f³ÝV(ß L LîÊ&
# 6NOBYÓâ2;5ÐLTpøÔ«IÂ-@=$tHðòvK îPúøýßR%f³»
# ìuLPÇ$á lÐ!IÀÝý-±|Ê
# PêB%æâbCÈ?q±c apP6Iè$ 7ßßÈ'	¡Þåë]Ø	Iè~&! Hð	¡?Øëïeï´ÝxÉ`Ï&	Xö·ÄòIB(+@â¾¾H*qÜÐ}àÊ'õ*-Ê&	4û[bù$! ÔLP4»û·Óz]ñ®?ø~ÍåÆëiz6Iè$L$ôqÐ}Ê
# Pê9	B%NTÝV_>©W	h}P6Iè$àuÑþX@>e(õ¡Ç
# n+/Ô«´=($tHfNú8Iè>e(õ¥â4;6ÄüLô*ÕGeIÂÌIB'	Ý'	¡¬¥fJø ÿ·ÓzÚ#²IB$¿û÷·ÄòIB(+@©¥â¹¸nn_8 ,>A}¨?hz%?aDIÂ%1â_!@±Ì®ºýU*µP, ìU^oJ&	ÂKbÙ$! ÌLTQXj·r@YÆ¦G%?aDIÂ%±lËøþë]÷3	JÅv°²IöºâC°×_@uûüiÓ+$ü	 J.dXVÄLeqJÅi¶ÝÊehÂ$á dð'(I¸$MbYÊ<'A©ø<ÈnåÀ~$	øê\àP[?=ÍôJ&	ÂKbÙ$! Ì»¤J²ÏIeñ	ZÇ0I¸($ü	 J.dXV2ïnP*»²[9|ù¤^% LîJ&	ÂÿÂgQíodXVÄ´¸Hw7Qµ[9°_TÇ0I¸($ü	 J.dXVÆÁ·Tñð<¬ÅÌÍ'õ*apP2Iø@$\È&	±¬i\T*>QM°W[¦l0AÿÜßhòIB(@Sæî¥âÙl»ÃOêU0I¸($L$àý-±|Ê
# Pf&Aªø+.6Ä|½J@$ÜM&Hð?ßþX@>e|Úþ×»îOTJ|Å¹­¾|R¯+¾ÊâÿÂ<½þý>M&Hð?ßþX@>eh|KÙ­P L å@Ù$a$¢º¿%OBY¿ßñ[ªDX:Ûìa Ge	i$L>eh|ßÂ·TñÐH\F _I´>($L$,$Lã$aòIB(+@"#Wqç$@CÈ'	&	Ð l0AP8IÆIÂäPV2oT*>Qµ[9°_ITM&H
# '	Ó8I|Ê
# P*IP*\k¯8ûìUjÊ&	$	i$L>e(3 UÂýw-q`ïnÀ^% þ 9$Ì$à¼÷·Ä}ÊÐIP*¾Hp[9 ÌÙ3&	(.pP6I!IÀGîoäPVDFÀÇ
# BÅq-þMÐpR¯+¾Òï{ýPÿü9	ÓMfH
# '	ó8I}Êè´¾ÞõÁªPñ\\\Kò3	3&	aPÖÏ_Ó9ÍÙ$a$¡p0Ù'	¡¬>*1à¶r@YÂ$AÂ$á l0CP8IÇIÂìPVÄL_fIMTpàV&	&	÷eÂIÂ<Nf$²$¦
# 8*q=û$aöIÂIIÂ=@Ù$a$¡p0Ù'	¡¬¥fJ¸­P^&	&	÷e|ÌíþX@>e(5 TâÈ{6QÁáwzR¯&	÷e|þÖþX@>eHL$T<Y:û$aö3	3&	&	÷ey$Ì>eh<mð-UâDu6C/Ô«IÂ-@K6IX IX9IXÆIÂâPñ³¿µìbChñIÂIZ0I¸($,$¬$,ã$añIB(+@w7HÕÅD/Ô«IÂ=@Ù$a$aå$a'	OB¿ÞõÁqP°4®Åþ[æ«8èuÅbþ`¯ó¿÷D®gqK6IX IX9IXÆIÂâPVR3	JÅaéb¢ûe@$àK1°×ùßYàÏß£:-Ù$a$`·¿%OBY¿ßñ[ªÄLÛÊ[a@e¨<($,$àÃiö·ÄòIB(+@"#_qã¼á¿ÃOêUZMHVNq°ø$! $ðÐR	@>Ipåz¶Gee$,>eH$	lTJØÅµI^%  l°@°q°Å'	¡¬¥fìÜV(ÔÆÚ#²IÂIÂÆIÂ2N$²I*1YÖ¢ÊB¿¨õ'lP IØ8I(ã$¡ø$! y¤R±«°¸Ô«T^Ê&	|@ÚþX@>eHdü¤Tü×b@öÝ
# Ø«4=($$TqwîzÃwáþðW Sþz6H¨ÄE[ê2ÿQ«ôAX`_¯;Ï±(Ù ¡,ÀmPYÆ||àÊ_ïòèó#r¶©a)ñùñ	Ôªà³<Â'#|Ø2æãsWþz#=B%b·Ôe¨U~E\àÏ´,7¾ß²1B1B·xuÌÇ®üõ.&z
# ö,%.ü3¨UÁg}O6E(ðaT¶1"¸ò×»<*qâÔíä­
# >Û#|²!B©À-P©c>>Dpå¯wyc8	*~Áíä­
# >õ>Ù¡4à#Póñ+½Ëá!¾ßDÀAn©Ûe>ØªàÓáJ>Âõ1!¸ò×»øðIªP:·Ôeñû­
# >ý	>k6AX_ÀOR××ÏêWþzÓVJÅ©[êðåS´Ê|â_¸Í' ¬ðáÔuóñ+½ËT©xÔ-uøò)Z|¦Gødóòqo÷:ÎVÄEÏxÄà[ªÄ-
# n'/ÔjÅWþà_çi¾3)²fóòqk÷:ÎVÄEH8 *ü°ÿK±ÿYM¼pR«Ïl~°B~ îì^ÇùÁêóÕÜeðõ.fJä£n©Ãoô¤V%l~°B~ nì^ÇùÁêóóIMBXM@pøòI­V|Óï¶úËg)ËçùÛÍVÈÄ}Ýë8?X}~a>©!¡£¤«ÏÜFOjUòÙáÍVÈÄmÝë8?X}~°Sÿõ.»dí[ªÄ]XJð±ïjÀV%l~°B~ îê^ÇùÁêóÕ¸ö¯wy0#¢Tâ÷Çç®|R«O{O6?X!?7u¯ãü`õùÁjÎý¿ÞåÁP¡ø×oæE'µ*ùô'ølÙü`ü@ÜÓ½óÍç¹¿àë]Ü$Tâv:·ÔáË'µªøl¯Gødó
# òqK÷6Î6ÄEOêéJÅ×on'ù÷Z|¦Gødó
# òqG÷6Î6læî¯wyp>'Tâü',Åßo?V+¾ù[ýåÓîÌlÙü`ü@ÜÐ½óÍçqí_ïò`>D©8¿v;9|ù¤V%ÌîñÉæäâ~îml>?ØÌ©ÿ×»<?*1¿³ùü Åçò|Eö¶úË§öùÓc·l~°A~ nçÞÆùÁæóP|RÏC*_o>?påZ|0?¸Ç'l»¹·q~°ùü >ãÇ/þK	>¦|R«æ÷ødó
# òq3÷6Î6læÆ¯wyp¾-TâüÔíäòÆ|êæ÷ødó
# òq/÷6Î6²à#æÄõµÈØºØ.óic>ÜãÍ6ÈÄ­ÜÛ8?Ø|~°×þõ.ÎOJÌïlfÀàÀvOóÁüàÍ*äâNî:ÎªÏBùÔT~ Tb>Ñíä2ÿþ@«OÅüàl~P!?7r×q~P}~ÊOêþ¡ù¨ÛÉeÁgóÁüàl~P!?÷q×q~P}~P©ÿzóJÅþ§¨âÀvæïTÈæùuc>¾fó
# ù¸»óêóP|ÆÉÀ·Tóm·Ûe>>Ë#|²ùAü@ÜÅ]ÇùAõùA(>â|}­TâócÃOjUò)ðÉæòqwçÕç¡,øü¯ßJÌï¥*óñOA¨>ë#|²ùAü@ÜÃ]ÇùAõùA(>"àù*¥âùjF(ÏæÏl~P!?·p×q~P}~Ê?`ªTìªu8 ,ø`~ øÔGødó
# ù¸»óêóP|ÆIü*1âvrøòI­V¼ùÁ¿ð/~c¾·fó
# ù¸»óêój¾ÞåÁüPóíêóêóùàÓàÓ²ùAü`ãü óæóPf>M$ìOJÌ4?Ð|~Ð0?`>íl~Ð ?Ø8?hãü ùü NÄ|¯Rñç'öÃ||~Ð0?|¦GødóùÁÆùAçÍç¡Ìoßl©;*_¸Ø.óÁü 1ÌÊ¶ÏùdóùÁÆùAçÍç¡,ø¤æJÿ¸Ø.óÁü@ðÁüàl~Ð ?Ø8?hãü ùü 1YÀùPóæó·ÑZ|0?¸Ç'4È*çm4²à#ò*1¿||~Ð0?à'ù6ÌÖuþüþÍäó6ÎÏBYðÏ?qÊð,%øøûææ÷ødóù¾zK,²àºA¨Ä|UóùÛèI­J>ÜãÍäó6ÎÏBYðIÍ8KÏbÃü@ðÁüàl~Ð ?¨´q~Ð|~ÊOjþ@©ÿñÏ?h>?h>ÜâÓ³ùAü_c¸¿%O÷ùA(3?P*?p;9 ÌùóéÜãÍ:äøÃý-±||~ÊOjþ@¨Äù\7QÅí2ÌÌîñÉæòÊùAçÝç¡ÌïÜì©ù¥âß·Ôá7zR«ÿðaW½ñRÔÍ:äó>ÎºÏBYðù_é& 8üFOjUòYáÍ:äøný-±||~ÊÏx²à[ªD~ívr@Yüþ@~?¸À/i½ñÎÚÍ:äó>ÎºÏBYðI=ÿ@¨D~ûa>¦|R«Ïl~Ð!?hôq~Ð}~ÊOêùB%æG»Ïº8©UÉg{O6?è4Îú8?è>?èæ®¯wyp>'Tb~§Ûe>uÌ§>Â'tÈç}t²à3N¾µÏºÏÜFOjUòiðÉæòÆùAçÝç¡,ø¤ Tb¾ªàðåZ|ú|~/ør|þåÄðøÄ2ñ¹Ê~þM©x~'.Eþ4éú
# [| ÕÛ|ùÁ0ð¡üàX>6?eÁ'3 T<¿¢ï7»ÑZ|¦Gø$ó?aàCùÁ%±|l~Ëô¦Í«ìÏ¤~ìNlù@~OÃûÁæ¹Ìíõq¾3¿ùÁ0ð¡üàX>6?eÁ'3 UäOãRâócÊ'µ*ù,ðIæÂÀòKbùØü Ìó¤Î·ãR?ÀVéi?ø~ù,Ûçó½ó+ü	ÿËßØ±¿%ÍbYðÉ<ÿ@©øü'.E÷gÅ²øü¬c>ë#|ùÁ0ð¡üàX>6?eÁGäâ÷GääO¡æcç°UÉg{O2?ø>\ËÇæ±,ødæ¤J|¿Ùù»ÑZ|ê#|ùÁ0ð¡üàX>6?eÁ'ó
# G©¢ó¸øý±óØªäÓáÌþåÄò±ùA,>âÉ¿)ÏWÅ¥³ÑZ|ú|¦l~0A~oÿÛßÇgòùA(3iüdÄo©âó¸çÏ UÅgz=Â'LtÎ¦q~0ùü T~ Tt¾`wrøòI­J>Ó#|²ùÁùAçü`çÏBÞ¯yýüRñù\\ÞPËâóù>íó[ýåÓÚúy¾3eó	òÎùÁ4Î&²à#¾¾*?KñïOlù,c>ÜãÍ&È:çÓ8?|~ÊOfþ@©ø|..%øØ÷7b«ô4ÖlõOÿ÷ëíc>Ùü`ùÁ¤7q~0ùü ÌüRñüµÝÉeñýùàùÁ=>Ùü`ÚçÓ8?|~ÊOfþ@©ÄùÛÉáË'µ*ù`~pO6?*ðáü`çÏBYðÉÌHÆ¥8ÌxÂI­J>ÜãÍ¦|8?ÆùÁäóP|2÷/(Ï@?ÌÇÎ`«æ÷ødó©Î¦q~0ùü ÌüTñùvXJ|~ìü¶*ù`~pÏÍæðáü`ç³ÏBùÌ©ù¥b:àð=©UÅgÆüàl~0OÀóyÌ>eÁ'óþ¥âùø¸ç;®|R«æ÷ødóy>Ìãü`öùA(wæ#ò>?*q¾ívr@YðüfüÌóZz¹Á'Ìðáü`ç³ÏBYðÉçB%ÎOgPæë7hUòYáÍæ|8?ÇùÁìóP|D~ÀþG¨ÄüÛÉeñù)c>å>Ùü`ü¿Xö·ÄòñùA(>bþýPëëØó1Or<©UÉg}O6?!?À7ªìoåãóP|D2ÀùPóÓ°¸~3o8©UzZû¶úïí¿äs>Ùü`üø¼¿%ÏBYð'ßZ%®ßìûbYüþÔ1l~0C~_éû[bùøü ëqÊð,ÅþÔmô¤V%l~0C~_üû[bùøü 1 ®Äü¸>°Ï?°åZ|ú|l~°@~_üû[âø,>eæ³d TbþÚíäðåZU|×#|²ùÁùý-±||~ÊOjþ@¨ÄüNX¿ßb»ÌgóáÍÈ&Îq~°øü _(5 Tâ.¬E@e¾@^éqí?ØÌïõÜ«·Ïäl°@¤ÛßÈ±,l¡	iX¸Pæ+lèUZMHð?ÌþX@>Ae(5 T|Dç¶r@Y| BÀêÿà¿¦¶~>bµd#"#e!,>Be(5 Tâ;¬Å5Å'hZÍÈðKcK, !Ä²4~=ã·TCºÅ¤/Ô«´=(","àÆþX@>DeH<ßOJLÁÅyÄI½J@õ@Ùa¿Zö·Äò)B,@Ç (8¦[Ì}
# /Ô«Ôð«eK, #Ä²y¢R9E·ÊPêO*Ù¡@WOû[â#Ä2*©A¡òn+ôª×#²AB ¿Zö·ÄòAB,@©I¡òÅDßéI½J@Ó#²IB$ÿÃìoäXHø*N¨ÄW\l7=Ô+½âùT_¿*c.Ù$¡@_-û[bù$! D'T"+u[9 ,¾â0I0I¸($HðÇyK, $Ä²zPÃºØòIBÁ$^ÆÍü¨¿>?ì.Ù$¡@°pPÆIBñIB,@"#àËl¡§Ýa-ÎâÜNOêUÂ$á lP IÀë¢ý-±|ËPjA¨Ä¸HñIÛéI½J@$ÜM
# $	'	e$$Ä²G*qÞÖ|P0I0I¸($HNÊ8I(>IeH$	*Ø$Ä~&	&	÷eI:ý-±|ËPj"A¨ÄÄb1QÁý2 L LnZ³IÂ
# I^Þîo´ú$!Ð:¾Yá[«ø+.6D\ù¤^ {²IÂ
# ...
# Êþ;$¡© Ë#@¢¦ÀÔñÑÎë±@´©2BLÝ©1u3ß~OÚÔ:5õ¦ÏI]Ï¢MÝ	âàþg/KùÍÅ$T|2¦NäGDM=©ãsR×3bhS7etËýö;I~|Bô}ê	L´þKýRæåó§¥¨©'0õîM=SOÚÔM	Ý§NR¤tOÝ	:¦~HÔÔz÷¦©'mê¦LîS')rÈAÍd2ÒÆ@ÐÔïzSïÞÔ1õ¤MÝ	Ð}ê$EN.&mêj¢ûemú- 9jêLí¼$kS7e$S÷_ê$EÎöªlPö¦ÁÔñå_8À7úêwsÔÔ3:>'u=#6uS&@Èéw¿uBRäÉ¦Ëûemú= QSÏ`êøÐÁõX ÚÔmùånTg)ÿ­®¦²A|D@ÕñQë_8@~õ)}þ¶£ªAÕñ©ë±D´ªÛ2!B,ÜwDHl/fíêj¦ûeqÈ¨«gpu|ÊÝzF,íê¶LnU')Ò£RSÙty¿,NIÊzYÇG­gÄÑ²nËñpÿK¥üc:¾AüÕÊc"ù"Q[Ï`ëøõX"ÚÖm!ºN¾ÙIÊËüÕÒõºîo£Ê ë}?U[ÉQ]ÏV×¯íÑõ¬uÝ	Pg¤Èé¬,Zçé~Y R!õõÜ÷õL|=k_·eB$t»:IÓ@f,BD>þwqH{HTØs"^Ø3ö¬Ý	Po¤ÈR3!"ß«þ»8A¤?A¤D½¼7öB½hc·eO¤e÷>BRä¾5
# Ê~S« ²û[©
# ({_¦;D¢Ê^& â½e/ZÙm	u×I?QSÙp:;!2=B$êìe"ÞÙqö¢Ý'OØ¸ßÖ")Ò^/BÊ7]Þ/û¾¸ãóMäÿ÷¬J$êìe"ÞÙqö¢Ý	Ò_'µÙûï5
# Êä¯8;¾¹ãø&RóëÆg$êì%ïì8{ÑÎnËqvÿ[¤HÝE>#ÚÙKAg¿G$êì%ïì8{ÑÎnËy<ù«EÝwGvv5Óý²8Aý¨³D¼³âìE;»-"ã×±½iì4Úx"ºÅ^Ê:û="Qg/àìøÃh=#vv[&Dû]"=ö¢{ìj¦ûeq± ³·åóW±uöÎÿcÖ3bhg·eB8»ßi$)Òd·+ðD´³6&Î~HÔÙ8;þäYÏ%¢Ý	±¿i4uÕT6(_¿}Lýuö
# Î?yÖ3bTíì¶ìÔñ+ÙÞ<å÷µªè£oPöß#õ5$RÑÙï:{gÇ/ØõX"ÚÙm!}vV¤Èá¹*¤|2!2 ³ß#uö
# Îê¼KD;»-ÏÈøro"{¿j*.ïÅýG¿þWÈÓ«ÕgjÔÙ+8;þà_Ï%¢Ý	qýMS¤Xo¸@O¿þù&Òó³(5êì}òÎ^³Wíì¶L4ÇRþ·VÕÎ®fº_'¤GD½³OÞÙ+qöªÝ	±¿yÊ÷«vvUÞ/Dò#D¢Î^ÁÙqÉë±D´³Û2!2~Ü¦È}
# f,,^Ít¿,N):{gÇ?ë±D´³Û2!2~Ü¦Èé 5M÷Ëâ"¾?b¯§én<@¶F½³ãþõX"ÚÙm!ÎîwQXÊw¬ªvö*ÚðûeqH{HÔÙ+8;6 Ö3bhg·eB÷ÎNRä©|hg¯}L¤?A¤E½³ãóõ"M;»-{"mü ¹7MMHùeO¤½Dìbn:{gÇ»¸×3bhg·eBdü$¹7Mf,ÿ.é¦½³ãÛn¾p1ßD¦åÆCd[ÔÙ8;þ¡^Ï%¢ÝO$ôhx"ý5
# Ê8;¾;âø&ê-êì
# }öÎÞ³7íì¶Lx'{¿$EzM;»)û'=4pv|yÄ.æH.éÆg$êì
# ^®gÄÑÎnËé³ûF"{¿v~ázKc"é"Qgoàì¸±KD;»-"¡;ÙIôGÌX~E÷Ëâ¨³7pv¼·~=#vv[&DÆ6þ¦)ÒÕUSÙ L1¨³7pv¼Su=#vv[&DÆ6þæ)òÑgãhÃïÅD²'Î^þ}ÓÇD¢ÎÞÀÙñÎÈõX"ÚÙmÛø¦H½	)ßty¿,NAg¿G$êì
# ò¬gÄÑÎnËÈØÆß<åû#j*.ïÅ	"èì·ô¨³wpöÅ;{'ÎÞµ³Û²'ÒC/s#)ÒÕíºÏ®Êûeq'ÒÑÙï:{g_¼³wâì];»-"ã;Õß<å?#j*½!vpv|U×ðM¤.õó®n:{g_¼³wâì];»-'O8;ùßoº¼_÷|ñÍ.&Oó«Í7>#Qgïàìx¯êzF,íì¶Lîgg)¿¯eÆ"µôÙøÎo¾ùÂÅ|¾!}N$êìïúZÏ%¢Ý	Ðýì,å½ë>»é~Y !uöÎ÷­gÄÑÎnËÈøNõ7M];»*ïÅ	"ù"QgïàìwöN½kg·eB8»ßûe)ò¡Ãï.ïÅ	"å"QgïàìÉ;{'ÎÞµ³Û2!zû:IþÊeB_Øõ|ó×¿ô¨³wpöä½gïÚÙm	ÝÏNR¤««¦²Aic"í"QgïàìxgäzF,íì¶LSï~_¤ÈY»OD;{ïc"ý"õtö !âý\ØÿÌ²#rÔuW¥ü¡°$"gº_÷W"pÛDÎþ4D³KD:;	Ògw>ÂRþËýÖz"àìøÁ/\Ì7%}þ
# ú
# :ûOÐqÎ~D,éìPÎHät,å÷µìXtößÅDÜF\Ì4Vo|FÎþ4D³KD:;	±¿iÊ|SÙ L ³»ÓA¸i®5Ýøý'h8g?"tv("Æ³7D;ùHgÿ] Î~HÐÙsö#bHg2!2>õþ¦)ßC´c¹óZ¶L>#èì:û="Agÿ	"ÎÙ%"ÊHäl<Kù>»Ë9»,ïÅ	"èì÷ý'x%³KD:;	Èýì,åOÙùv·ßÅDÜF\Ì4·òúøäC}ý'h8g?"tv("ÞÆý	:ò}v9
# Ê:;!Î~HÐÙsö#bHg2!2¶ñ7Mù>»|FäÙøßÅ	"èì·LQgÀÙ³wö8û¤Ý=iüt¹7Oy1cy"j¦ûeq'2¡³ß#uö	={g³OÚÙmôÙYÊi´c"ò¹ñ¿û¾$õË-f{úüí<u:ûÎ½³OÄÙ'íì¶\<Òg÷»($åûìv,BD;ûÎ¯üÂÅäiûçw+Ô)êì8;Þa¿KD;»-"ÄÆ½!ß·cyCT3Ý/;¸ÓApo"Km7>#QgÀÙñ^ÕõX"ÚÙm¼¦ü¯_3ùÈ¼ý.NI:ûÎw}­gÄÑÎnËÈÿZ;Û]Éuã¾p)2HüCÈô ¯0¯?Ã×¸ ¯>ÇÓ:ª]{¶ªýó¸êòcÖH­Å¢¨Èûì4ÜµÄP"åH¹HÔÙpv|ëkÞR,íì6LçY~¥qÐÎ®Fºî&÷$âvÐA"ï$yHÔÙpöê} Î>hg·aB8»_E!Y~¿íË0`ÃäL:ûÎ^½³ÄÙíì6L½»©Æ»Ü/ÃënrH»HÔÙpöê} Î>hg·aBäøt¹;Íòû~åPk¤éWIQgOàìø®ê¼¥"I;»
# {")òQvåwÙ¾üï	ûk$³ã÷ßp2"¥¼þE)E=³ã[_óbhg·aBØ¸_×"Y~ÊôD¬³¸®÷¡õDU7E=³ãûóbhg·áÉ|eªnÒÎ®ÂënrÏkÄ×G:{Í¯¿Ï>¥¨³'pv|bÞR,íì6L:»Ö"YdçCÒÎnÂ:»_iLèìSzýÍÐÇ%Î^½³'âìI;»
# "Ç6~§Y¤ªkgàè:{Bg'DÐÙÏ:{g¯ÞÙqö¤Ý	ò¦º_×bYÈ¾/ï#j¤ënrßàg·ß°6¼þÖÛ¢ÎÀÙ«wöD=ig·aB$ò>;Ë"U]5Âä®U ³#uöÎo}Í[%¢Ý	ã]ïwå«ºI×Ù®³'pvüúNæHý=Ä)E=³ãûóbhg·aBäØÆï4ÔÕPk¤Ag?G$êì	w"Ï[%¢Ý	bãä9þûOz(NÐgÇÓ¿a"ïb¿L$G=³ãNäyK1D²vvöD2±qÿËN²ÈÚoÖÎ®Fºî&÷c"ý¨³gpöÉ;{&Îµ³Û0!97fùu-Ó!¢=ÇDKD=³OÞÙ3qö¬Ý'r¼ëýÎ³|UW
# e°ÿeÏÖÙü²ÚvPÞ×Q^?7~ÊQgÏàìwöL=kg·aBä¸~§YÄG²vv5Òu79A$_B$êìß·KD;»
# "sãYYûÍÚÙMØ
# ø99Ad¼HÔÙ38;îD·KD;»
# "¡:;É"õÓ¹Ft=c"å"QgÏàì¸§oÞR,íì6Lg÷+$ì×²3ðD´³ç
# D|}$³4½~nü£ÎÁÙqOß¼¥X"ÚÙmAG³È]K¾Ï.ÃënrÈt	¨³gpöæ=gÏÚÙm!uvB$ò}v9ÂäiÇDÚ%D¢ÎÁÙwöL=kg·aBäØÆï4Ô³Øü¾èðº Ò¯ 2F}goÞÙGâì£vvöDFâìËò¿#£(¤/ö×Èx;$2Þ.!uöw"Ï[%¢Ý	²7ÞW¬X!¢]tÝMîIÄWuGpöëë'ùOcÔÙGpvÜe9o)vvîÈñ×ï<Ëÿ¨¡,&8;^oØÁÈ4Ø2F}gÇýJóbhg·aBäØÆï<Ë¯Æ¾ª'¢ëì#8;>¿ádÞô;Æ¨³àì¸_iÞR,íì6Lg÷«ñ$¼­ ²@Øÿ²ã1tösD¢Î>³ãîyK±D´³Û0!zdÕøQHù¢Gºî&' ³#uö÷bÌ[%¢Ý	ã7Õï4ÔG!åéº Î~HÔÙGpv¬üÏ[%¢Ý	RA÷U]Ev©¡,&¿#àìx[|ÃDZ;±;h:ÎuæyK±D´³Û0!ª³,²óA
# eÑáu79Aý¨³àìXC·KD;»
# "ï³³,RgÅæ÷EtÝMNAg?E¤D½³wïì8{ÑÎnÃHO³üj|ÑÎnÂ£#RnD
# :û9"Qg/àìÝ;{!Î^´³Û0!B*èþédØv8¢nÝMîIÄ¿XÐÙûtb]:{gïÞÙqö¢ÝñNóe8;É"¿#EÒ^w{ñû~8{ÍC=qD½³wïì8{ÑÎnÂ©³û"É"uv5E×Ýä¾ÁÁ¾aåÇë'ùO%êì½{g/ÄÙvvfD¼½($8{R¾è®»É	"ã%D¢Î^ÀÙ»wöB½hg7aFäØÆï4Tum_vöRKD½³wïì8{ÑÎnÂÙõî~Y¹kig/¢¿î&'ÔKD½Xg/7ïì8{ÑÎnÂqv¿®E²HÝô5y"ºÎ^ÀÙq¹ÿ
# [x'Ò^?É*Qg/
# xg/ÄÙvvfD§_E|DÒûýZ¥i:{é@Ä;{!Î^´³0#B*èÄCÎ®²àP<~L¤_A¤F½ÞwöJ½jg7aB¤WÐï4bÕÎ®Âënr?&Ro:{wöJ½jg7aFØ¸_'Y¤ª«²èðºÜ¯êVpöZ¦'ù×¨³×D¼³WâìU;»	ãßâ-~°d½ñj(¯»É=ø]¦½§áÄ5uöwöJ½jg7aF¼ÏîÙIñÛ'"ÂënrO"~wPgn·g>Ô¨³×xg¯ÄÙ«vvfDBçÆ³,¿N
# e°_û­èìÈx	¨³×D¼³WâìU;»	3"ÄÙý³É"ëZ¦/ÿô«ÂënrH¹HÔÙk"ÞÙ+qöªÝãÓåî4ìû5}ùìP<tvB¤^B$êì`ç-ÅÑÎnÂÈqýÎ³¼!ª¡,:¼î&÷$â÷4Ö	ô'ù×¨³WpvüG8o)vvfDmüÎ³È/»>NtÝMNi:{gÇ)Ï[%¢Ýâì~5d=v>®¢³"ý
# "SÔÙ'pvü§:o)È¤Ý	éØÆï4ìÄ¶3pD&íì:»'2Ý.!uö	Bç-ÅÑÎnÂ±qo$¼jgàè:ûÎî«º8û4´'ùOQgÀÙqÊóbhg7aüwýe¬4,²oúò_M2a×ÀÙ³ßÓ8³O%x[a:ûÎ·óyK±D´³0#Bêì~¥dµßI;»éºÜß4¡³×áÄIþSÔÙ'pv<2cÞR,íì&Ì¿©~§Yd'ö¤ëìj¤ënr:û9"QgÀÙñ¨yK±D´³0#:dª®éÜµt}*ÇDÐÙÏ:ûÎGóbhg7aFäøMõ;Í"ëZòE×ÝätösD¢Î>³ãzÞR,íì&Ì'DOÿIeÑáu7¹'¿§qBg¯ýÄ·¦¨³Oàìø¨:o)vvfDO»ó,_QCY LµÚ1tösD¢Î>³ã_ß¼¥X"ÚÙM9>þN³HUwR¾èðº Î~H:{gÇ¿yK1Dvv&Dqv¿ÒH²È¾ß¦ëì&ì´Û!Î~HÔÙ8{òÎÞ³7íì&Ì:»¿k,RgWCY L³g_ÕmèìS;ñmuöÎR<o)vvÆËîË?¨³,²ÒØ/:¼î&÷Èè÷46pö6äo+´¨³7pv¬üÏ[%¢Ý²ëÝ¯4²,ÿËnú"D´³7pöÑïjàì-
# 'NmQgoàì(Åóbhg7aFäØÆï4ÔGÔP'2/!uöÎR<o)vvfDBï³³,ò;¢ÝÅ)ÇDÊ%D¢ÎÞÀÙq5zÞR,íì&Ì§Yä}vÓ¹ké÷Ù[=&R/!uöÎ½³7âìM;»	3"ÄÆýºÉ"ûµì<íì
# }ô{8{Ë·çý¶¨³7pöì½goÚÙM!ï³g­Ð·Þ®³«ðº Ò.!uöÎç-ÅÑÎnÂqvbÇ_ûIe0yúíÇDúDzÔÙ;8;ÖÐæ-ÅéÚÙMéÇoªßiÙÔ/:¼î&÷c"ýv	¨³wpv\·KD;»	3"ÄÆ}Åd:{R¾è®»É=øªnH¿½^ÕíQgïàì¸®3o)vvÆ/[ü`]eùF;OD;{Gg÷{;:ûO¼­Ð£ÎÞÁÙq]gÞR,íì&ÌÛøfúH×Înâ ³ûÝA½¥tâ:{gÏÞÙ;qö®ÝâìÞGH©¨¡,8OAg?G$êì={gïÄÙ»vvfDHÝ¯ý,RgWCYp(:;!Î~HÔÙ;8{öÎÞ³wíì&Ì¾õF²È~-5ÂäwAg?G$êìW£ç-ÅÑÎnÂHè[o,Ëï|èÚÙMØ¿=ÝÑÙýÆÎÞoíõ=êì×uæ-ÅÑÎnÂÈñðwEVQì<]gïèì:û9"QgïàìhHóbhg7aF8;¹k,òô«]×Ýätö3DÚ-èìsögÊýÏöDq½f¹:;ôDlØ]#û!ëi"AgÿH4D³?S,éì6Ìgw«(4{ãmg/®ªs}'ÒÇ«ºítöDCÄ9û3ÅÎnÃø|ôeëUå~Gl_ÎexÝMîIÄíi¹¾3i|ýmv:ûG¢!âýbHg·aFäØÆï4Ë¯ýÚ¾Ü¹ñr¤ënrO"nw´ð 2¦zâ	:ûG¢!âýbHg·aFAçêì4ËÕm_äáu79Ad¼HÐÙ?
# çìÏKD:»
# 3":;Í"w­}_îíi&DÊ1r	 ³$"ÎÙ)tvfD»"Ëò» /OD:ûçäz	 ³$îà³Æ¼¥X"ÒÙm9þòúfù=Ð'"ëì{q{¡2¼þ=Äv:ûG¢!âýbHg·aFTÐ]}eù½(Ð'"Ï û Ò.!töDCÄ9û3ÅÎnÃÈ±ßy«È¡,&w­~L¤_Ad:ûÎ^¼³ÄÙíì&Lï³Ó,×´³«®»ÉýÈp»HÔÙpv4¤yK±D´³0#âmÜ¿õÆ²|Ýöå~íP<tvWÕ¹¾é¯}¯
# QgÀÙñYcÞR,íì&»¿lq½ÒÈ²üj¼Êa×ÐÙ]}:x©íõ÷ÙÛuö¯ÚyK±D´³0#rlãwEÖµÔP"èì:û9"QgÀÙñª·KD;»	3"¤î×~Ißbûò8hgÐÙýÚïÎ>M¯¿«Û¨³àìøodÞR,íì&Ì
# º_×bYäwÄÌÀÑÎ> ³"èìçD}gÇÍ[%¢ÝRg÷È²¼³«¡,:¼î&' ³#uö½zg³ÚÙMñ6î÷k±,_CCY L®tvBý¨³àìÕ;û@}ÐÎnÂqvWg§Y~5~ôEtÝMNAg?G$êì8{õÎ>g´³0#BÎ #O¿Ç_ûIe0¹FÀÙññ<´òúÛÓ-E=³Wïì8{ÒÎnÂH"6îk,Ë;{ôE×Ýä~L$¡³#uöÎ^½³'âìI;»	3"÷ÙYß÷+²èðº Î~HÔÙ8{õÎ³'íì&¿Æ_¶øA
# dÕxÛ'¢=³ã]û
# çú~¸@~ýûì-E=³Wïì8{ÒÎnÂ±qB$TgOBÊ'äKD=³Wïì8{ÒÎnÂHäûì,ÔÕP^wDÆKD=³Wïì8{ÒÎnÂH¨ÎN²H}$igW#]wDÊ%D¢ÎÀÙ«wöD=ig7aFäø+nwEö4&]gOºÎê1z	¨³'pöÉ;{"Î´³0#yfùu­¤ëìI;{gÇ§ÿ7ëÈ0´××~SÔÙ8ûä=gOÚÙMì§YÞ®³«®»É	"í"QgOàìwöD=ig7aF$ò}vEvª¡,:¼î&'ô+ä¨³gpöÉ;{&Îµ³0!#ï³Ó,¿E
# e°¿ketvOÄvpHÔÙ38ûä=gÏÚÙMÏ²È.SÛ'¢=£³ûØ¶t__iÌQgÏàìwöL=kg7a|ú²Åªº$T¬²vö¬=£³ûªnFg/åõZ:{g¼³gâìY;»	3"÷ÙYÙù ²àP<tv¿ÑÙk®'®¨³gpöÉ;{&Îµ³0#B\#÷Ùm_~ÅÅAg'DÐÙÏ:{g¼³gâìY;»	3"ÄÆýÓ/É"k¿¦/BD¾Ïþ99Aý¨³gpöÉ;{&Îµ³0#B<k.ÿôEè:{Fg'DÐÙÏ:{goÞÙ3qö¬ÝRg÷õEêìYHùCñDÀÙqÍâ
# çú 2¥ôz}$G=³7ïì8{ÖÎnÂÈñérwEjY;»éº Î~HÔÙ38{óÎ³gíì&ÌD¾õÆ²ÈF;OD×Ùs?&Î~Èuö½yg³ÚÙMßT¿Ó,²§ÑöåÚÙÇÛ!ý¨³àìÍ;ûH}ÔÎnÂ© û»Ëò¨²à=pv\i}ÃDÚ­¿þ¶Âuö½yg³ÚÙMþ²ÅVI©!ÚÙÕH×ÝäDü{#8û0'QgÁÙwö8û¨ÝbãÞGH©!ª¡,8O×,Þ°4'®¨³àìÍ;ûH}ÔÎnÂH¨ÎN²ÈJ£Ê¢ÃënrÈx	¨³àìÍ;ûH}ÔÎnÂ±q¿®Å²¼!Úx"ºÎ>c"å"QgÁÙwö8û¨ÝRA'1{B¤j"ºÎ>Öc"õ"QgÁÙ»wö8û¨Ýã¯¸Ýy÷Q×ÙG]gÑÙý{#8ûÓôúÎ1êì#8{÷Î>gµ³0#âmìi$Ydoü¨]tÝMNi:ÎÞ½³ÄÙGíì&ÌÞg'Y¤ªkûòDt}Dg'DúDJÔÙ8{÷Î^³íì&Lr"¼wvå×µòE×Ýä~L¤Ü.!uöÎÞ½³âìE;»	3"ÄÆýFEöý¾üùZE;{Ag'DKD½³wïì8{ÑÎn[½y"o½±,²Ò¨²èðºÜw"ødó-Æñõoô´uöÎÞ½³âìE;»m	½ÏN²HÅJ
# eÑáu79A$_B$êì½{g/ÄÙvvÛ*!ª³,RÕ-¢¾èðº 2^B$êì½{g/ÄÙvvÛ*!97e½(¦/òË.~ÝMN):{gïÞÙqö¢Ý¶JÛøfU¢ëì*¼î&÷$âWã8{*ùõoô´uöb}ßÓF8{ÑÎn[%DkÔÙ}}D
# e0!2.!uöÒwöB½hg·­"!g'Yd¿é\#ÚÙK;&Ò.!uöÒwöB½hg·­"ä+n~ídEÒ^wDúDjÔÙë
# xg¯ÄÙ«vvÛª'RmüÎ³|]
# e°'RoDêí"Qg¯ñÎ^³Wíì¶UB$tn<É"uvÓ¿FÔH×ÝäDü[o=Õtb'v:{M@Ä;{%Î^µ³ÛVO$tn<Ëòw-Û'"ÊðënrO"¾>RÑÙ{}ý[o­F½f â½g¯ÚÙm«© ûUå×µL_þÄ3&w-tv¿®UÁÙó­¼þÕ¤V£Î^G â½g¯ÚÙm«±qrÞg¯ÚÙMAg'DÆKD½ â½g¯ÚÙm«Èñ®÷;Í";èªòEtÝMN):{­@Ä;{%Î^µ³ÛV	È·ÞXÙdú"×vöÎNÔKD½³ã¢ø¼¥X"ÚÙm«Hè}vEv>¨¡,&DÐÙý[o=ùÄWjÔÙ+8;*Ø¼¥X"ÚÙm«±q_±bY¾ª«²èðº Ò.!uö
# Î7yK±D´³ÛV	c¿Ó,RC4}OD;{Eg'DúD¦¨³Oàìø;o)È¤Ý¶êLÞÆÉ¾_Eö4¾üïéºÜL·KD}gÇÛù¼¥X"ÚÙm«qv¿ÒH²È~-5â ³û·Þ&pöÒØSÔÙ'pvÔyK±D´³ÛV'zdUÓ_EQ#]wû'ëzoØÂHN|ëm:ûÎ?óbhg·­"do¼÷å
# ÑôEîZºÎ>e âÏ|ÐÙßO!{HÔÙ'pöÁ;ûD}ÒÎn[%Dw½ßiY/z¤ënr:û9"QgÀÙïìqöI;»m9¶ñ;Í"»ÔPûg­©Ag?G$êì8;jÁ¼¥X"ÚÙm«HèÜxEªºvv;O¤Ag?G$êì8;þ#·KD;»m!6N~ÙCï³ý>û4Ag?G$êì8; æ-ÅÑÎn[%DmüN³È:Û'"¿Ïþ9¹'ÿâÎ>'¾c5E}gÇ£yK±D´³ÛV	ã¯¸Ýy!¢Ï ´³Oý:û)"-êì
# ÿbæ-ÅiÚÙm«H#6îWIÙ¯ÕD!}Ñ#]wû1Î~HÔÙ8;~L}ÞR,íì¶UB8»_×"YdO£Êaÿ;Òc"èìçD½³ãÃÌ¼¥X"ÚÙm«Ù!tÿôK²HÅªBú¢Gºî&÷$âë#
# ½'¾,Ö¢ÎÞÀÙñóbhg·­"¤î«º,Ë¯ý¾È]K×Ù:;!Î~HÔÙ8;þS·KD;»m!{ã½,²7¾é:»
# ¯»É	"èìçD½³ã?ÂyK±D´³ÛV	bã~5dMHù¢Gºî&÷$âWã8ûx»øjR:{gÇWÔæ-ÅÑÎn[%D¿âv§Y¤Î®²@\#èìH½HÔÙ8;n@·KD;»m!uv_ÕeY~]K
# eÑáu79AdºHÔÙ8;æ-ÅÑÎn[%DBçÆ³,_ClÚÙvöÎî+V­!vâ«I-êì
# åaÞR,íì¶UB$tn<É"»LÕP"èìH¿H:{gÇ¿¾yK1DºvvÛª'ÒmüN³ÈÎ5Âþw¤£³{"ýv	¨³wpöì½gïÚÙm«Èñ®÷;Í";ÔPûk¤£³"Ã%D¢ÎÞÁÙ³wöN½kg·­Hè[o$ÔGº®³«ðºÜw"øèðs}¦òú*J:{gÏÞÙ;qö®Ý¶JöÆ,RgWCYtxÝMîIÄ¿ÑÓÁÙÇTO|5©G½³gïì8{×În[%Dw½ßiñ®ëìj¤ënrÈx	¨³wpöì½gïÚÙm«±q_C$Y¤>Òµ³0ùegÇ7ëHO|¦G½³gïì8{×În[%D{!Yd/J×uv&¿#õ:û9"Qgïàì£wöN½kg·­"¡sãI©Xu±ù}ðèLÇDÐÙÏ:{g½³wâì];»m	ÕÙYyÖÒï³«ðº Î~HÔÙ;8ûè½gïÚÙm«ÙOµBßgWCYp(8;.÷¿a"$/¯kõ[ÐÙ?
# çìÏ=û9"Ðª#òëÝA,ËWu¡/$bÃîýsrßàÚ÷Îµ¤Ò×wõ[ÐÙ?
# çìÏKD:;´Jgw{QXß¯eûrïÈ®»É	"Ã%DÎþh8g¦X"ÒÙ¡ÕâDÎgY¾ªkûrÏZr¤ënrÏ»«!B»ÖÔ^?a ßÎþh8g¦X"ÒÙ¡UB8»[E¡Y®>bûrï³Ë®»É=¸´ð Òêë_Mê· ³$"ÎÙ)tvh!tW±bY~/í\#ÒÙ?'' ³#töDCÄ9û3ÅÎ­"ä}vg4\#ò}v9Òu79Aý ³$"ÎÙ)tvhAÇ²üj¼Ê¢Ãënr:û9"AgÿHÜ)ÎÙ)tvh9>]îN³üî Û¹kIgÿÜyÖBgïåõ¯&õ[ÐÙ?
# çìÏKD:;´J.w§Y~wíË9»¯»É	"èìçý#ÑqÎþL±D¤³C«Hdo<ËòU]9E×ÝätöSD¨³àìÅ;û@}ÐÎn[õDHfùßÓ¿FÔH×Ýä~LdÀ:û9"QgÀÙwö8û Ý¶JDêì,ËïE±}ùß5Òu7¹§³»ª.´ðpö[~ý[o}:ûÎ^¼³ÄÙíìÐª'rlãwåë#r(ýïÈÎok¼a"¹½~Â@¢Î>³ïìqöA;;´êdù:»ÊaBùÞ°qzý«I}:ûÎ^¼³ÄÙíìÐª'ÙO³\}DeÑáu79Ad¼HÔÙpöâ} Î>hgV=c¿ó,BDÒk¤):ûÎ^¼³ÄÙíìÐª'Blü,r×ÒÎnÂÞzL¤^B$êì8{õÎ>g´³C«H¤ÎÎ²üî Ûyú{ã?'÷$âNDJyý=}:ûÎ^½³ÄÙíìÐª'©³³,¿;ÈöEOÁ­»É	"í"QgÀÙ«wö8û ZõDw½ßißbû"DdýsrH¿H:{g¯ÞÙqö¤ZuD±q¿Â²|=Bú¢Ãënr?&°Î~HÔÙ8{õÎ³'íìÐª'Bv½{!Y~/íË_#v(:»¯ê&töú¾åe"QgOàìÕ;{"Î´³ÛV'O$rË"/z¤ënrß ò7l¡¤z^W·§¨³'pöê=gOÚÙm«±q¿ÒÈ²|
# Ñöåè:{ÊÇDò%D¢ÎÀÙ«wöD=ig·­"ï³Ó,_gOºÎnÂÞGÒxLd¼HÔÙ8{õÎ³'íì¶UBØ¸ßù@²È^Óûf¨
# {gOåH¹HÔÙ8{õÎ³'íì¶UBäøMõ;Í"õ$6¿/z¤ënrH½HÔÙ8ûä=gOÚÙm«© »ÖñIu?A_ä®%Ï û 2]B$êì	}òÎ³'íì¶UBä¸~çYäçÆÛ0¹kµc"í"QgOàìwöD=ig·­"sãYÙA/&×H?&Ò¯ £ÎÁÙ'ïì8{ÖÎn[õD2Ùï~Y¯!¾ü.S5Òu7¹'÷¶´PÞßB|ý£ÎÁÙ'ïì8{ÖÎn[%DmüN³È~-ÓßoÂþé7ÇDKD=³OÞÙ3qö¬Ý¶Ú<ã/¯ßiYE1}kD~ëísrO"~/JFg¯íöz=G=³OÞÙ3qö¬Ý¶J:»_E!YdíW
# e°ÿeÏèì:û9"QgÏàìwöL=kg·­"ÄÆý/;Ë"w-ù>»éº Î~HÔÙ38ûä=gÏÚÙm«yÝW¬X÷5Âä®ÎN ³#uöÎ>ygÏÄÙ³vvÛ*!B*è~5d¶/ODA÷99Aý¨³gpöæ=gÏÚÙm«ÈñðwE*VY;»
# ¯»É	"èìçD=³7ïì8{ÖÎn[%DH<kêìY×ÙÕH×Ýä¾ÁÞ°éáÑ¯:{goÞÙ3qö¬Ý¶Jg÷+,¢ÞE~ÝMNAg?Ed:ÎÞ¼³ÄÙGíì¶UOd$t¿®E²ÈÆQ×ÙÕH×Ýä~LdDg?G$êì#8{óÎ>gµ³ÛV	bãþYdt¦/BDÿ99Aùí?þüóÏßþãë·¯¿û·¿ýÓÏÿùõ×?ýåoÿøÍ_þãÇÑ¯ÿ$ññ¿¿ýò÷ÿõöû_¾=8=ÿôç¿þáç_ßÿô÷ùåÛó¿ýo_ÿ×ÿëë¯ßþñÿþåÿöAu÷ÿþæ×ýËþý_~]ÿ0¼gÿö3ýñÿûå×ÿùâïþPK
# odXxùSxl/tables/table4.xml}ÛnÂ0_%ÊýHËDAÓ$¦Mh=×6RUb`¼ýRÒ1(WíÏñïÃtþ­Û¡óÒ§½34¹-¤)3þ¹^Ü8ó¦e
# füÏgS/Ìá&ãOéäm0¤Ò×
# ï ¨@É83,2>à,òv¿ªì>Ô
# UYb|Æ+¢z"Ï+Ôà{¶F"ë4P0])|í
# _!V¢$C¡A>ÂìB*B÷Oh?[µÕÆ³Ün
# v~hÅF#jÃ#®AÁ[~SÈl©ûÊ1Åi4WesPk±¬©FÖýÃ[ÿ½Ø°È=Þþðuµ
# w$5KÒu;×äÈó½´i+:(|5Ûf®OÎ¥,+
# ñálbÎ¬ÑO¨ñ67õëjÁ%xðZHwî;éýPK
# odXZÙ°##xl/worksheets/_rels/sheet1.xml.relsÏÏ
# Â0ðW)¹ÛNY·»Ê|ØepkKSÅ½½]xðBø~ÉË÷4Õ°²Æ5í4ÜêË#ÚGgIÃLe_iÄ"ÜE2,kècô'¥Øô4!KçÉ¦KëÂ1­¡SÍ;R»,;¨ðmÀÚ5¢)UÄûH¼½L"zöôOkÛÁÐÙçD6þ¨]TU£!TÍT«ÕsÅPK
# odzý
# xl/styles.xmlíYmOÛ0þ+¿§imÕ­@$$&Á¤}u'µðKä¸¬eÚí$m:P  ~»{î¹cãÑéQçËîöÌ#úàçmÐê'WÇ
# }°À98rµ øf±r4Ï}0U*BGSÌP~$2ÌõH"$CJ7e
# óLbçFQè¹î1dpP çí.á0IDEA$$ÂpQT!±Ç0è0$ïfYKÃfHP¢pX4¼L¹(¤ÚeKG|Æ¦r'3®|à8%¯z:ÞqñfHR:fÎ=¢º§m4#At¦îááBâQJc1BE¿gÄ¬K¥ #¥éZÃáf\Äþ½Ü¹'.ãØEÇx¤ÂºáõÛE¦ýàz2j)X0`¶xF5hÑöz¯ÔÎ%±áÕýÇ^âÆëØî@O\wO¶ÚBÇ.2Ö/p½>¨ºÆ#¥Õ%I§¦T"fP)ý.G1A©àÆn4»>ø@MõûýßTA¸ÝÇÖ+#ZÚxJ#:6?«ae-&´dÅ»¡F!ü6k¿|ÜDà@|Ü<Wá~ûIç0f@YÑËg)½1x¿åj6íyâ;þel6{ÇìTUU/¼eµ)¿V`×`½n;OJí5u¨-Öà6uz ,£ë±lcÜhj¿Qr+çQÕt¦B­gvnûÌ,8O¶Qiw?K9>Ç¦Y\wn¶Áóh"ÛcÛ¹jÈ¤ÅÀ§>­wgjDÔ{ÏJÇdV+±oçcyï(ÚÌºQ´ÝÃkwÃÚvï`V³ãYÍÞçËß¨C	ÝÉ^î+';¸ìÂÛ6q:¯_|L÷7&Eûm	Äg±n?ìqTÈÞ5,¼µSõÚzÙ»r.¯\Eæ+õµq®§5f<OÖ¿¾+ó~ÝÆqfTÝ.}°ªÇ1±ÁRê¹ªZÕ¯Ì¢Ú¶·ð\]åÊÎLü¹Î/¯Õw'ýV·{­AorÞêuÏ&ççÁÀõÜ³¿æ oïrJ",K¥ÑUjÂlíBä
# ×!öjÅDP/þ[7àêæfüPK
# odX¯Üt[Content_Types].xmlÍVËjÃ0ü£k±¤JCÇ6ÐôiÈÐ*iò÷]Ûm)ÁÆ×òìÎ<ï+ì  v6gãlÄ°Ò)m×9{[>¥·,Á(¬ÆYÈÙÍgÓåÁ&4k1geþs%T3çÁR¸PHË°æ^ÈXF7\:ÁÆ4Öl6}BlMLîÛï5uÎ÷FKÉßYuD~fLÓ¥öxA
# ,yÜK»Bñ
# Çõæ^è`Vð'k®(´åä¶¢}¡°ÉUBÛÖìBø,*bå{Ãß]Ø¬Ûdé×
# Íûoò
# ¼)ã3ñ19gâãêL|\ÒG¤ð.Õh^HØ¥ß"*"z"·ÛÀÏùøJMé¤>¢îØ59]¼n<åÎ¡Xª8QwêQ¬L÷u«lË÷­þÁ×KÀÀë¥ÿt¼ùß}PK
# odXìêudocProps/app.xmlSËnÛ0üçÆt8(Aà u1`'=o©Å"	r£ØýúR2¤È
# |émwg0}PÜîk5¢v6g)ËÐ*Wh»ËÙÓöÛÅWE[qsvÀÈn¥Xç1Æ%
# å¬"òÎ£ª°8IÀÒ(¥aÇ]Yj÷N½ÕhÏ¦Ó^8ÕªÅçíÁ'ñ£ÞÿáÐX\øÁ âÎ{£PêQ¾ëÚMö&î×EÚ zr*ø8IR`"
# þQ+vZkÐ!JÑÐ¢AE.d¿!bÛRÎ,¥Aê?)±#íXíbã#ùË×X!R|(vá;õµwù`$Å§·ÆÇr
# Î8îîýÎÙÈãÊ½ÀåØÞ	2;\E®Ï"óOcèú§°°ÃÀ¥XºÚ=Èï<.Óî¾d?¬Þâ§¶¯ñÉoÝ=öë<-MtÃºX¥ÓòØ=ç3ÐÞÝóñkÉô³º{ësÁ?¾üPK
# odX	xl/_rels/PK
# odXc¡F¾þìxl/_rels/workbook.xml.relsµÔËj0àW	g_£Î¥CÌlJa¶­} G#£ä^|û¦.¤Bº!ÿÿmNÎ×ï¶è©vVAÅ Ðæ®¨m¥à={y8 Ö¶Ð³¨ GëåüæðLÝæîIJÊ
# ¶"×¡
# 7¥ó­æpôìt~×Ê4ÒÿÍi¦È´¯|9'È$-B$¬ïpI¡+Ë:Çg´hù^9¸
# ü­H@.Ä¤ÛcÒÅÝöÝbÌ~{Ì~1æ°=æ0!£=oìÃDÑÚIø9Îc¸op}Å:Ö?ÎÖs(A9¬«Ïñ:N¿9ù¥.?PK
# odX±¬ãnxl/sharedStrings.xmluTÁrÓ0ýïÔ)e:IÜI¤
# L:·´uÄ¬´F=´_Ïª½×ýVzïíÛµ×¿=U#Æä8¬êó³E]a0l]èVõ·ÃÇWoë*®êGLõu»L)Wr3¤U}Ê¹×4ÉÐC:ãT8zÈò»&õÁ¦böÔ¼^,..Ôá!äU}quy!2Cp¿Ü¾`o®jQqí2·[¦ÁóeÛeS 8!$SÔºÑ^¦xZ;
# ÐÁO#s+=ßÙ1PúÏ¥ÙS,;­ï§u&ÌÎpe±Ú8:OOÜ!PµgãÐêjM0¢r°hPÓÂ=LÜ)|#ËßÖnÁF§Ô@Ý¬{ícg¡ÈÜ»NõøLSxTúBA"y=ÇìF¥ù%AfâsDeÁîÇRS0ò?aT>$ÝÒõA8%G­wFÄÁrìf@ÕO8ny3s^Ç¨aYË¤'³(tEç~êíóàan£DIâ;FT«qÑ¤÷x!Õ±À#WÅ3Ùµ$¯ÝÔ¶-u¢ª¯@òÀé¬36]ügx¼íPK
# odX<pÜ:´*xl/workbook.xml­oOÛ0Æ¿±òv8Q[5Ec0Á6mH0xL|i<;²]R¾ýìU¼Ê=ç~öÝyy¼mzm¸%Nc@Vq¹.ñïë¯fK%£BI(ñ|¼ZöJ?Ü+õ\¹4%n¬íªCÕtj¥[jÔkb:
# À¶¤q|DZÊ%	ýªk^Á©ª6-H;BjÝåMÃ;WË¸ûAzÓl¸`%gqP={Æ¸+\îHÚu?iëºÜ
# L^¼ÔNøàCo^ò^¢í-Lõ%ÎgnvO:r¢â[ÎlãF;KæÅ;¾nlgEì­,kzï\þ\5lú"½àî¦ú%n+>sÁ|
# Ã­ÏÕ:^ÓÀæt9ÌYhÎöóÀæ|ÌEh.¦§NÔ\óØUÏ§Ô*s¶µ ¥2wßjEÅÕDñjÃAô9JÑ·(çÉÿ&#4õÐì½Ðì :ñÐïÍGhñ¯öÉî]yu©Q½âÉ²é)No}õPK
# odX_rels/PK
# odXj¿¼ÆæJ$_rels/.relsPK
# odX	3docProps/PK
# odXZxl/PK
# odX	{xl/theme/PK
# odX¹B$¬u¢xl/theme/theme1.xmlPK
# odX*}n8docProps/core.xmlPK
# odXxl/worksheets/PK
# odXÕ°K=-ýíxl/worksheets/sheet5.xmlPK
# odX
# l6xl/tables/PK
# odXENIR6xl/tables/table1.xmlPK
# odX8xl/worksheets/_rels/PK
# odXà°##J8xl/worksheets/_rels/sheet5.xml.relsPK
# odXý«Å";9xl/worksheets/sheet4.xmlPK
# odXe^ÊÏg= >xl/worksheets/sheet3.xmlPK
# odXé¥CU¦xl/tables/table2.xmlPK
# odXY9ØQ°##¨xl/worksheets/_rels/sheet3.xml.relsPK
# odX¤qVÈs'a¿©xl/worksheets/sheet2.xmlPK
# odX=³eS¹Ð	xl/tables/table3.xmlPK
# odX×Ï°##>Ò	xl/worksheets/_rels/sheet2.xml.relsPK
# odXH¢û'3½/Ó	xl/worksheets/sheet1.xmlPK
# odXxùSòúxl/tables/table4.xmlPK
# odXZÙ°##wüxl/worksheets/_rels/sheet1.xml.relsPK
# odzý
# hýxl/styles.xmlPK
# odX¯Üt#
# [Content_Types].xmlPK
# odXìêuÈ
# docProps/app.xmlPK
# odX	
# xl/_rels/PK
# odXc¡F¾þì²
# xl/_rels/workbook.xml.relsPK
# odX±¬ãnè
# xl/sharedStrings.xmlPK
# odX<pÜ:´*ý
# xl/workbook.xmlPK¤Þ

# %%
df = pd.read_excel('data/laliga.xlsx')
df.head()
# Out:
#    Column1     season  division  round           localTeam    visitorTeam  \
# 0    26201 2005-06-01         1      1  Atletico de Bilbao  Real Sociedad
# 1    26202 2005-06-01         1      1              Alaves      Barcelona
# 2    26203 2005-06-01         1      1            Valencia          Betis
# 3    26204 2005-06-01         1      1  Atletico de Madrid       Zaragoza
# 4    26205 2005-06-01         1      1               Cadiz    Real Madrid
#
#    localGoals  visitorGoals       date   timestamp
# 0           3             0 2005-08-27  1125093600
# 1           0             0 2005-08-27  1125093600
# 2           1             0 2005-08-27  1125093600
# 3           0             0 2005-08-28  1125180000
# 4           1             2 2005-08-28  1125180000

# %% [markdown]
# No tenemos problemas cuando los datos están perfectos, con una única hoja, y empezando en la celda A1. ¿Qué argumentos nos pueden resultar útiles?
#
# 1. `io`: dónde está el archivo
# 2. `sheet_name`: el nombre de la hoja
# 3. `header`: dónde está la cabecera
# 4. `usecols`: indica el rango de columnas Excel en el que se encuentran. Por ejemplo: 'A:F'
# 5. `skiprows`: filas que deberia ignorar
#
# Veamos más ejemplos. El Excel de `laliga.xlsx` tiene varias pestañas. Por defecto, lee la primera, `Hoja1`, pero podemos especificar otras.

# %%
df = pd.read_excel('data/laliga.xlsx', sheet_name = 'Hoja2')
df.head()
# Out:
#   Unnamed: 0           Unnamed: 1 Unnamed: 2 Unnamed: 3          Unnamed: 4  \
# 0        NaN                  NaN        NaN        NaN                 NaN
# 1    Column1               season   division      round           localTeam
# 2      26201  2005-06-01 00:00:00          1          1  Atletico de Bilbao
# 3      26202  2005-06-01 00:00:00          1          1              Alaves
# 4      26203  2005-06-01 00:00:00          1          1            Valencia
#
#       Unnamed: 5  Unnamed: 6    Unnamed: 7           Unnamed: 8  Unnamed: 9
# 0            NaN         NaN           NaN                  NaN         NaN
# 1    visitorTeam  localGoals  visitorGoals                 date   timestamp
# 2  Real Sociedad           3             0  2005-08-27 00:00:00  1125093600
# 3      Barcelona           0             0  2005-08-27 00:00:00  1125093600
# 4          Betis           1             0  2005-08-27 00:00:00  1125093600

# %% [markdown]
# Vemos que hay algún problema con los datos. Las primeras líneas están en blanco en el Excel. Podemos, o bien ignorarlas, o indicarle donde está la cabecera

# %%
df = pd.read_excel('data/laliga.xlsx', sheet_name = 'Hoja2', header = 2)
df.head()
# Out:
#    Column1     season  division  round           localTeam    visitorTeam  \
# 0    26201 2005-06-01         1      1  Atletico de Bilbao  Real Sociedad
# 1    26202 2005-06-01         1      1              Alaves      Barcelona
# 2    26203 2005-06-01         1      1            Valencia          Betis
# 3    26204 2005-06-01         1      1  Atletico de Madrid       Zaragoza
# 4    26205 2005-06-01         1      1               Cadiz    Real Madrid
#
#    localGoals  visitorGoals       date   timestamp
# 0           3             0 2005-08-27  1125093600
# 1           0             0 2005-08-27  1125093600
# 2           1             0 2005-08-27  1125093600
# 3           0             0 2005-08-28  1125180000
# 4           1             2 2005-08-28  1125180000

# %% [markdown]
# Otro problema que nos puede surgir es que la tabla no esté ni en las primeas filas, ni en las primeras columnas

# %%
df = pd.read_excel('data/laliga.xlsx',
                   sheet_name = 'Hoja3',
                  header = 2,
                  usecols = 'B:K')
df.head()
# Out:
#    Column1     season  division  round           localTeam    visitorTeam  \
# 0    26201 2005-06-01         1      1  Atletico de Bilbao  Real Sociedad
# 1    26202 2005-06-01         1      1              Alaves      Barcelona
# 2    26203 2005-06-01         1      1            Valencia          Betis
# 3    26204 2005-06-01         1      1  Atletico de Madrid       Zaragoza
# 4    26205 2005-06-01         1      1               Cadiz    Real Madrid
#
#    localGoals  visitorGoals       date   timestamp
# 0           3             0 2005-08-27  1125093600
# 1           0             0 2005-08-27  1125093600
# 2           1             0 2005-08-27  1125093600
# 3           0             0 2005-08-28  1125180000
# 4           1             2 2005-08-28  1125180000

# %%
df = pd.read_excel('data/laliga.xlsx',
                   sheet_name = 'Hoja4',
                  header = 3,
                  usecols = 'C:L',
                  nrows = 7)
df.head(50)
# Out:
#    Column1     season  division  round           localTeam    visitorTeam  \
# 0    26201 2005-06-01         1      1  Atletico de Bilbao  Real Sociedad
# 1    26202 2005-06-01         1      1              Alaves      Barcelona
# 2    26203 2005-06-01         1      1            Valencia          Betis
# 3    26204 2005-06-01         1      1  Atletico de Madrid       Zaragoza
# 4    26205 2005-06-01         1      1               Cadiz    Real Madrid
# 5    26206 2005-06-01         1      1       Celta de Vigo         Malaga
# 6    26207 2005-06-01         1      1             Espanol         Getafe
#
#    localGoals  visitorGoals       date   timestamp
# 0           3             0 2005-08-27  1125093600
# 1           0             0 2005-08-27  1125093600
# 2           1             0 2005-08-27  1125093600
# 3           0             0 2005-08-28  1125180000
# 4           1             2 2005-08-28  1125180000
# 5           2             0 2005-08-28  1125180000
# 6           0             2 2005-08-28  1125180000

# %%
df = pd.read_excel('data/laliga.xlsx',
                   sheet_name = 'Hoja5',
                   skiprows=list(range(4942,4952)))
len(df)
# Out:
# 4964

# %%
df = pd.read_excel('data/laliga.xlsx',
                   sheet_name = 'Hoja5')
len(df)
df.iloc[4940:4955]
# Out:
#       Column1 season  division  round           localTeam  visitorTeam  \
# 4940      NaN    NaT       NaN    NaN                 NaN          NaN
# 4941      NaN    NaT       NaN    NaN                 NaN          NaN
# 4942      NaN    NaT       NaN    NaN                 NaN          NaN
# 4943      NaN    NaT       NaN    NaN                 NaN          NaN
# 4944      NaN    NaT       NaN    NaN                 NaN          NaN
# 4945      NaN    NaT       NaN    NaN                 NaN          NaN
# 4946      NaN    NaT       NaN    NaN                 NaN          NaN
# 4947      NaN    NaT       NaN    NaN                 NaN          NaN
# 4948      NaN    NaT       NaN    NaN                 NaN          NaN
# 4949      NaN    NaT       NaN    NaN                 NaN          NaN
# 4950  36661.0    NaT       1.0   36.0  Atletico de Madrid      Espanol
# 4951  36662.0    NaT       1.0   36.0              Malaga       Alaves
# 4952  36663.0    NaT       1.0   36.0           Barcelona  Real Madrid
# 4953  36664.0    NaT       1.0   36.0             Leganes      Levante
# 4954  36665.0    NaT       1.0   37.0              Girona     Valencia
#
#       localGoals  visitorGoals       date     timestamp
# 4940         NaN           NaN        NaT           NaN
# 4941         NaN           NaN        NaT           NaN
# 4942         NaN           NaN        NaT           NaN
# 4943         NaN           NaN        NaT           NaN
# 4944         NaN           NaN        NaT           NaN
# 4945         NaN           NaN        NaT           NaN
# 4946         NaN           NaN        NaT           NaN
# 4947         NaN           NaN        NaT           NaN
# 4948         NaN           NaN        NaT           NaN
# 4949         NaN           NaN        NaT           NaN
# 4950         0.0           2.0 2018-05-06  1.525558e+09
# 4951         0.0           3.0 2018-05-06  1.525558e+09
# 4952         2.0           2.0 2018-05-06  1.525558e+09
# 4953         0.0           3.0 2018-05-07  1.525644e+09
# 4954         0.0           1.0 2018-05-12  1.526076e+09

# %%
len(range(4942,4952))
# Out:
# 10

# %% [markdown]
# **Escritura de Excel**
#
# Al igual que con el CSV, tenemos el método `to_excel()`, para escribir el `DataFame` en un archivo Excel. **Recuerda poner la extensión del Excel (.xlsx) en el nombre del archivo**. Tienes [el enlace a la documentación para ver más detalle](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_excel.html).

# %%
df.to_excel('data/laligaExcelWrite.xlsx')

# %% [markdown]
# ## 5. JSON
# ***JavaScript Objet Notation* es otro formato de texto plano que se utiliza para el intercambio de datos**. Originalmente se utilizaba como notación literal de objetos en JavaScript, pero actualmente es un formato de datos independiente del lenguaje. JavaScript es un lenguaje de programación web, por lo que JSON se utiliza mucho en el intercambio de objetos entre cliente y servidor.
#
# **¿Qué diferencia hay con un CSV o un Excel?** Ya no tenemos esa estructura de fila/columna, sino que ahora es un formato tipo clave/valor, como si fuese un diccionario. En una tabla en la fila 1, columna 1, tienes un valor. En un JSON no, en la clave "mi_clave" puedes tener almacenado un valor, una lista o incluso un objeto. Salimos del formato tabla al que estamos acostubrados para ganar en flexibilidad.
#
# Un JSON tiene la siguiente pinta:
#
# ![imagen](./img/json_image.png)

# %%
data1 =  {
        "firstName": "Jane",
        "lastName": "Doooooo"
}
data2 =  {
        "firstName": "Joe",
        "lastName": "Doe"
}
data3 =  {
        "firstName": "J",
        "lastName": "D"
}
df = pd.DataFrame([data1,data2,data3])
df
# Out:
#   firstName lastName
# 0      Jane  Doooooo
# 1       Joe      Doe
# 2         J        D

# %%
dictionario = { "Col1": [1,2,3,4,5], "Col2": [6,5,7,8,9]}
df = pd.DataFrame(dictionario)
df
# Out:
#    Col1  Col2
# 0     1     6
# 1     2     5
# 2     3     7
# 3     4     8
# 4     5     9

# %%
data =  {
        "firstName": "Jane",
        "lastName": "Doe",
        "hobbies": ["running", "sky diving", "singing"],
        "age": 35,
        "children": [
            {
                "firstName": "Alice",
                "age": 6
            },
            {
                "firstName": "Bob",
                "age": 8
            }
        ]
    }

# %%
data['hobbies']
# Out:
# ['running', 'sky diving', 'singing']

# %%
data['hobbies'][0]
# Out:
# 'running'

# %%
data['children'][1]['firstName']
# Out:
# 'Bob'

# %%
for kid in data['children']:
    print(kid['firstName'])
# Out:
# Alice
# Bob

# %% [markdown]
# **Puedo guardar el JSON en un archivo. Para ello, usamos la librería `json`**, que viene incluida en la instalación de Anaconda.

# %%
import json

with open("data/data_file.json", "w") as write_file:
    json.dump(data, write_file) # Le da la estructura json

# %% [markdown]
# O también objetos de una clase

# %%
class Persona:
    piernas = 2
    def __init__(self, firstName, lastName, hobbies):
        self.firstName = firstName
        self.lastName = lastName
        self.hobbies = hobbies
        
pers1 = Persona("Pepe", "Carrasco", ["Bricolaje", "Tenis"])
pers2 = Persona("Jose", "Carrasco", ["Bricolaje", "Tenis"])

# %%
type(pers1)
# Out:
# __main__.Persona

# %%
pers1.__dict__
# Out:
# {'firstName': 'Pepe',
#  'lastName': 'Carrasco',
#  'hobbies': ['Bricolaje', 'Tenis']}

# %% [markdown]
# Lo puedo guardar en un archivo *pepe.json*

# %%
with open("data/pepe.json", "w") as write_file:
    json.dump(pers2.__dict__, write_file)

# %% [markdown]
# Luego lo puedo volver a cargar

# %%
with open("data/pepe.json", "r") as json_file:
    data = json.load(json_file)
    
print(data)
print(data['firstName'])
# Out:
# {'firstName': 'Jose', 'lastName': 'Carrasco', 'hobbies': ['Bricolaje', 'Tenis']}
# Jose

# %% [markdown]
# Para el siguiente ejemplo, utilizamos `pandas` y leeremos el archivo JSON, de tal manera que nos transforme los datos en formato tabla, en un `DataFrame`.

# %%
df_json = pd.read_json('data/Musical_Instruments_5.json',lines=True) # lines:True --> consiferar cada línea un objeto json
df_json
# Out:
#            reviewerID        asin  \
# 0      A2IBPI20UZIR0U  1384719342
# 1      A14VAT5EAX3D9S  1384719342
# 2      A195EZSQDW3E21  1384719342
# 3      A2C00NNG1ZQQG2  1384719342
# 4       A94QU4C90B1AX  1384719342
# ...               ...         ...
# 10256  A14B2YH83ZXMPP  B00JBIVXGC
# 10257   A1RPTVW5VEOSI  B00JBIVXGC
# 10258   AWCJ12KBO5VII  B00JBIVXGC
# 10259  A2Z7S8B5U4PAKJ  B00JBIVXGC
# 10260  A2WA8TDCTGUADI  B00JBIVXGC
#
#                                            reviewerName   helpful  \
# 0      cassandra tu "Yeah, well, that's just like, u...    [0, 0]
# 1                                                  Jake  [13, 14]
# 2                         Rick Bennette "Rick Bennette"    [1, 1]
# 3                             RustyBill "Sunday Rocker"    [0, 0]
# 4                                         SEAN MASLANKA    [0, 0]
# ...                                                 ...       ...
# 10256                                   Lonnie M. Adams    [0, 0]
# 10257                                Michael J. Edelman    [0, 0]
# 10258                                  Michael L. Knapp    [0, 0]
# 10259                           Rick Langdon "Scriptor"    [0, 0]
# 10260                                   TheTerrorBeyond    [0, 0]
#
#                                               reviewText  overall  \
# 0      Not much to write about here, but it does exac...        5
# 1      The product does exactly as it should and is q...        5
# 2      The primary job of this device is to block the...        5
# 3      Nice windscreen protects my MXL mic and preven...        5
# 4      This pop filter is great. It looks and perform...        5
# ...                                                  ...      ...
# 10256            Great, just as expected.  Thank to all.        5
# 10257  I've been thinking about trying the Nanoweb st...        5
# 10258  I have tried coated strings in the past ( incl...        4
# 10259  Well, MADE by Elixir and DEVELOPED with Taylor...        4
# 10260  These strings are really quite good, but I wou...        4
#
#                                                  summary  unixReviewTime  \
# 0                                                   good      1393545600
# 1                                                   Jake      1363392000
# 2                                   It Does The Job Well      1377648000
# 3                          GOOD WINDSCREEN FOR THE MONEY      1392336000
# 4                  No more pops when I record my vocals.      1392940800
# ...                                                  ...             ...
# 10256                                         Five Stars      1405814400
# 10257  Long life, and for some players, a good econom...      1404259200
# 10258                                   Good for coated.      1405987200
# 10259                                        Taylor Made      1404172800
# 10260  These strings are really quite good, but I wou...      1405468800
#
#         reviewTime
# 0      02 28, 2014
# 1      03 16, 2013
# 2      08 28, 2013
# 3      02 14, 2014
# 4      02 21, 2014
# ...            ...
# 10256  07 20, 2014
# 10257   07 2, 2014
# 10258  07 22, 2014
# 10259   07 1, 2014
# 10260  07 16, 2014
#
# [10261 rows x 9 columns]

# %% [markdown]
# ## 6. TXT
# **Son simplemente archivos donde hay texto**. Hemos visto que los CSVs y los JSON tienen su propio formato y extension. En el caso del .txt no tienen ninguno específico aunque no quita para que sus elementos estén separados por comas, y se pueda leer igualmente como si fuese un CSV.
#
# Cuando almacenamos datos siempre tienen una estructura, por lo que aunque sea un `.txt`, llevará los datos en formato json, separados por comas, tabulaciones, puntos y comas...
#
# Por ejemplo, si tenemos los datos de la liga guardados en un `.txt`, separados por tabulaciones, lo podremos leer con el `pd.read_csv()`.

# %%
df = pd.read_csv('data/laligaTXT.txt', sep='\t')
df.head()
# Out:
#    Unnamed: 0   season  division  round           localTeam    visitorTeam  \
# 0       26201  2005-06         1      1  Atletico de Bilbao  Real Sociedad
# 1       26202  2005-06         1      1              Alaves      Barcelona
# 2       26203  2005-06         1      1            Valencia          Betis
# 3       26204  2005-06         1      1  Atletico de Madrid       Zaragoza
# 4       26205  2005-06         1      1               Cadiz    Real Madrid
#
#    localGoals  visitorGoals        date   timestamp
# 0           3             0  27/08/2005  1125093600
# 1           0             0  27/08/2005  1125093600
# 2           1             0  27/08/2005  1125093600
# 3           0             0  28/08/2005  1125180000
# 4           1             2  28/08/2005  1125180000

# %% [markdown]
# Recuerda que la separación por tabulaciones, también tiene su propia extensión: el `.tsv`, que igualmente lo podremos leer con `read_csv()`.

# %%
df = pd.read_csv('data/laligaTSV.tsv', sep='\t')
df.head()
# Out:
#    Unnamed: 0   season  division  round           localTeam    visitorTeam  \
# 0       26201  2005-06         1      1  Atletico de Bilbao  Real Sociedad
# 1       26202  2005-06         1      1              Alaves      Barcelona
# 2       26203  2005-06         1      1            Valencia          Betis
# 3       26204  2005-06         1      1  Atletico de Madrid       Zaragoza
# 4       26205  2005-06         1      1               Cadiz    Real Madrid
#
#    localGoals  visitorGoals        date   timestamp
# 0           3             0  27/08/2005  1125093600
# 1           0             0  27/08/2005  1125093600
# 2           1             0  27/08/2005  1125093600
# 3           0             0  28/08/2005  1125180000
# 4           1             2  28/08/2005  1125180000

# %% [markdown]
# El método `read_csv()` no se ciñe únicamente a leer CSVs, sino a prácticamente cualquier archivo que lleve un carácter concreto en la separación de sus campos. Si conocemos ese caracter, sabremos leer el archivo con `pandas`.

# %% [markdown]
# ## 7. ZIP
# En ocasiones los datos que recibimos en nuestros programas están comprimidos, ya sea en un formato `.zip`, `.rar`, `.7z`, u otro tipo de archivo.
#
# En este apartado verás un ejemplo de cómo descomprimir archivos `.zip`. Para ello empleamos la librería `zipfile` que viene incluida en la instalación de Anaconda. [Tienes el enlace a la documentación para más detalle](https://docs.python.org/3/library/zipfile.html#zipfile-objects).
#
# Para extraer todos los archivos:

# %%
import zipfile

with zipfile.ZipFile('data/laligaZIP.zip') as zip_ref:
    data_zip = zip_ref.extractall('data')

# %% [markdown]
# Si quieres descomprimir un archivo `.rar` [tendrás que descargarte un paquete como por ejemplo `unrar`.](https://pypi.org/project/unrar/)

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/ejercicio.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>Ejercicio zip</h3>
#
# Consulta la documentación para extrar un único archivo por nombre de data/laligaZIP.zip en la carpeta extracted_files.
#
#  </td></tr>
# </table>

# %%
with zipfile.ZipFile('data/laligaZIP.zip') as zip_ref:
    zip_ref.extract('laligaZIP.csv','extracted_files')

# %% [markdown]
# ## 8. pickle
# **`pickle` es el módulo que nos permite serializar y deserializar un objeto de Python**. Esta operación lo que hace es traducirlo a un stream de bytes.
#
# A efectos prácticos, lo que nos permite es guardar objetos de Python, y recuperarlos más adelante.

# %%
pers1

# %%
import pickle

df = pd.read_csv("data/laliga.csv")

with open('data/pepe.json') as json_file:
    data = json.load(json_file)
    
with open('data/importante.pkl', 'wb') as f:
    pickle.dump(pers1, f)
    pickle.dump(df, f)
    pickle.dump(data, f)

# %%
with open('data/importante.pkl', 'rb') as f:
    a = pickle.load(f)
    b = pickle.load(f)
    c = pickle.load(f)
    
#print(a)
print(type(b))
print(b)
print(c)
# Out:
# <class 'pandas.DataFrame'>
#       Unnamed: 0   season  division  round           localTeam    visitorTeam  \
# 0          26201  2005-06         1      1  Atletico de Bilbao  Real Sociedad
# 1          26202  2005-06         1      1              Alaves      Barcelona
# 2          26203  2005-06         1      1            Valencia          Betis
# 3          26204  2005-06         1      1  Atletico de Madrid       Zaragoza
# 4          26205  2005-06         1      1               Cadiz    Real Madrid
# ...          ...      ...       ...    ...                 ...            ...
# 4935       36680  2017-18         1     38          Villarreal    Real Madrid
# 4936       36681  2017-18         1     38  Atletico de Bilbao        Espanol
# 4937       36682  2017-18         1     38           Barcelona  Real Sociedad
# 4938       36683  2017-18         1     38            Valencia      Deportivo
# 4939       36684  2017-18         1     38  Atletico de Madrid          Eibar
#
#       localGoals  visitorGoals        date   timestamp
# 0              3             0  27/08/2005  1125093600
# 1              0             0  27/08/2005  1125093600
# 2              1             0  27/08/2005  1125093600
# 3              0             0  28/08/2005  1125180000
# 4              1             2  28/08/2005  1125180000
# ...          ...           ...         ...         ...
# 4935           2             2  19/05/2018  1526680800
# 4936           0             1  20/05/2018  1526767200
# 4937           1             0  20/05/2018  1526767200
# 4938           2             1  20/05/2018  1526767200
# 4939           2             2  20/05/2018  1526767200
#
# [4940 rows x 10 columns]
# {'firstName': 'Jose', 'lastName': 'Carrasco', 'hobbies': ['Bricolaje', 'Tenis']}

# %%
print(type(a))
a.firstName
# Out:
# <class '__main__.Persona'>
# 'Pepe'

# %%
b.head()
# Out:
#    Unnamed: 0   season  division  round           localTeam    visitorTeam  \
# 0       26201  2005-06         1      1  Atletico de Bilbao  Real Sociedad
# 1       26202  2005-06         1      1              Alaves      Barcelona
# 2       26203  2005-06         1      1            Valencia          Betis
# 3       26204  2005-06         1      1  Atletico de Madrid       Zaragoza
# 4       26205  2005-06         1      1               Cadiz    Real Madrid
#
#    localGoals  visitorGoals        date   timestamp
# 0           3             0  27/08/2005  1125093600
# 1           0             0  27/08/2005  1125093600
# 2           1             0  27/08/2005  1125093600
# 3           0             0  28/08/2005  1125180000
# 4           1             2  28/08/2005  1125180000

# %%
c
# Out:
# {'firstName': 'Jose',
#  'lastName': 'Carrasco',
#  'hobbies': ['Bricolaje', 'Tenis']}

# %% [markdown]
# ## 9. Encoding

# %%
pd.read_csv('data/encoding.csv', encoding = 'utf-8')
# Out:
#       País                       Comida
# 0   España                       paella
# 1    Japón                        sushi
# 2  Francia  La Lamproie à la Bordelaise

# %%
pd.read_csv('data/encoding.csv', encoding = 'iso-8859-1')
# Out:
#      PaÃ­s                        Comida
# 0  EspaÃ±a                        paella
# 1   JapÃ³n                         sushi
# 2  Francia  La Lamproie Ã  la Bordelaise

# %%
pd.read_csv('data/encoding.csv')
# Out:
#       País                       Comida
# 0   España                       paella
# 1    Japón                        sushi
# 2  Francia  La Lamproie à la Bordelaise

# %%
pd.read_csv('data/encoding.csv', encoding = 'ascii')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 pd.read_csv('data/encoding.csv', encoding = 'ascii')
#
# File c:\Users\urkow\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\urkow\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File c:\Users\urkow\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\urkow\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1922, in TextFileReader._make_engine(self, f, engine)
#    1919     raise ValueError(msg)
#    1921 try:
# -> 1922     return mapping[engine](f, **self.options)
#    1923 except Exception:
#    1924     if self.handles is not None:
#
# File c:\Users\urkow\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:95, in CParserWrapper.__init__(self, src, **kwds)
#      92 if kwds["dtype_backend"] == "pyarrow":
#      93     # Fail here loudly instead of in cython after reading
#      94     import_optional_dependency("pyarrow")
# ---> 95 self._reader = parsers.TextReader(src, **kwds)
#      97 self.unnamed_cols = self._reader.unnamed_cols
#      99 passed_names = self.names is None
#
# File pandas/_libs/parsers.pyx:568, in pandas._libs.parsers.TextReader.__cinit__()
#
# File pandas/_libs/parsers.pyx:657, in pandas._libs.parsers.TextReader._get_header()
#
# File pandas/_libs/parsers.pyx:868, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File pandas/_libs/parsers.pyx:885, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File pandas/_libs/parsers.pyx:2076, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xc3 in position 2: ordinal not in range(128)

# %%
pd.read_csv('data/encoding.csv', encoding='iso8859_10')
# Out:
#      PaÃ­s                        Comida
# 0  EspaÃąa                        paella
# 1   JapÃģn                         sushi
# 2  Francia  La Lamproie Ã  la Bordelaise

# %%
pd.read_csv('data/encoding.csv')
# Out:
#       País                       Comida
# 0   España                       paella
# 1    Japón                        sushi
# 2  Francia  La Lamproie à la Bordelaise

# %% [markdown]
# ## 10. Archivos y carpetas
# Resulta de gran utilidad automatizar lecturas/escrituras/borrado/movimientos de archivos entre carpetas. Si tenemos un proceso definido en Python, podremos ejecutarlo tantas veces queramos y de este modo evitar dedicarle tiempo tareas tediosas y rutinarias. Para ello tendremos que apoyarnos en el módulo de Python `os`.
#
# Lo primero de todo es saber en qué directorio estamos trabajando. Esto es fundamental para elegir bien la ruta relativa.

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\urkow\\Documents\\Documentos_Clase\\2026-02-BILBAO-FT-Data-Science\\2-Data_Analysis\\3-Sources\\Archivos\\Teoría'

# %%
import shutil

# %% [markdown]
# El directorio de trabajo lo podríamos cambiar si quisiéramos, por ejemplo, al escritorio.

# %%
os.chdir('*+*+_Mi_ruta_absoluta_al_escritorio_+*+*')
print(os.getcwd())
print(os.listdir())
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 os.chdir('*+*+_Mi_ruta_absoluta_al_escritorio_+*+*')
#       2 print(os.getcwd())
#       3 print(os.listdir())
#
# OSError: [WinError 123] El nombre de archivo, el nombre de directorio o la sintaxis de la etiqueta del volumen no son correctos: '*+*+_Mi_ruta_absoluta_al_escritorio_+*+*'

# %% [markdown]
# Podemos juntar rutas en un único path. Realiza un concatenado con barras entendibles por Windows.

# %%
os.path.join("C:\\path\\directory", "some_file.txt")
# Out:
# 'C:\\path\\directory\\some_file.txt'

# %% [markdown]
# Si quieres buscar algún tipo de archivo concreto, tienes varias opciones:
# - Buscar por nombre
# - Buscar por extensión
#
# En función de lo que encuentres, realizarás una operación u otra. Ahora bien, igualmente para buscar, tendrás que recorrer todos los archivos que estén en un directorio o en varios directorios. Para listar todos los ARCHIVOS y CARPETAS que hay en el directorio actual de trabajo, utilizamos `os.listdir()`.

# %%
os.getcwd()
# Out:
# 'c:\\Users\\urkow\\Documents\\Documentos_Clase\\2026-02-BILBAO-FT-Data-Science\\2-Data_Analysis\\3-Sources\\Archivos\\Teoría'

# %%
os.listdir()
# Out:
# ['data',
#  'extracted_files',
#  'img',
#  'Lectura_Escritura.ipynb',
#  'print_os_getcwd.py']

# %% [markdown]
# Voy a quedarme con todos los notebooks del actual directorio de trabajo.

# %%
for i in os.listdir():
    if i.endswith('.ipynb'):
        print("Notebook", i)
# Out:
# Notebook Lectura_Escritura.ipynb

# %% [markdown]
# Si quiero acceder sólo a los directorios

# %%
for i in os.listdir():
    if '.' not in i:
        print("directorio", i)
# Out:
# directorio data
# directorio extracted_files
# directorio img

# %% [markdown]
# Otro método interesante para bucear en los archivos y carpetas de un directorio concreto es el `os.walk()`. Va a devolver un iterable que podremos recorrer en un for y obtener en formato tupla todos los archivos, subcarpetas y ficheros de subcarpetas. Para cada elemento de la tupla tenemos:
# - El directorio donde está apuntando.
# - Los directorios que hay ahí.
# - Los archivos que hay ahí.

# %%
result_generator = os.walk(os.getcwd())

files_result = [x for x in result_generator]
files_result
# Out:
# [('c:\\Users\\urkow\\Documents\\Documentos_Clase\\2026-02-BILBAO-FT-Data-Science\\2-Data_Analysis\\3-Sources\\Archivos\\Teoría',
#   ['data', 'extracted_files', 'img'],
#   ['Lectura_Escritura.ipynb', 'print_os_getcwd.py']),
#  ('c:\\Users\\urkow\\Documents\\Documentos_Clase\\2026-02-BILBAO-FT-Data-Science\\2-Data_Analysis\\3-Sources\\Archivos\\Teoría\\data',
#   [],
#   ['class_hlf.py',
#    'class_hlf.txt',
#    'data_file.json',
#    'dog_breeds.txt',
#    'dummy.csv',
#    'ejercicio.csv',
#    'ejercicio_clase.csv',
#    'encoding.csv',
#    'file_write.txt',
#    'file_writes.txt',
#    'importante.pkl',
#    'laliga.csv',
#    'laliga.xlsx',
#    'laliga4.csv',
#    'laligaExcelWrite.xlsx',
#    'laligaPC.csv',
#    'laligaTSV.tsv',
#    'laligaTXT.txt',
#    'laligaWrite.csv',
#    'laligaZIP.csv',
#    'laligaZIP.zip',
#    'Musical_Instruments_5.json',
#    'pepe.json',
#    'poblacion.csv',
#    'preguntas.py']),
#  ('c:\\Users\\urkow\\Documents\\Documentos_Clase\\2026-02-BILBAO-FT-Data-Science\\2-Data_Analysis\\3-Sources\\Archivos\\Teoría\\extracted_files',
#   [],
#   ['laligaZIP.csv']),
#  ('c:\\Users\\urkow\\Documents\\Documentos_Clase\\2026-02-BILBAO-FT-Data-Science\\2-Data_Analysis\\3-Sources\\Archivos\\Teoría\\img',
#   [],
#   ['ejercicio.png',
#    'ejercicios.png',
#    'encoding.jpg',
#    'error.png',
#    'file.png',
#    'importante',
#    'json_image.png',
#    'path.png',
#    'python.jpg',
#    'python.png'])]

# %% [markdown]
# ¿Qué podemos hacer dentro de un directorio, aparte de listar ficheros y subdirectorios? Las principales operaciones serían:
# - Crear o eliminar directorios
# - Crear o eliminar ficheros
# - Mover ficheros

# %%
os.getcwd()
# Out:
# 'c:\\Users\\urkow\\Documents\\Documentos_Clase\\2026-02-BILBAO-FT-Data-Science\\2-Data_Analysis\\3-Sources\\Archivos\\Teoría'

# %%
os.listdir("c:\\Users\\urkow\\Documents\\Documentos_Clase\\2026-02-BILBAO-FT-Data-Science\\2-Data_Analysis\\3-Sources\\Archivos\\Teoría")
# Out:
# ['data',
#  'extracted_files',
#  'img',
#  'Lectura_Escritura.ipynb',
#  'print_os_getcwd.py']

# %%
os.mkdir('direct_prueba')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 os.mkdir('direct_prueba')
#
# FileExistsError: [Errno 17] File exists: 'direct_prueba'

# %%
os.rmdir('direct_prueba')

# %%
f = open("fichero.txt", "w")

for i in range(10):
    f.write("Line:" + str(i)+ "\n")
    
f.close()

# %%
import shutil
shutil.move("fichero.txt", "fichero2.txt")
# Out:
# 'fichero2.txt'

# %%
shutil.move("fichero2.txt", "extracted_files/")
# Out:
# 'extracted_files/fichero2.txt'

# %%
os.remove('extracted_files/fichero2.txt')

# %%
os.path.abspath('data/fichero.txt')
# Out:
# 'c:\\Users\\urkow\\Documents\\Documentos_Clase\\2026-02-BILBAO-FT-Data-Science\\2-Data_Analysis\\3-Sources\\Archivos\\Teoría\\data\\fichero.txt'

# %%
os.path.dirname(os.path.abspath('data/fichero.txt'))
# Out:
# 'c:\\Users\\urkow\\Documents\\Documentos_Clase\\2026-02-BILBAO-FT-Data-Science\\2-Data_Analysis\\3-Sources\\Archivos\\Teoría\\data'

# %%
os.getcwd()
# Out:
# 'c:\\Users\\urkow\\Documents\\Documentos_Clase\\2026-02-BILBAO-FT-Data-Science\\2-Data_Analysis\\3-Sources\\Archivos\\Teoría'

# %%
os.path.abspath('extracted_files/laligaZIP.csv')
# Out:
# 'c:\\Users\\urkow\\Documents\\Documentos_Clase\\2026-02-BILBAO-FT-Data-Science\\2-Data_Analysis\\3-Sources\\Archivos\\Teoría\\extracted_files\\laligaZIP.csv'

# %%
os.path.dirname(os.path.abspath('extracted_files/laligaZIP.csv'))
# Out:
# 'c:\\Users\\urkow\\Documents\\Documentos_Clase\\2026-02-BILBAO-FT-Data-Science\\2-Data_Analysis\\3-Sources\\Archivos\\Teoría\\extracted_files'
