# %% [markdown]
#    #                                                  Titanic Exercise
#
#    ![titanic](https://userscontent2.emaze.com/images/a5f68f37-6349-4065-a1fc-921cbe7401b2/958230111417e36d6b3c67ffd7bc3494.jpeg)
#    #### Practise Pandas

# %% [markdown]
# First of all, import the needed libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. Read in filename and call the variable `titanic`
#     - Explore the `titanic` dataset using `info`, `dtypes` & `describe`

# %%
titanic = pd.read_csv('./data/titanic.csv') # Ruta lógica desde donde se encuentra el dataset
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   str
#  3   sex        1309 non-null   str
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   str
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    str
#  10  embarked   1307 non-null   str
#  11  boat       486 non-null    str
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    str
# dtypes: float64(3), int64(4), str(7)
# memory usage: 143.3 KB

# %%
titanic.describe().T
# Out:
#            count        mean        std   min      25%       50%      75%  \
# pclass    1309.0    2.294882   0.837836  1.00   2.0000    3.0000    3.000
# survived  1309.0    0.381971   0.486055  0.00   0.0000    0.0000    1.000
# age       1046.0   29.881138  14.413493  0.17  21.0000   28.0000   39.000
# sibsp     1309.0    0.498854   1.041658  0.00   0.0000    0.0000    1.000
# parch     1309.0    0.385027   0.865560  0.00   0.0000    0.0000    0.000
# fare      1308.0   33.295479  51.758668  0.00   7.8958   14.4542   31.275
# body       121.0  160.809917  97.696922  1.00  72.0000  155.0000  256.000
#
#                max
# pclass      3.0000
# survived    1.0000
# age        80.0000
# sibsp       8.0000
# parch       9.0000
# fare      512.3292
# body      328.0000

# %% [markdown]
# 2. Create a separate dataframe with the columns `['name', 'sex', 'age']`, call it `people`
#
# It can be done two ways, do it both!

# %%
# Cogemos las columnas directamente y las guardamos
people = titanic[['name','sex','age']]
people
# Out:
#                                                  name     sex    age
# 0                       Allen, Miss. Elisabeth Walton  female  29.00
# 1                      Allison, Master. Hudson Trevor    male   0.92
# 2                        Allison, Miss. Helen Loraine  female   2.00
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.00
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# ...                                               ...     ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.50
# 1305                            Zabour, Miss. Thamine  female    NaN
# 1306                        Zakarian, Mr. Mapriededer    male  26.50
# 1307                              Zakarian, Mr. Ortin    male  27.00
# 1308                               Zimmerman, Mr. Leo    male  29.00
#
# [1309 rows x 3 columns]

# %%
# Con índices implícitos
name = titanic.loc[:,['name','sex','age']]
name
# Out:
#                                                  name     sex    age
# 0                       Allen, Miss. Elisabeth Walton  female  29.00
# 1                      Allison, Master. Hudson Trevor    male   0.92
# 2                        Allison, Miss. Helen Loraine  female   2.00
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.00
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# ...                                               ...     ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.50
# 1305                            Zabour, Miss. Thamine  female    NaN
# 1306                        Zakarian, Mr. Mapriededer    male  26.50
# 1307                              Zakarian, Mr. Ortin    male  27.00
# 1308                               Zimmerman, Mr. Leo    male  29.00
#
# [1309 rows x 3 columns]

# %% [markdown]
# 3. Print the output of `people` showing the first three rows and the last four rows, using `append`,`tail` and `head`

# %%
people3h = pd.concat([people.head(3),people.tail(3)],ignore_index=True)
people3h
# Out:
#                              name     sex    age
# 0   Allen, Miss. Elisabeth Walton  female  29.00
# 1  Allison, Master. Hudson Trevor    male   0.92
# 2    Allison, Miss. Helen Loraine  female   2.00
# 3       Zakarian, Mr. Mapriededer    male  26.50
# 4             Zakarian, Mr. Ortin    male  27.00
# 5              Zimmerman, Mr. Leo    male  29.00

# %% [markdown]
# 4. Slice the row from 3 to 9, call it `s_titanic`

# %%
s_titanic = titanic.iloc[2:9]
s_titanic
# Out:
#    pclass  survived                                             name     sex  \
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
#
#     age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 2   2.0      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 5  48.0      0      0   19952   26.5500      E12        S    3    NaN
# ...

# %% [markdown]
# 5. Slice the row from 40 to 63 in reverse order, call it `s_titanic_rev`

# %%
# Del 63 (62) al 40 (39 incluido -> 38)
# Pensaba que no era necesario 
s_titanic_rev = titanic.iloc[62:38:-1]
s_titanic_rev
# Out:
#     pclass  survived                                               name  \
# 62       1         0                        Chaffee, Mr. Herbert Fuller
# 61       1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 60       1         0                      Cavendish, Mr. Tyrell William
# 59       1         1  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
# 58       1         0                             Case, Mr. Howard Brown
# 57       1         1          Carter, Mrs. William Ernest (Lucile Polk)
# 56       1         1                         Carter, Mr. William Ernest
# 55       1         1                          Carter, Miss. Lucile Polk
# 54       1         1                Carter, Master. William Thornton II
# 53       1         0                             Carrau, Mr. Jose Pedro
# 52       1         0                            Carrau, Mr. Francisco M
# 51       1         0                           Carlsson, Mr. Frans Olof
# ...

# %% [markdown]
# 6. Slice the columns from the starting column to `'parch'`, call it `left_columns`

# %%
left_columns = titanic.loc[:,:'parch']
left_columns
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch
# 0     female  29.00      0      0
# ...

# %% [markdown]
# 7. Slice the columns from `'name'` to `'age'`, call it `middle_columns`

# %%
middle_columns = titanic.loc[:,'name':'age']
middle_columns
# Out:
#                                                  name     sex    age
# 0                       Allen, Miss. Elisabeth Walton  female  29.00
# 1                      Allison, Master. Hudson Trevor    male   0.92
# 2                        Allison, Miss. Helen Loraine  female   2.00
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.00
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# ...                                               ...     ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.50
# 1305                            Zabour, Miss. Thamine  female    NaN
# 1306                        Zakarian, Mr. Mapriededer    male  26.50
# 1307                              Zakarian, Mr. Ortin    male  27.00
# 1308                               Zimmerman, Mr. Leo    male  29.00
#
# [1309 rows x 3 columns]

# %% [markdown]
# 8. Slice the columns from `'ticket'` to the end, call it `right_columns`

# %%
right_columns = titanic.loc[:,'ticket':]
right_columns
# Out:
#       ticket      fare    cabin embarked boat   body  \
# 0      24160  211.3375       B5        S    2    NaN
# 1     113781  151.5500  C22 C26        S   11    NaN
# 2     113781  151.5500  C22 C26        S  NaN    NaN
# 3     113781  151.5500  C22 C26        S  NaN  135.0
# 4     113781  151.5500  C22 C26        S  NaN    NaN
# ...      ...       ...      ...      ...  ...    ...
# 1304    2665   14.4542      NaN        C  NaN  328.0
# 1305    2665   14.4542      NaN        C  NaN    NaN
# 1306    2656    7.2250      NaN        C  NaN  304.0
# 1307    2670    7.2250      NaN        C  NaN    NaN
# 1308  315082    7.8750      NaN        S  NaN    NaN
#
#                             home.dest
# 0                        St Louis, MO
# 1     Montreal, PQ / Chesterville, ON
# 2     Montreal, PQ / Chesterville, ON
# 3     Montreal, PQ / Chesterville, ON
# 4     Montreal, PQ / Chesterville, ON
# ...                               ...
# 1304                              NaN
# ...

# %% [markdown]
# 9. What is the name of the oldest person who died in the Titanic? Was he or she travelling alone or had any family travelling with them?

# %% [markdown]
# In order to give an answer to the second question you should find out which columns give you that info. Usually part of your job as a Data Scientist will be get to know the dataset which you are working with. In this case the columns which give you that info are the following:
#         - 'sibsp' Number of Siblings/Spouses Aboard
#         - 'parch' Number of Parents/Children Aboard

# %%
# Edad de la persona muerta más mayor
# Entiendo que en la columna 'survided' 1 significa sí
muertos = titanic[titanic['survived'] == 0]
nom_mayor = muertos[['name']][muertos['age'] == muertos['age'].max()]
nom_mayor
# Out:
#                      name
# 1235  Svensson, Mr. Johan

# %%
# Viajaba solo o con familia?
# 'sibsp' nos da el número de familiares
# familiares = titanic[['name','survived','sibsp','parch']][titanic['name'] == nom_mayor]
# familiares

# %% [markdown]
# 10. Create the list of 5 random numbers of rows from 0 to the lenght of the dataframe, call it `rows`
#
# ex. `rows = [3,7,99,52,48]` use `random` library

# %% [markdown]
# This list of numbers are random, could be different.

# %%
import random

# %%
rows = [random.randint(0, len(titanic) - 1) for _ in range(5)]
rows
# Out:
# [568, 236, 428, 883, 1294]

# %%
rows2 = random.sample(range(len(titanic)), 5)
rows2
# Out:
# [1041, 700, 1064, 1268, 718]

# %% [markdown]
# 11. Create the list of three column labels, call it `cols`

# %%
# Obtenemos índices aleatorios
columnas = [random.randint(0, len(titanic.columns) - 1) for _ in range(3)]
columnas
# Out:
# [7, 5, 10]

# %%
# Buscamos los nombres de las columnas con esos índices
cols = [titanic.columns[c] for c in columnas]
cols
# Out:
# ['ticket', 'sibsp', 'embarked']

# %%
cols2 = [random.choice(list(titanic.columns)) for _ in range(3)]
cols2
# Out:
# ['embarked', 'embarked', 'sex']

# %% [markdown]
# 12. Use both lists `rows` and `cols` to create a new dataframe

# %%
titanic_12 = titanic.loc[rows,cols]
titanic_12
# Out:
#         ticket  sibsp embarked
# 568     248734      0        S
# 236   PC 17760      0        C
# 428     250649      0        S
# 883     350050      0        S
# 1294     54636      0        S

# %%
# Comprobamos elos datos recuperados
titanic.loc[rows]
# Out:
#       pclass  survived                             name     sex   age  sibsp  \
# 568        2         0                Swane, Mr. George    male  18.5      0
# 236        1         0              Ringhini, Mr. Sante    male  22.0      0
# 428        2         1  Hamalainen, Mrs. William (Anna)  female  24.0      0
# 883        3         0           Jensen, Mr. Hans Peder    male  20.0      0
# 1294       3         0             Williams, Mr. Leslie    male  28.5      0
#
#       parch    ticket      fare cabin embarked boat   body    home.dest
# 568       0    248734   13.0000     F        S  NaN  294.0          NaN
# 236       0  PC 17760  135.6333   NaN        C  NaN  232.0          NaN
# 428       2    250649   14.5000   NaN        S    4    NaN  Detroit, MI
# 883       0    350050    7.8542   NaN        S  NaN    NaN          NaN
# 1294      0     54636   16.1000   NaN        S  NaN   14.0          NaN

# %% [markdown]
# 13. Create a boolean array with the condition of being a woman or a man, using the `sex` column, where **female** is True. Call it `array_fe`

# %%
array_fe = titanic['sex'] == 'female'
array_fe
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 1304     True
# 1305     True
# 1306    False
# 1307    False
# 1308    False
# Name: sex, Length: 1309, dtype: bool

# %% [markdown]
# 14. Rename the column `"sex"` to `"gender"` and filter the `titanic` dataframe with the boolean array, call it `woman_titanic`

# %%
# Renombramos columna
titanic = titanic.rename(columns={'sex': 'gender'})
# titanic

# %%
# Filtramos mujeres
woman_titanic = titanic[array_fe]
woman_titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 2          1         0                     Allison, Miss. Helen Loraine
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
#
#       gender   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# 15. How many woman were younger than 18? Call the variable `minor_wo`

# %%
minor_wo = woman_titanic[woman_titanic['age'] < 18]
len(minor_wo)
# Out:
# 72

# %%
minor_wo = woman_titanic[woman_titanic['age'].lt(18)] 
# lt() less than
# gt() greater than
# le() less or equal
# ge() greater or equal

len(minor_wo)
# Out:
# 72

# %% [markdown]
# 16. How many woman that were less than 18 actually died? Call the variable `dead_wo`

# %%
dead_wo = minor_wo[minor_wo['survived'] == 0]
len(dead_wo)
# Out:
# 22

# %% [markdown]
# 17. Drop rows with *Nan* in `titanic` with `how='any'` and print the shape

# %%
titanic_nonan = titanic.dropna(how='any') # Borra celda de la fila o columna (axis=1) es NaN
titanic_nonan.shape
# Out:
# (0, 14)

# %% [markdown]
# 18. Drop rows with *Nan* in `titanic` with `how='all'` and print the shape

# %%
titanic_nonan = titanic.dropna(how='all') # Borra toda la fila o columna (axis=1) es NaN
titanic_nonan.shape
# Out:
# (1309, 14)

# %% [markdown]
# Check in [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html) why the shapes are different.

# %% [markdown]
# 19. Drop columns in `titanic` with more than 1000 missing values and print the columns remaining

# %%
titanic.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   str
#  3   gender     1309 non-null   str
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   str
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    str
#  10  embarked   1307 non-null   str
#  11  boat       486 non-null    str
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    str
# dtypes: float64(3), int64(4), str(7)
# memory usage: 143.3 KB

# %%
# fare, cabin, embarked, boat, body y home.dest tienen valores nulos
# cabin y body tienen más de 1000 nulos
cols_drop = titanic.columns[titanic.isna().sum() > 1000]
titanic_19 = titanic.drop(columns=cols_drop)
titanic_19
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#       gender    age  sibsp  parch  ticket      fare embarked boat  \
# ...

# %%
# También he visto que se puede hacer de otra manera
titanic_19 = titanic.dropna(axis=1, thresh=len(titanic) - 1000)
titanic_19
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#       gender    age  sibsp  parch  ticket      fare embarked boat  \
# ...

# %% [markdown]
# 20. Calculate the ratio of missing values at the `boat` column.

# %%
# Sumamos los valores nulos de la columna 'boat'
titanic['boat'].isna().sum()/len(titanic) # Es exactamente lo mismo que mean()
# Out:
# np.float64(0.6287242169595111)

# %% [markdown]
# 21.  Group `titanic` by `'pclass'` and aggregate by the columns `age` & `fare`, by `max` and `median` and assign it to `by_class`

# %%
by_class = titanic.groupby('pclass').agg({'age': ['max', 'median'],
                                          'fare': ['max', 'median']})
by_class
# Out:
#          age             fare
#          max median       max   median
# pclass
# 1       80.0   39.0  512.3292  60.0000
# 2       70.0   29.0   73.5000  15.0458
# 3       74.0   24.0   69.5500   8.0500

# %% [markdown]
# 22. Print the maximum age in each class from `by_class`

# %%
# Acceso multiíndice
by_class[[('age','max')]]
# Out:
#          age
#          max
# pclass
# 1       80.0
# 2       70.0
# 3       74.0

# %% [markdown]
# 23. Print the median fare in each class from `by_class`

# %%
# Acceso multiíndice
by_class[[('fare','median')]]
# Out:
#            fare
#          median
# pclass
# 1       60.0000
# 2       15.0458
# 3        8.0500

# %% [markdown]
# 24. Using [`.pivot_table()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html) to count how many women or men survived by class, call it `counted`.
#
# Don't panic and read the documentation!

# %%
counted = pd.pivot_table(titanic, values='survived', index='pclass', columns='gender', aggfunc='sum')
counted
# Out:
# gender  female  male
# pclass
# 1          139    61
# 2           94    25
# 3          106    75

# %% [markdown]
# 25. Add a new column with the sum of survived men and women, call it `counted['total']`

# %%
counted['total'] = counted['male'] + counted['female']
counted
# Out:
# gender  female  male  total
# pclass
# 1          139    61    200
# 2           94    25    119
# 3          106    75    181

# %%
counted.loc["Total"] = counted[['female', 'male']].sum()
counted
# Out:
# gender  female   male  total
# pclass
# 1        139.0   61.0  200.0
# 2         94.0   25.0  119.0
# 3        106.0   75.0  181.0
# Total    339.0  161.0    NaN

# %%
counted['total_class'] = counted.sum(axis=1)
counted
# Out:
# gender  female   male  total  total_class
# pclass
# 1        139.0   61.0  200.0        400.0
# 2         94.0   25.0  119.0        238.0
# 3        106.0   75.0  181.0        362.0
# Total    339.0  161.0    NaN        500.0

# %% [markdown]
# 26. Sort `counted` by the `'total'` column. In which class the people survived the most?

# %%
counted.sort_values('total_class',ascending=False)
# Out:
# gender  female   male  total  total_class
# pclass
# Total    339.0  161.0    NaN        500.0
# 1        139.0   61.0  200.0        400.0
# 3        106.0   75.0  181.0        362.0
# 2         94.0   25.0  119.0        238.0

# %% [markdown]
# 27. Please, show only the rows using a mask with the following conditions:
#     - They are woman
#     - From third class
#     - Younger than 30
#     - They survived
#
#     ¿How many rows fulfill the condition?

# %%
# Usamos woman_titanic, que ya tenemos el filtro de mujeres
mask = (woman_titanic['pclass'] == 3) & (woman_titanic['age'] < 30) & (woman_titanic['survived'] == 1)

# Número de personas que cumplen esas condiciones
len(woman_titanic[mask])
# Out:
# 57

# %% [markdown]
# 28. Now, show only the rows using `.loc` with the following conditions:
#     - They are man
#     - From first class
#     - Older than 50
#     - They died
#
#     ¿How many rows fulfill the condition?

# %%
# df con las condiciones
titanic_28 = titanic.loc[(titanic['gender'] == 'male') & (titanic['pclass'] == 1) & (titanic['age'] > 50) & (titanic['survived'] == 0)]
len(titanic_28[['name']])
# Out:
# 29

# %% [markdown]
# 29. Print the uniques values at the column `'name'`

# %%
print(list(titanic['name'].unique()))
# Out:
# ['Allen, Miss. Elisabeth Walton', 'Allison, Master. Hudson Trevor', 'Allison, Miss. Helen Loraine', 'Allison, Mr. Hudson Joshua Creighton', 'Allison, Mrs. Hudson J C (Bessie Waldo Daniels)', 'Anderson, Mr. Harry', 'Andrews, Miss. Kornelia Theodosia', 'Andrews, Mr. Thomas Jr', 'Appleton, Mrs. Edward Dale (Charlotte Lamson)', 'Artagaveytia, Mr. Ramon', 'Astor, Col. John Jacob', 'Astor, Mrs. John Jacob (Madeleine Talmadge Force)', 'Aubart, Mme. Leontine Pauline', 'Barber, Miss. Ellen "Nellie"', 'Barkworth, Mr. Algernon Henry Wilson', 'Baumann, Mr. John D', 'Baxter, Mr. Quigg Edmond', 'Baxter, Mrs. James (Helene DeLaudeniere Chaput)', 'Bazzani, Miss. Albina', 'Beattie, Mr. Thomson', 'Beckwith, Mr. Richard Leonard', 'Beckwith, Mrs. Richard Leonard (Sallie Monypeny)', 'Behr, Mr. Karl Howell', 'Bidois, Miss. Rosalie', 'Bird, Miss. Ellen', 'Birnbaum, Mr. Jakob', 'Bishop, Mr. Dickinson H', 'Bishop, Mrs. Dickinson H (Helen Walton)', 'Bissette, Miss. Amelia', 'Bjornstrom-Steffansson, Mr. Maurit
# ...

# %%
titanic['name'].nunique()
# Out:
# 1307

# %% [markdown]
# 30. Find if was there any `name` repeated at the Titanic?
#
# Hint: There were two people with the same name, who?

# %%
titanic[['name']][titanic['name'].duplicated()]
# Out:
#                      name
# 726  Connolly, Miss. Kate
# 925      Kelly, Mr. James

# %% [markdown]
# 31. Using `matplotlib` find the appropriate visualization to show the distribution of the column `'age'`

# %%
import matplotlib.pyplot as plt

# %%
titanic['age'].hist(bins=33);

# %%
plt.hist(titanic['age'], bins=33, edgecolor='yellow');

# %% [markdown]
# 32. Using `matplotlib` find the appropriate plot to visualize the column `'gender'`

# %%
counts = titanic['gender'].value_counts()

plt.bar(counts.index, counts.values)
plt.xlabel('Gender');

# %%
# Otra manera con el pastelito
counts = titanic['gender'].value_counts()

plt.pie(counts.values, labels=counts.index, autopct='%1.1f%%') # autopct muestra porcentajes
plt.title('Proportion of Gender')
# plt.show()
# Out:
# Text(0.5, 1.0, 'Proportion of Gender')

# %% [markdown]
# 32b. What if you also plot the column `'gender'` using the function [`countplot`](https://seaborn.pydata.org/generated/seaborn.countplot.html) from the library [`seaborn`](https://seaborn.pydata.org/)?
#
# Remember you have never used `seaborn` before, therefore you should install it before importing it.

# %%
sns.countplot(data=titanic, x='gender')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %% [markdown]
# 33. Using the function [`catplot`](https://seaborn.pydata.org/generated/seaborn.catplot.html) from the library `seaborn`, find out if the hypothesis _"Women are more likely to survive shipwrecks"_ is true or not.
#
# You should get something like this:

# %% [markdown]
# ![catplot](./img/catplotgen.png)

# %%
# Por sexo, se cuentan los supervivientes y muertos
sns.catplot(data=titanic,x='gender',hue='survived', kind='count', height=5, aspect=1.2)

plt.title('Vividor de la vida por sexo')
plt.xlabel('Gender')
plt.ylabel('Count');

# %%
sns.catplot(data=titanic, x='gender', y='survived', hue='gender', kind='bar');

# %% [markdown]
# 34. Using [`kdeplot`]("https://seaborn.pydata.org/generated/seaborn.kdeplot.html") from `seaborn` represent those who not survived distributed by age.<>
#
# Hint: First you should "filter" the `titanic` dataset where the column "survived" is 0, indexing the column `"age"` only.
#
# Arguments you should pass to the function:
#
#     - color = "red"
#     - label = "Not Survived"
#     - shade = True
#
# You should get something like this:

# %% [markdown]
# ![kdeplot](./img/kdeplotsur.png)

# %%
edad_muertes = titanic.loc[titanic['survived'] == 0, 'age']
edad_muertes
# Out:
# 2        2.0
# 3       30.0
# 4       25.0
# 7       39.0
# 9       71.0
#         ...
# 1304    14.5
# 1305     NaN
# 1306    26.5
# 1307    27.0
# 1308    29.0
# Name: age, Length: 809, dtype: float64

# %%
from matplotlib.lines import Line2D

# Replicamos lo que nos piden
sns.kdeplot(data=edad_muertes, color='red', label='Not Survived', fill=True)

line = Line2D([0], [0], color='red')

plt.legend(handles=[line], labels=['Not Survived'])
